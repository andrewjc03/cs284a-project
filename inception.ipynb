# %% [markdown]
# <a href="https://colab.research.google.com/github/andrewjc03/cs284a-project/blob/main/DR_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Connect to drive (where dataset is uploaded)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Out:
# drive  sample_data

# %%
# !unzip "drive/MyDrive/Colab Notebooks/data.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train_images/b9fe7da14a32.png
#   inflating: __MACOSX/train_images/._b9fe7da14a32.png
#   inflating: train_images/9cc6b1f9bcbd.png
#   inflating: __MACOSX/train_images/._9cc6b1f9bcbd.png
#   inflating: train_images/e06d3d4733f0.png
#   inflating: __MACOSX/train_images/._e06d3d4733f0.png
#   inflating: train_images/48fda42bd5d4.png
#   inflating: __MACOSX/train_images/._48fda42bd5d4.png
#   inflating: train_images/a386ec9aabde.png
#   inflating: __MACOSX/train_images/._a386ec9aabde.png
#   inflating: train_images/6fe67482bfae.png
#   inflating: __MACOSX/train_images/._6fe67482bfae.png
#   inflating: train_images/2f8d14a7d390.png
#   inflating: __MACOSX/train_images/._2f8d14a7d390.png
#   inflating: train_images/0abf0c485f66.png
#   inflating: __MACOSX/train_images/._0abf0c485f66.png
#   inflating: train_images/8a3eb86ae4bd.png
#   inflating: __MACOSX/train_images/._8a3eb86ae4bd.png
#   inflating: train_images/fd87b6b2e664.png
#   inflating: __MACOSX/train_images/._fd87b6b2e664.png
#   inflating: train_images/0fbbd665431f.png
#   inflating: __MACOSX/train_images/._0fbbd665431f.png
#   inflating: train_images/b402daa0864c.png
#   inflating: __MACOSX/train_images/._b402daa0864c.png
#   inflating: train_images/958c1fa044ba.png
#   inflating: __MACOSX/train_images/._958c1fa044ba.png
#   inflating: train_images/d51b3fe0fa1b.png
#   inflating: __MACOSX/train_images/._d51b3fe0fa1b.png
#   inflating: train_images/22098b1fe461.png
#   inflating: __MACOSX/train_images/._22098b1fe461.png
#   inflating: train_images/8114d6a160df.png
#   inflating: __MACOSX/train_images/._8114d6a160df.png
#   inflating: train_images/5e7cc6ab4ac4.png
#   inflating: __MACOSX/train_images/._5e7cc6ab4ac4.png
#   inflating: train_images/57a5e4274275.png
#   inflating: __MACOSX/train_images/._57a5e4274275.png
#   inflating: train_images/737ef6226677.png
#   inflating: __MACOSX/train_images/._737ef6226677.png
#   inflating: train_images/e251bdf05b85.png
#   inflating: __MACOSX/train_images/._e251bdf05b85.png
#   inflating: train_images/76516f828d88.png
#   inflating: __MACOSX/train_images/._76516f828d88.png
#   inflating: train_images/ff52392372d3.png
#   inflating: __MACOSX/train_images/._ff52392372d3.png
#   inflating: train_images/96c3e3db68bc.png
#   inflating: __MACOSX/train_images/._96c3e3db68bc.png
#   inflating: train_images/b1197f2cc9b3.png
#   inflating: __MACOSX/train_images/._b1197f2cc9b3.png
#   inflating: train_images/2da82d14e1b7.png
#   inflating: __MACOSX/train_images/._2da82d14e1b7.png
#   inflating: train_images/9e99ae6ee7af.png
#   inflating: __MACOSX/train_images/._9e99ae6ee7af.png
#   inflating: train_images/6c4ec95dd8ba.png
#   inflating: __MACOSX/train_images/._6c4ec95dd8ba.png
#   inflating: train_images/b835b6e31a59.png
#   inflating: __MACOSX/train_images/._b835b6e31a59.png
#   inflating: train_images/2dd28ac497d2.png
#   inflating: __MACOSX/train_images/._2dd28ac497d2.png
#   inflating: train_images/c8905b8d5cf1.png
#   inflating: __MACOSX/train_images/._c8905b8d5cf1.png
#   inflating: train_images/1d674e2e32e0.png
#   inflating: __MACOSX/train_images/._1d674e2e32e0.png
#   inflating: train_images/a150ff5dfe07.png
#   inflating: __MACOSX/train_images/._a150ff5dfe07.png
#   inflating: train_images/5bf3357a2823.png
#   inflating: __MACOSX/train_images/._5bf3357a2823.png
#   inflating: train_images/4b6895d0cf8d.png
#   inflating: __MACOSX/train_images/._4b6895d0cf8d.png
#   inflating: train_images/8ffa608170d3.png
#   inflating: __MACOSX/train_images/._8ffa608170d3.png
#   inflating: train_images/fd48cf452e9d.png
#   inflating: __MACOSX/train_images/._fd48cf452e9d.png
#   inflating: train_images/c58971bcebb2.png
#   inflating: __MACOSX/train_images/._c58971bcebb2.png
#   inflating: train_images/f9d8ff3e6592.png
#   inflating: __MACOSX/train_images/._f9d8ff3e6592.png
#   inflating: train_images/9a56cfb980ec.png
#   inflating: __MACOSX/train_images/._9a56cfb980ec.png
#   inflating: train_images/681c3c115684.png
#   inflating: __MACOSX/train_images/._681c3c115684.png
#   inflating: train_images/8d3d67661620.png
#   inflating: __MACOSX/train_images/._8d3d67661620.png
#   inflating: train_images/6889bc64ab09.png
#   inflating: __MACOSX/train_images/._6889bc64ab09.png
#   inflating: train_images/25a0a1e41afd.png
#   inflating: __MACOSX/train_images/._25a0a1e41afd.png
#   inflating: train_images/a76132e79688.png
#   inflating: __MACOSX/train_images/._a76132e79688.png
#   inflating: train_images/7635921c5efb.png
#   inflating: __MACOSX/train_images/._7635921c5efb.png
#   inflating: train_images/a8b3c0961d42.png
#   inflating: __MACOSX/train_images/._a8b3c0961d42.png
#   inflating: train_images/52edbe29d655.png
#   inflating: __MACOSX/train_images/._52edbe29d655.png
#   inflating: train_images/a56230242a95.png
#   inflating: __MACOSX/train_images/._a56230242a95.png
#   inflating: train_images/034cb07a550f.png
#   inflating: __MACOSX/train_images/._034cb07a550f.png
#   inflating: train_images/ab686895533e.png
#   inflating: __MACOSX/train_images/._ab686895533e.png
#   inflating: train_images/1d74c4713e21.png
#   inflating: __MACOSX/train_images/._1d74c4713e21.png
#   inflating: train_images/f7508f14dd7b.png
#   inflating: __MACOSX/train_images/._f7508f14dd7b.png
#   inflating: train_images/e62490b7d0e9.png
#   inflating: __MACOSX/train_images/._e62490b7d0e9.png
#   inflating: train_images/51a078d6d43a.png
#   inflating: __MACOSX/train_images/._51a078d6d43a.png
#   inflating: train_images/c0a117de7d0a.png
#   inflating: __MACOSX/train_images/._c0a117de7d0a.png
#   inflating: train_images/53327edb9e4d.png
#   inflating: __MACOSX/train_images/._53327edb9e4d.png
#   inflating: train_images/ab03d50bba2f.png
#   inflating: __MACOSX/train_images/._ab03d50bba2f.png
#   inflating: train_images/7f2cce721e19.png
#   inflating: __MACOSX/train_images/._7f2cce721e19.png
#   inflating: train_images/6180920bc224.png
#   inflating: __MACOSX/train_images/._6180920bc224.png
#   inflating: train_images/9c514d2d5b3f.png
#   inflating: __MACOSX/train_images/._9c514d2d5b3f.png
#   inflating: train_images/7e160c8b611e.png
#   inflating: __MACOSX/train_images/._7e160c8b611e.png
#   inflating: train_images/7ddcfcea7369.png
#   inflating: __MACOSX/train_images/._7ddcfcea7369.png
#   inflating: train_images/f02956bd7c50.png
#   inflating: __MACOSX/train_images/._f02956bd7c50.png
#   inflating: train_images/df5ce3ea7820.png
#   inflating: __MACOSX/train_images/._df5ce3ea7820.png
#   inflating: train_images/d6df4fe492ec.png
#   inflating: __MACOSX/train_images/._d6df4fe492ec.png
#   inflating: train_images/bfdee9be1f1d.png
#   inflating: __MACOSX/train_images/._bfdee9be1f1d.png
#   inflating: train_images/596f4fdb0004.png
#   inflating: __MACOSX/train_images/._596f4fdb0004.png
#   inflating: train_images/d6f6bdfd8011.png
#   inflating: __MACOSX/train_images/._d6f6bdfd8011.png
#   inflating: train_images/a1b12fdce6c3.png
#   inflating: __MACOSX/train_images/._a1b12fdce6c3.png
#   inflating: train_images/7ef5ff774a48.png
#   inflating: __MACOSX/train_images/._7ef5ff774a48.png
#   inflating: train_images/af3b0115aad1.png
#   inflating: __MACOSX/train_images/._af3b0115aad1.png
#   inflating: train_images/0dc8d25b3f69.png
#   inflating: __MACOSX/train_images/._0dc8d25b3f69.png
#   inflating: train_images/0efc93ec838b.png
#   inflating: __MACOSX/train_images/._0efc93ec838b.png
#   inflating: train_images/ebe0175e530c.png
#   inflating: __MACOSX/train_images/._ebe0175e530c.png
#   inflating: train_images/c8823cdaf7fa.png
#   inflating: __MACOSX/train_images/._c8823cdaf7fa.png
#   inflating: train_images/4ccfa0b4e96c.png
#   inflating: __MACOSX/train_images/._4ccfa0b4e96c.png
#   inflating: train_images/1541226c5d72.png
#   inflating: __MACOSX/train_images/._1541226c5d72.png
#   inflating: train_images/5b47043942f4.png
#   inflating: __MACOSX/train_images/._5b47043942f4.png
#   inflating: train_images/698d6e422a80.png
#   inflating: __MACOSX/train_images/._698d6e422a80.png
#   inflating: train_images/5728b8aa98ef.png
#   inflating: __MACOSX/train_images/._5728b8aa98ef.png
#   inflating: train_images/4da2961e62fe.png
#   inflating: __MACOSX/train_images/._4da2961e62fe.png
#   inflating: train_images/aa8a1e814811.png
#   inflating: __MACOSX/train_images/._aa8a1e814811.png
#   inflating: train_images/c94f37085d0f.png
#   inflating: __MACOSX/train_images/._c94f37085d0f.png
#   inflating: train_images/52ae917fcea4.png
#   inflating: __MACOSX/train_images/._52ae917fcea4.png
#   inflating: train_images/0fcfc6301f3d.png
#   inflating: __MACOSX/train_images/._0fcfc6301f3d.png
#   inflating: train_images/9a94e0316ee3.png
#   inflating: __MACOSX/train_images/._9a94e0316ee3.png
#   inflating: train_images/df6d13d04da1.png
#   inflating: __MACOSX/train_images/._df6d13d04da1.png
#   inflating: train_images/2d07162a13b1.png
#   inflating: __MACOSX/train_images/._2d07162a13b1.png
#   inflating: train_images/c67117c6ab3b.png
#   inflating: __MACOSX/train_images/._c67117c6ab3b.png
#   inflating: train_images/8660e1864665.png
#   inflating: __MACOSX/train_images/._8660e1864665.png
#   inflating: train_images/803120c5d287.png
#   inflating: __MACOSX/train_images/._803120c5d287.png
#   inflating: train_images/103f97a2ab15.png
#   inflating: __MACOSX/train_images/._103f97a2ab15.png
#   inflating: train_images/12025b34deb8.png
#   inflating: __MACOSX/train_images/._12025b34deb8.png
#   inflating: train_images/454792eb6e05.png
#   inflating: __MACOSX/train_images/._454792eb6e05.png
#   inflating: train_images/310c27067ac0.png
#   inflating: __MACOSX/train_images/._310c27067ac0.png
#   inflating: train_images/ca30a97e9d13.png
#   inflating: __MACOSX/train_images/._ca30a97e9d13.png
#   inflating: train_images/276b14f72328.png
#   inflating: __MACOSX/train_images/._276b14f72328.png
#   inflating: train_images/3b018e8b7303.png
#   inflating: __MACOSX/train_images/._3b018e8b7303.png
#   inflating: train_images/3c1efa38d0da.png
#   inflating: __MACOSX/train_images/._3c1efa38d0da.png
#   inflating: train_images/ed2c52c14493.png
#   inflating: __MACOSX/train_images/._ed2c52c14493.png
#   inflating: train_images/28f73575e1f2.png
#   inflating: __MACOSX/train_images/._28f73575e1f2.png
#   inflating: train_images/fd62bd0db4f1.png
#   inflating: __MACOSX/train_images/._fd62bd0db4f1.png
#   inflating: train_images/e81f4a2fbbdc.png
#   inflating: __MACOSX/train_images/._e81f4a2fbbdc.png
#   inflating: train_images/50f5201fd18a.png
#   inflating: __MACOSX/train_images/._50f5201fd18a.png
#   inflating: train_images/07083738b75e.png
#   inflating: __MACOSX/train_images/._07083738b75e.png
#   inflating: train_images/a2dff8dbc9f8.png
#   inflating: __MACOSX/train_images/._a2dff8dbc9f8.png
#   inflating: train_images/4d1cf360b2d7.png
#   inflating: __MACOSX/train_images/._4d1cf360b2d7.png
#   inflating: train_images/bebfbd907cac.png
#   inflating: __MACOSX/train_images/._bebfbd907cac.png
#   inflating: train_images/f45f1485c940.png
#   inflating: __MACOSX/train_images/._f45f1485c940.png
#   inflating: train_images/ea7e21bab610.png
#   inflating: __MACOSX/train_images/._ea7e21bab610.png
#   inflating: train_images/7e980424868e.png
#   inflating: __MACOSX/train_images/._7e980424868e.png
#   inflating: train_images/674057ab250c.png
#   inflating: __MACOSX/train_images/._674057ab250c.png
#   inflating: train_images/81d79d53ed7b.png
#   inflating: __MACOSX/train_images/._81d79d53ed7b.png
#   inflating: train_images/830e297965a1.png
#   inflating: __MACOSX/train_images/._830e297965a1.png
#   inflating: train_images/17188c13e635.png
#   inflating: __MACOSX/train_images/._17188c13e635.png
#   inflating: train_images/a688f20f8895.png
#   inflating: __MACOSX/train_images/._a688f20f8895.png
#   inflating: train_images/e96bd80a8a53.png
#   inflating: __MACOSX/train_images/._e96bd80a8a53.png
#   inflating: train_images/f36cb007a1ef.png
#   inflating: __MACOSX/train_images/._f36cb007a1ef.png
#   inflating: train_images/7e77b61e1639.png
#   inflating: __MACOSX/train_images/._7e77b61e1639.png
#   inflating: train_images/fe3f62695b2d.png
#   inflating: __MACOSX/train_images/._fe3f62695b2d.png
#   inflating: train_images/02cd34a85b24.png
#   inflating: __MACOSX/train_images/._02cd34a85b24.png
#   inflating: train_images/27b68863349f.png
#   inflating: __MACOSX/train_images/._27b68863349f.png
#   inflating: train_images/a77dbec966d4.png
#   inflating: __MACOSX/train_images/._a77dbec966d4.png
#   inflating: train_images/992b9a07b25f.png
#   inflating: __MACOSX/train_images/._992b9a07b25f.png
#   inflating: train_images/a4b8de38eac1.png
#   inflating: __MACOSX/train_images/._a4b8de38eac1.png
#   inflating: train_images/0161338f53cc.png
#   inflating: __MACOSX/train_images/._0161338f53cc.png
#   inflating: train_images/40527a5e95dd.png
#   inflating: __MACOSX/train_images/._40527a5e95dd.png
#   inflating: train_images/7adfb8fc0621.png
#   inflating: __MACOSX/train_images/._7adfb8fc0621.png
#   inflating: train_images/d3d578fe433f.png
#   inflating: __MACOSX/train_images/._d3d578fe433f.png
#   inflating: train_images/4fecf87184e6.png
#   inflating: __MACOSX/train_images/._4fecf87184e6.png
#   inflating: train_images/e019b3e0f33d.png
#   inflating: __MACOSX/train_images/._e019b3e0f33d.png
#   inflating: train_images/415d5c5e785f.png
#   inflating: __MACOSX/train_images/._415d5c5e785f.png
#   inflating: train_images/d8404680bba6.png
#   inflating: __MACOSX/train_images/._d8404680bba6.png
#   inflating: train_images/d85d052900b4.png
#   inflating: __MACOSX/train_images/._d85d052900b4.png
#   inflating: train_images/0cae727cf119.png
#   inflating: __MACOSX/train_images/._0cae727cf119.png
#   inflating: train_images/82088c6734e6.png
#   inflating: __MACOSX/train_images/._82088c6734e6.png
#   inflating: train_images/c21eb81de9fc.png
#   inflating: __MACOSX/train_images/._c21eb81de9fc.png
#   inflating: train_images/ec6f1797a25a.png
#   inflating: __MACOSX/train_images/._ec6f1797a25a.png
#   inflating: train_images/baaca2f7e1f0.png
#   inflating: __MACOSX/train_images/._baaca2f7e1f0.png
#   inflating: train_images/222f3ee3a1e8.png
#   inflating: __MACOSX/train_images/._222f3ee3a1e8.png
#   inflating: train_images/fa6f3d8bb1d5.png
#   inflating: __MACOSX/train_images/._fa6f3d8bb1d5.png
#   inflating: train_images/60eeae3ba23d.png
#   inflating: __MACOSX/train_images/._60eeae3ba23d.png
#   inflating: train_images/1d14dd912671.png
#   inflating: __MACOSX/train_images/._1d14dd912671.png
#   inflating: train_images/e7b5dd5bab1f.png
#   inflating: __MACOSX/train_images/._e7b5dd5bab1f.png
#   inflating: train_images/7d1da90d3ca9.png
#   inflating: __MACOSX/train_images/._7d1da90d3ca9.png
#   inflating: train_images/13ab8db8c700.png
#   inflating: __MACOSX/train_images/._13ab8db8c700.png
#   inflating: train_images/0dc031c94225.png
#   inflating: __MACOSX/train_images/._0dc031c94225.png
#   inflating: train_images/42b93b574f23.png
#   inflating: __MACOSX/train_images/._42b93b574f23.png
#   inflating: train_images/975252e325e3.png
#   inflating: __MACOSX/train_images/._975252e325e3.png
#   inflating: train_images/6cee2e148520.png
#   inflating: __MACOSX/train_images/._6cee2e148520.png
#   inflating: train_images/38373431d996.png
#   inflating: __MACOSX/train_images/._38373431d996.png
#   inflating: train_images/b8e9a8f4617d.png
#   inflating: __MACOSX/train_images/._b8e9a8f4617d.png
#   inflating: train_images/4ad6109706e8.png
#   inflating: __MACOSX/train_images/._4ad6109706e8.png
#   inflating: train_images/4ef16a53d899.png
#   inflating: __MACOSX/train_images/._4ef16a53d899.png
#   inflating: train_images/59928f999ae7.png
#   inflating: __MACOSX/train_images/._59928f999ae7.png
#   inflating: train_images/07a2b8cabf6b.png
#   inflating: __MACOSX/train_images/._07a2b8cabf6b.png
#   inflating: train_images/c05b7b4c22fe.png
#   inflating: __MACOSX/train_images/._c05b7b4c22fe.png
#   inflating: train_images/840527bc6628.png
#   inflating: __MACOSX/train_images/._840527bc6628.png
#   inflating: train_images/d83c3efade75.png
#   inflating: __MACOSX/train_images/._d83c3efade75.png
#   inflating: train_images/511fd66b2df8.png
#   inflating: __MACOSX/train_images/._511fd66b2df8.png
#   inflating: train_images/3dfc50108072.png
#   inflating: __MACOSX/train_images/._3dfc50108072.png
#   inflating: train_images/7bda86d95c5b.png
#   inflating: __MACOSX/train_images/._7bda86d95c5b.png
#   inflating: train_images/ec01f0862669.png
#   inflating: __MACOSX/train_images/._ec01f0862669.png
#   inflating: train_images/5905a9b06a73.png
#   inflating: __MACOSX/train_images/._5905a9b06a73.png
#   inflating: train_images/904b03ad5594.png
#   inflating: __MACOSX/train_images/._904b03ad5594.png
#   inflating: train_images/417f408ee8e0.png
#   inflating: __MACOSX/train_images/._417f408ee8e0.png
#   inflating: train_images/0c76fd494af6.png
#   inflating: __MACOSX/train_images/._0c76fd494af6.png
#   inflating: train_images/14c3b41d289c.png
#   inflating: __MACOSX/train_images/._14c3b41d289c.png
#   inflating: train_images/2fde69f20585.png
#   inflating: __MACOSX/train_images/._2fde69f20585.png
#   inflating: train_images/76b950c6ed5e.png
#   inflating: __MACOSX/train_images/._76b950c6ed5e.png
#   inflating: train_images/6c6efb6b1358.png
#   inflating: __MACOSX/train_images/._6c6efb6b1358.png
#   inflating: train_images/08bef347f40d.png
#   inflating: __MACOSX/train_images/._08bef347f40d.png
#   inflating: train_images/5a93c0f783c4.png
#   inflating: __MACOSX/train_images/._5a93c0f783c4.png
#   inflating: train_images/b43440c6ebe4.png
#   inflating: __MACOSX/train_images/._b43440c6ebe4.png
#   inflating: train_images/5cbe88914a72.png
#   inflating: __MACOSX/train_images/._5cbe88914a72.png
#   inflating: train_images/c561bcd519e9.png
#   inflating: __MACOSX/train_images/._c561bcd519e9.png
#   inflating: train_images/38e0e28d35d3.png
#   inflating: __MACOSX/train_images/._38e0e28d35d3.png
#   inflating: train_images/a673193cd5a9.png
#   inflating: __MACOSX/train_images/._a673193cd5a9.png
#   inflating: train_images/9dab2e6ba44b.png
#   inflating: __MACOSX/train_images/._9dab2e6ba44b.png
#   inflating: train_images/5b0e53f53ef3.png
#   inflating: __MACOSX/train_images/._5b0e53f53ef3.png
#   inflating: train_images/992599744a23.png
#   inflating: __MACOSX/train_images/._992599744a23.png
#   inflating: train_images/90b8bf342032.png
#   inflating: __MACOSX/train_images/._90b8bf342032.png
#   inflating: train_images/96ea316ed0ab.png
#   inflating: __MACOSX/train_images/._96ea316ed0ab.png
#   inflating: train_images/6653ad026901.png
#   inflating: __MACOSX/train_images/._6653ad026901.png
#   inflating: train_images/ff03f74667df.png
#   inflating: __MACOSX/train_images/._ff03f74667df.png
#   inflating: train_images/fa9f1bc03f21.png
#   inflating: __MACOSX/train_images/._fa9f1bc03f21.png
#   inflating: train_images/ed648b9bcd95.png
#   inflating: __MACOSX/train_images/._ed648b9bcd95.png
#   inflating: train_images/4a7dc013e802.png
#   inflating: __MACOSX/train_images/._4a7dc013e802.png
#   inflating: train_images/17e6116b89b3.png
#   inflating: __MACOSX/train_images/._17e6116b89b3.png
#   inflating: train_images/76cab26493f1.png
#   inflating: __MACOSX/train_images/._76cab26493f1.png
#   inflating: train_images/cfb17a7cc8d4.png
#   inflating: __MACOSX/train_images/._cfb17a7cc8d4.png
#   inflating: train_images/3286073a976e.png
#   inflating: __MACOSX/train_images/._3286073a976e.png
#   inflating: train_images/530d78467615.png
#   inflating: __MACOSX/train_images/._530d78467615.png
#   inflating: train_images/e6a58edc5b42.png
#   inflating: __MACOSX/train_images/._e6a58edc5b42.png
#   inflating: train_images/e2c39ed0c941.png
#   inflating: __MACOSX/train_images/._e2c39ed0c941.png
#   inflating: train_images/af831c158744.png
#   inflating: __MACOSX/train_images/._af831c158744.png
#   inflating: train_images/bb9a3d835a94.png
#   inflating: __MACOSX/train_images/._bb9a3d835a94.png
#   inflating: train_images/0b00f8a77510.png
#   inflating: __MACOSX/train_images/._0b00f8a77510.png
#   inflating: train_images/290ecdba359f.png
#   inflating: __MACOSX/train_images/._290ecdba359f.png
#   inflating: train_images/d332d7b8a26e.png
#   inflating: __MACOSX/train_images/._d332d7b8a26e.png
#   inflating: train_images/8785b71238d8.png
#   inflating: __MACOSX/train_images/._8785b71238d8.png
#   inflating: train_images/4294a14c656a.png
#   inflating: __MACOSX/train_images/._4294a14c656a.png
#   inflating: train_images/b46b09a45f39.png
#   inflating: __MACOSX/train_images/._b46b09a45f39.png
#   inflating: train_images/a9e984b57556.png
#   inflating: __MACOSX/train_images/._a9e984b57556.png
#   inflating: train_images/66a0bf258013.png
#   inflating: __MACOSX/train_images/._66a0bf258013.png
#   inflating: train_images/25b0e72705a8.png
#   inflating: __MACOSX/train_images/._25b0e72705a8.png
#   inflating: train_images/fcc55ae641ae.png
#   inflating: __MACOSX/train_images/._fcc55ae641ae.png
#   inflating: train_images/f7116e7b2f4e.png
#   inflating: __MACOSX/train_images/._f7116e7b2f4e.png
#   inflating: train_images/b9c7c5182075.png
#   inflating: __MACOSX/train_images/._b9c7c5182075.png
#   inflating: train_images/dc0f6e5b489b.png
#   inflating: __MACOSX/train_images/._dc0f6e5b489b.png
#   inflating: train_images/1da4a17c18c9.png
#   inflating: __MACOSX/train_images/._1da4a17c18c9.png
#   inflating: train_images/46f56c38051f.png
#   inflating: __MACOSX/train_images/._46f56c38051f.png
#   inflating: train_images/41960d5f58c2.png
#   inflating: __MACOSX/train_images/._41960d5f58c2.png
#   inflating: train_images/ca9c912ebad7.png
#   inflating: __MACOSX/train_images/._ca9c912ebad7.png
#   inflating: train_images/763ad1236efe.png
#   inflating: __MACOSX/train_images/._763ad1236efe.png
#   inflating: train_images/9910c827e2fe.png
#   inflating: __MACOSX/train_images/._9910c827e2fe.png
#   inflating: train_images/d51e5d7484ea.png
#   inflating: __MACOSX/train_images/._d51e5d7484ea.png
#   inflating: train_images/2776d70724d3.png
#   inflating: __MACOSX/train_images/._2776d70724d3.png
#   inflating: train_images/b13d72ceea26.png
#   inflating: __MACOSX/train_images/._b13d72ceea26.png
#   inflating: train_images/63c3c571b8ee.png
#   inflating: __MACOSX/train_images/._63c3c571b8ee.png
#   inflating: train_images/b200c23b299b.png
#   inflating: __MACOSX/train_images/._b200c23b299b.png
#   inflating: train_images/4fef9ed8a4c5.png
#   inflating: __MACOSX/train_images/._4fef9ed8a4c5.png
#   inflating: train_images/c5a0e84e955d.png
#   inflating: __MACOSX/train_images/._c5a0e84e955d.png
#   inflating: train_images/1bf30c84bbad.png
#   inflating: __MACOSX/train_images/._1bf30c84bbad.png
#   inflating: train_images/49eb73968c44.png
#   inflating: __MACOSX/train_images/._49eb73968c44.png
#   inflating: train_images/a44345b27804.png
#   inflating: __MACOSX/train_images/._a44345b27804.png
#   inflating: train_images/7b8c78b41c0d.png
#   inflating: __MACOSX/train_images/._7b8c78b41c0d.png
#   inflating: train_images/97a5ad7548b7.png
#   inflating: __MACOSX/train_images/._97a5ad7548b7.png
#   inflating: train_images/8a81f62320d6.png
#   inflating: __MACOSX/train_images/._8a81f62320d6.png
#   inflating: train_images/5257cb536da2.png
#   inflating: __MACOSX/train_images/._5257cb536da2.png
#   inflating: train_images/5d9c841eb245.png
#   inflating: __MACOSX/train_images/._5d9c841eb245.png
#   inflating: train_images/51131b48f9d4.png
#   inflating: __MACOSX/train_images/._51131b48f9d4.png
#   inflating: train_images/b8ebedd382de.png
#   inflating: __MACOSX/train_images/._b8ebedd382de.png
#   inflating: train_images/61e301bd3c25.png
#   inflating: __MACOSX/train_images/._61e301bd3c25.png
#   inflating: train_images/8f2996b8d855.png
#   inflating: __MACOSX/train_images/._8f2996b8d855.png
#   inflating: train_images/757572337fd0.png
#   inflating: __MACOSX/train_images/._757572337fd0.png
#   inflating: train_images/2ecbc2e3f239.png
#   inflating: __MACOSX/train_images/._2ecbc2e3f239.png
#   inflating: train_images/01eb826f6467.png
#   inflating: __MACOSX/train_images/._01eb826f6467.png
#   inflating: train_images/a85cda5f725d.png
#   inflating: __MACOSX/train_images/._a85cda5f725d.png
#   inflating: train_images/188a9323be03.png
#   inflating: __MACOSX/train_images/._188a9323be03.png
#   inflating: train_images/f531232ecb55.png
#   inflating: __MACOSX/train_images/._f531232ecb55.png
#   inflating: train_images/d88806d9ece9.png
#   inflating: __MACOSX/train_images/._d88806d9ece9.png
#   inflating: train_images/fce93caa4758.png
#   inflating: __MACOSX/train_images/._fce93caa4758.png
#   inflating: train_images/fca931da5c5e.png
#   inflating: __MACOSX/train_images/._fca931da5c5e.png
#   inflating: train_images/9ce46d400cd6.png
#   inflating: __MACOSX/train_images/._9ce46d400cd6.png
#   inflating: train_images/242fc19be06f.png
#   inflating: __MACOSX/train_images/._242fc19be06f.png
#   inflating: train_images/8c87bd748996.png
#   inflating: __MACOSX/train_images/._8c87bd748996.png
#   inflating: train_images/72d98188648f.png
#   inflating: __MACOSX/train_images/._72d98188648f.png
#   inflating: train_images/7cc4b7aabe04.png
#   inflating: __MACOSX/train_images/._7cc4b7aabe04.png
#   inflating: train_images/b4f41b5bf0ef.png
#   inflating: __MACOSX/train_images/._b4f41b5bf0ef.png
#   inflating: train_images/5b2648ad455e.png
#   inflating: __MACOSX/train_images/._5b2648ad455e.png
#   inflating: train_images/6b128e648646.png
#   inflating: __MACOSX/train_images/._6b128e648646.png
#   inflating: train_images/43ddd0ab0cc4.png
#   inflating: __MACOSX/train_images/._43ddd0ab0cc4.png
#   inflating: train_images/cd45bfa07d41.png
#   inflating: __MACOSX/train_images/._cd45bfa07d41.png
#   inflating: train_images/9ab18a4a957f.png
#   inflating: __MACOSX/train_images/._9ab18a4a957f.png
#   inflating: train_images/0dbe6c26cedc.png
#   inflating: __MACOSX/train_images/._0dbe6c26cedc.png
#   inflating: train_images/912fbe06407e.png
#   inflating: __MACOSX/train_images/._912fbe06407e.png
#   inflating: train_images/3f73c91b7e32.png
#   inflating: __MACOSX/train_images/._3f73c91b7e32.png
#   inflating: train_images/c096131ad065.png
#   inflating: __MACOSX/train_images/._c096131ad065.png
#   inflating: train_images/2eba4279e503.png
#   inflating: __MACOSX/train_images/._2eba4279e503.png
#   inflating: train_images/a8b637abd96b.png
#   inflating: __MACOSX/train_images/._a8b637abd96b.png
#   inflating: train_images/2376e5415458.png
#   inflating: __MACOSX/train_images/._2376e5415458.png
#   inflating: train_images/fbdc796290d4.png
#   inflating: __MACOSX/train_images/._fbdc796290d4.png
#   inflating: train_images/03a7f4a5786f.png
#   inflating: __MACOSX/train_images/._03a7f4a5786f.png
#   inflating: train_images/0cd31078cd08.png
#   inflating: __MACOSX/train_images/._0cd31078cd08.png
#   inflating: train_images/bd06028eb7dd.png
#   inflating: __MACOSX/train_images/._bd06028eb7dd.png
#   inflating: train_images/e4dcca36ceb4.png
#   inflating: __MACOSX/train_images/._e4dcca36ceb4.png
#   inflating: train_images/152db3de8120.png
#   inflating: __MACOSX/train_images/._152db3de8120.png
#   inflating: train_images/941d874c8afb.png
#   inflating: __MACOSX/train_images/._941d874c8afb.png
#   inflating: train_images/10a5026eb8e6.png
#   inflating: __MACOSX/train_images/._10a5026eb8e6.png
#   inflating: train_images/d18b1d8ac4de.png
#   inflating: __MACOSX/train_images/._d18b1d8ac4de.png
#   inflating: train_images/2cef97083e6f.png
#   inflating: __MACOSX/train_images/._2cef97083e6f.png
#   inflating: train_images/b7ce561a7328.png
#   inflating: __MACOSX/train_images/._b7ce561a7328.png
#   inflating: train_images/62e6f814c8f5.png
#   inflating: __MACOSX/train_images/._62e6f814c8f5.png
#   inflating: train_images/de18071c36e6.png
#   inflating: __MACOSX/train_images/._de18071c36e6.png
#   inflating: train_images/2d558de2cabe.png
#   inflating: __MACOSX/train_images/._2d558de2cabe.png
#   inflating: train_images/144b01e7b993.png
#   inflating: __MACOSX/train_images/._144b01e7b993.png
#   inflating: train_images/5efa24b03d5e.png
#   inflating: __MACOSX/train_images/._5efa24b03d5e.png
#   inflating: train_images/fb1b8771c70a.png
#   inflating: __MACOSX/train_images/._fb1b8771c70a.png
#   inflating: train_images/d2cd47ed2c1d.png
#   inflating: __MACOSX/train_images/._d2cd47ed2c1d.png
#   inflating: train_images/21037f5c7790.png
#   inflating: __MACOSX/train_images/._21037f5c7790.png
#   inflating: train_images/e12d41e7b221.png
#   inflating: __MACOSX/train_images/._e12d41e7b221.png
#   inflating: train_images/9d98a0b585f2.png
#   inflating: __MACOSX/train_images/._9d98a0b585f2.png
#   inflating: train_images/e9f3c85a2a02.png
#   inflating: __MACOSX/train_images/._e9f3c85a2a02.png
#   inflating: train_images/da9574d35b82.png
#   inflating: __MACOSX/train_images/._da9574d35b82.png
#   inflating: train_images/b95d4dd8e5e2.png
#   inflating: __MACOSX/train_images/._b95d4dd8e5e2.png
#   inflating: train_images/237aa50edc34.png
#   inflating: __MACOSX/train_images/._237aa50edc34.png
#   inflating: train_images/404ede327e98.png
#   inflating: __MACOSX/train_images/._404ede327e98.png
#   inflating: train_images/4da6e2089d57.png
#   inflating: __MACOSX/train_images/._4da6e2089d57.png
#   inflating: train_images/a6731dd737af.png
#   inflating: __MACOSX/train_images/._a6731dd737af.png
#   inflating: train_images/e34fa07bd64d.png
#   inflating: __MACOSX/train_images/._e34fa07bd64d.png
#   inflating: train_images/09934421c79e.png
#   inflating: __MACOSX/train_images/._09934421c79e.png
#   inflating: train_images/1bb0ddfe753a.png
#   inflating: __MACOSX/train_images/._1bb0ddfe753a.png
#   inflating: train_images/876e1dd12d38.png
#   inflating: __MACOSX/train_images/._876e1dd12d38.png
#   inflating: train_images/7550966ef777.png
#   inflating: __MACOSX/train_images/._7550966ef777.png
#   inflating: train_images/9f1efb799b7b.png
#   inflating: __MACOSX/train_images/._9f1efb799b7b.png
#   inflating: train_images/849a91e9ab28.png
#   inflating: __MACOSX/train_images/._849a91e9ab28.png
#   inflating: train_images/1e8c31e29dd3.png
#   inflating: __MACOSX/train_images/._1e8c31e29dd3.png
#   inflating: train_images/282bc792d23a.png
#   inflating: __MACOSX/train_images/._282bc792d23a.png
#   inflating: train_images/587146a55885.png
#   inflating: __MACOSX/train_images/._587146a55885.png
#   inflating: train_images/eb175669d789.png
#   inflating: __MACOSX/train_images/._eb175669d789.png
#   inflating: train_images/9287e57326d0.png
#   inflating: __MACOSX/train_images/._9287e57326d0.png
#   inflating: train_images/2a47e5b21791.png
#   inflating: __MACOSX/train_images/._2a47e5b21791.png
#   inflating: train_images/e0863b353093.png
#   inflating: __MACOSX/train_images/._e0863b353093.png
#   inflating: train_images/fd4c946c52bf.png
#   inflating: __MACOSX/train_images/._fd4c946c52bf.png
#   inflating: train_images/4ed31cc07366.png
#   inflating: __MACOSX/train_images/._4ed31cc07366.png
#   inflating: train_images/4d17559ac1e2.png
#   inflating: __MACOSX/train_images/._4d17559ac1e2.png
#   inflating: train_images/f61bf44c677c.png
#   inflating: __MACOSX/train_images/._f61bf44c677c.png
#   inflating: train_images/944a233fbf8e.png
#   inflating: __MACOSX/train_images/._944a233fbf8e.png
#   inflating: train_images/84b88e8d3bca.png
#   inflating: __MACOSX/train_images/._84b88e8d3bca.png
#   inflating: train_images/80b5697f2a5e.png
#   inflating: __MACOSX/train_images/._80b5697f2a5e.png
#   inflating: train_images/bb45257258cc.png
#   inflating: __MACOSX/train_images/._bb45257258cc.png
#   inflating: train_images/a664d2055886.png
#   inflating: __MACOSX/train_images/._a664d2055886.png
#   inflating: train_images/cd54d022e37d.png
#   inflating: __MACOSX/train_images/._cd54d022e37d.png
#   inflating: train_images/882a71de424e.png
#   inflating: __MACOSX/train_images/._882a71de424e.png
#   inflating: train_images/6d5a8362dd1e.png
#   inflating: __MACOSX/train_images/._6d5a8362dd1e.png
#   inflating: train_images/b576c5269ad1.png
#   inflating: __MACOSX/train_images/._b576c5269ad1.png
#   inflating: train_images/a654b25124c3.png
#   inflating: __MACOSX/train_images/._a654b25124c3.png
#   inflating: train_images/6ccfdb031184.png
#   inflating: __MACOSX/train_images/._6ccfdb031184.png
#   inflating: train_images/b66f23ffa730.png
#   inflating: __MACOSX/train_images/._b66f23ffa730.png
#   inflating: train_images/80e6e425f966.png
#   inflating: __MACOSX/train_images/._80e6e425f966.png
#   inflating: train_images/3ca637fddd56.png
#   inflating: __MACOSX/train_images/._3ca637fddd56.png
#   inflating: train_images/5eb8fb1aad41.png
#   inflating: __MACOSX/train_images/._5eb8fb1aad41.png
#   inflating: train_images/001639a390f0.png
#   inflating: __MACOSX/train_images/._001639a390f0.png
#   inflating: train_images/fb88783de055.png
#   inflating: __MACOSX/train_images/._fb88783de055.png
#   inflating: train_images/61bbc11fe503.png
#   inflating: __MACOSX/train_images/._61bbc11fe503.png
#   inflating: train_images/cd4e7f9fa1a9.png
#   inflating: __MACOSX/train_images/._cd4e7f9fa1a9.png
#   inflating: train_images/cd8da43e3069.png
#   inflating: __MACOSX/train_images/._cd8da43e3069.png
#   inflating: train_images/ce8d2efd9d4f.png
#   inflating: __MACOSX/train_images/._ce8d2efd9d4f.png
#   inflating: train_images/a32886cb31ab.png
#   inflating: __MACOSX/train_images/._a32886cb31ab.png
#   inflating: train_images/76e5b50f95a7.png
#   inflating: __MACOSX/train_images/._76e5b50f95a7.png
#   inflating: train_images/e93394175a19.png
#   inflating: __MACOSX/train_images/._e93394175a19.png
#   inflating: train_images/44f7f3ef9d50.png
#   inflating: __MACOSX/train_images/._44f7f3ef9d50.png
#   inflating: train_images/4d1e7def7624.png
#   inflating: __MACOSX/train_images/._4d1e7def7624.png
#   inflating: train_images/84a72e15b23c.png
#   inflating: __MACOSX/train_images/._84a72e15b23c.png
#   inflating: train_images/9a78c6a7b1c2.png
#   inflating: __MACOSX/train_images/._9a78c6a7b1c2.png
#   inflating: train_images/f30f203ef51e.png
#   inflating: __MACOSX/train_images/._f30f203ef51e.png
#   inflating: train_images/b0f8613305a3.png
#   inflating: __MACOSX/train_images/._b0f8613305a3.png
#   inflating: train_images/726dff37edc0.png
#   inflating: __MACOSX/train_images/._726dff37edc0.png
#   inflating: train_images/1eee55494271.png
#   inflating: __MACOSX/train_images/._1eee55494271.png
#   inflating: train_images/731b19a460ad.png
#   inflating: __MACOSX/train_images/._731b19a460ad.png
#   inflating: train_images/28f98cfe3858.png
#   inflating: __MACOSX/train_images/._28f98cfe3858.png
#   inflating: train_images/a8c9fcdbc0be.png
#   inflating: __MACOSX/train_images/._a8c9fcdbc0be.png
#   inflating: train_images/e322acd46152.png
#   inflating: __MACOSX/train_images/._e322acd46152.png
#   inflating: train_images/70d0392397de.png
#   inflating: __MACOSX/train_images/._70d0392397de.png
#   inflating: train_images/ad93d88c87ea.png
#   inflating: __MACOSX/train_images/._ad93d88c87ea.png
#   inflating: train_images/6a2642131e4a.png
#   inflating: __MACOSX/train_images/._6a2642131e4a.png
#   inflating: train_images/441117562359.png
#   inflating: __MACOSX/train_images/._441117562359.png
#   inflating: train_images/0c917c372572.png
#   inflating: __MACOSX/train_images/._0c917c372572.png
#   inflating: train_images/0a09aa7356c0.png
#   inflating: __MACOSX/train_images/._0a09aa7356c0.png
#   inflating: train_images/bcb0498ed2c1.png
#   inflating: __MACOSX/train_images/._bcb0498ed2c1.png
#   inflating: train_images/c96f743915b5.png
#   inflating: __MACOSX/train_images/._c96f743915b5.png
#   inflating: train_images/4242c0d87f57.png
#   inflating: __MACOSX/train_images/._4242c0d87f57.png
#   inflating: train_images/ff4955e76894.png
#   inflating: __MACOSX/train_images/._ff4955e76894.png
#   inflating: train_images/2463bb04ebc3.png
#   inflating: __MACOSX/train_images/._2463bb04ebc3.png
#   inflating: train_images/8acdf12f412a.png
#   inflating: __MACOSX/train_images/._8acdf12f412a.png
#   inflating: train_images/a00b4cb250a7.png
#   inflating: __MACOSX/train_images/._a00b4cb250a7.png
#   inflating: train_images/7ccb267fd394.png
#   inflating: __MACOSX/train_images/._7ccb267fd394.png
#   inflating: train_images/81914ceb4e74.png
#   inflating: __MACOSX/train_images/._81914ceb4e74.png
#   inflating: train_images/c52bb7343387.png
#   inflating: __MACOSX/train_images/._c52bb7343387.png
#   inflating: train_images/527bea76116c.png
#   inflating: __MACOSX/train_images/._527bea76116c.png
#   inflating: train_images/18b99159a14f.png
#   inflating: __MACOSX/train_images/._18b99159a14f.png
#   inflating: train_images/248139c423c4.png
#   inflating: __MACOSX/train_images/._248139c423c4.png
#   inflating: train_images/cfdbaef73a8b.png
#   inflating: __MACOSX/train_images/._cfdbaef73a8b.png
#   inflating: train_images/d41b33fcb94f.png
#   inflating: __MACOSX/train_images/._d41b33fcb94f.png
#   inflating: train_images/75238d945315.png
#   inflating: __MACOSX/train_images/._75238d945315.png
#   inflating: train_images/1ab8d3431ffc.png
#   inflating: __MACOSX/train_images/._1ab8d3431ffc.png
#   inflating: train_images/28751f290ba3.png
#   inflating: __MACOSX/train_images/._28751f290ba3.png
#   inflating: train_images/3428230bf1bd.png
#   inflating: __MACOSX/train_images/._3428230bf1bd.png
#   inflating: train_images/4a558a1cd243.png
#   inflating: __MACOSX/train_images/._4a558a1cd243.png
#   inflating: train_images/c704bd669f36.png
#   inflating: __MACOSX/train_images/._c704bd669f36.png
#   inflating: train_images/13073f075a56.png
#   inflating: __MACOSX/train_images/._13073f075a56.png
#   inflating: train_images/50d8a8fb7737.png
#   inflating: __MACOSX/train_images/._50d8a8fb7737.png
#   inflating: train_images/48a45619d1a3.png
#   inflating: __MACOSX/train_images/._48a45619d1a3.png
#   inflating: train_images/bb85097857fa.png
#   inflating: __MACOSX/train_images/._bb85097857fa.png
#   inflating: train_images/e96099b961b4.png
#   inflating: __MACOSX/train_images/._e96099b961b4.png
#   inflating: train_images/e52ed5c29c5e.png
#   inflating: __MACOSX/train_images/._e52ed5c29c5e.png
#   inflating: train_images/9e2058917304.png
#   inflating: __MACOSX/train_images/._9e2058917304.png
#   inflating: train_images/8cb6b0efaaac.png
#   inflating: __MACOSX/train_images/._8cb6b0efaaac.png
#   inflating: train_images/5d5b5da5f939.png
#   inflating: __MACOSX/train_images/._5d5b5da5f939.png
#   inflating: train_images/83d81ba5959c.png
#   inflating: __MACOSX/train_images/._83d81ba5959c.png
#   inflating: train_images/4cddfc22b0ad.png
#   inflating: __MACOSX/train_images/._4cddfc22b0ad.png
#   inflating: train_images/56e56aa08362.png
#   inflating: __MACOSX/train_images/._56e56aa08362.png
#   inflating: train_images/2c9dfc270f1b.png
#   inflating: __MACOSX/train_images/._2c9dfc270f1b.png
#   inflating: train_images/43e9c66eb0f3.png
#   inflating: __MACOSX/train_images/._43e9c66eb0f3.png
#   inflating: train_images/a1faeb4d5f10.png
#   inflating: __MACOSX/train_images/._a1faeb4d5f10.png
#   inflating: train_images/68332fdcaa70.png
#   inflating: __MACOSX/train_images/._68332fdcaa70.png
#   inflating: train_images/aeed1f251ceb.png
#   inflating: __MACOSX/train_images/._aeed1f251ceb.png
#   inflating: train_images/0953c0ac1735.png
#   inflating: __MACOSX/train_images/._0953c0ac1735.png
#   inflating: train_images/7247a2c97f71.png
#   inflating: __MACOSX/train_images/._7247a2c97f71.png
#   inflating: train_images/436fa3fd145a.png
#   inflating: __MACOSX/train_images/._436fa3fd145a.png
#   inflating: train_images/226c6ceb9185.png
#   inflating: __MACOSX/train_images/._226c6ceb9185.png
#   inflating: train_images/4df6a81b476e.png
#   inflating: __MACOSX/train_images/._4df6a81b476e.png
#   inflating: train_images/85fce24084da.png
#   inflating: __MACOSX/train_images/._85fce24084da.png
#   inflating: train_images/1a0dbc6c0cda.png
#   inflating: __MACOSX/train_images/._1a0dbc6c0cda.png
#   inflating: train_images/abbb8791785e.png
#   inflating: __MACOSX/train_images/._abbb8791785e.png
#   inflating: train_images/1fb455685328.png
#   inflating: __MACOSX/train_images/._1fb455685328.png
#   inflating: train_images/12b57dac703e.png
#   inflating: __MACOSX/train_images/._12b57dac703e.png
#   inflating: train_images/f8f5942b690e.png
#   inflating: __MACOSX/train_images/._f8f5942b690e.png
#   inflating: train_images/27e4c800a449.png
#   inflating: __MACOSX/train_images/._27e4c800a449.png
#   inflating: train_images/bcd503c726ba.png
#   inflating: __MACOSX/train_images/._bcd503c726ba.png
#   inflating: train_images/384db24ebbd7.png
#   inflating: __MACOSX/train_images/._384db24ebbd7.png
#   inflating: train_images/c31651ea04c6.png
#   inflating: __MACOSX/train_images/._c31651ea04c6.png
#   inflating: train_images/6ba5ed791444.png
#   inflating: __MACOSX/train_images/._6ba5ed791444.png
#   inflating: train_images/b6fd109b1bc9.png
#   inflating: __MACOSX/train_images/._b6fd109b1bc9.png
#   inflating: train_images/df4aec4a0eaf.png
#   inflating: __MACOSX/train_images/._df4aec4a0eaf.png
#   inflating: train_images/db3cd58aa315.png
#   inflating: __MACOSX/train_images/._db3cd58aa315.png
#   inflating: train_images/a0267206d51e.png
#   inflating: __MACOSX/train_images/._a0267206d51e.png
#   inflating: train_images/7d0a871c45db.png
#   inflating: __MACOSX/train_images/._7d0a871c45db.png
#   inflating: train_images/b8ac328009e0.png
#   inflating: __MACOSX/train_images/._b8ac328009e0.png
#   inflating: train_images/db49cdf1ea64.png
#   inflating: __MACOSX/train_images/._db49cdf1ea64.png
#   inflating: train_images/d9a475dfe59a.png
#   inflating: __MACOSX/train_images/._d9a475dfe59a.png
#   inflating: train_images/eaa0dfbd5024.png
#   inflating: __MACOSX/train_images/._eaa0dfbd5024.png
#   inflating: train_images/3b2b91590590.png
#   inflating: __MACOSX/train_images/._3b2b91590590.png
#   inflating: train_images/aafe980edd0c.png
#   inflating: __MACOSX/train_images/._aafe980edd0c.png
#   inflating: train_images/f920ccd926db.png
#   inflating: __MACOSX/train_images/._f920ccd926db.png
#   inflating: train_images/184a185e7447.png
#   inflating: __MACOSX/train_images/._184a185e7447.png
#   inflating: train_images/51405d042000.png
#   inflating: __MACOSX/train_images/._51405d042000.png
#   inflating: train_images/93be637084a2.png
#   inflating: __MACOSX/train_images/._93be637084a2.png
#   inflating: train_images/49419f8d5cb4.png
#   inflating: __MACOSX/train_images/._49419f8d5cb4.png
#   inflating: train_images/6165081b9021.png
#   inflating: __MACOSX/train_images/._6165081b9021.png
#   inflating: train_images/b574d229ec4c.png
#   inflating: __MACOSX/train_images/._b574d229ec4c.png
#   inflating: train_images/a7ec056502e7.png
#   inflating: __MACOSX/train_images/._a7ec056502e7.png
#   inflating: train_images/d7078e8b0349.png
#   inflating: __MACOSX/train_images/._d7078e8b0349.png
#   inflating: train_images/7b691d9ced34.png
#   inflating: __MACOSX/train_images/._7b691d9ced34.png
#   inflating: train_images/3fd45879afe6.png
#   inflating: __MACOSX/train_images/._3fd45879afe6.png
#   inflating: train_images/239f2c348ea4.png
#   inflating: __MACOSX/train_images/._239f2c348ea4.png
#   inflating: train_images/b35cad8fe2d7.png
#   inflating: __MACOSX/train_images/._b35cad8fe2d7.png
#   inflating: train_images/7d261f986bef.png
#   inflating: __MACOSX/train_images/._7d261f986bef.png
#   inflating: train_images/4ec7796df40e.png
#   inflating: __MACOSX/train_images/._4ec7796df40e.png
#   inflating: train_images/b0619ca93a5f.png
#   inflating: __MACOSX/train_images/._b0619ca93a5f.png
#   inflating: train_images/87774aafe068.png
#   inflating: __MACOSX/train_images/._87774aafe068.png
#   inflating: train_images/7356dd08b0ae.png
#   inflating: __MACOSX/train_images/._7356dd08b0ae.png
#   inflating: train_images/936299166bea.png
#   inflating: __MACOSX/train_images/._936299166bea.png
#   inflating: train_images/ef7eb85b75fc.png
#   inflating: __MACOSX/train_images/._ef7eb85b75fc.png
#   inflating: train_images/ac5b5dddf91b.png
#   inflating: __MACOSX/train_images/._ac5b5dddf91b.png
#   inflating: train_images/499c8df39222.png
#   inflating: __MACOSX/train_images/._499c8df39222.png
#   inflating: train_images/a0adbe677508.png
#   inflating: __MACOSX/train_images/._a0adbe677508.png
#   inflating: train_images/38055d8b9f08.png
#   inflating: __MACOSX/train_images/._38055d8b9f08.png
#   inflating: train_images/6f923b60934b.png
#   inflating: __MACOSX/train_images/._6f923b60934b.png
#   inflating: train_images/a182b5b191de.png
#   inflating: __MACOSX/train_images/._a182b5b191de.png
#   inflating: train_images/ef26625121b3.png
#   inflating: __MACOSX/train_images/._ef26625121b3.png
#   inflating: train_images/57f5ad4b5b29.png
#   inflating: __MACOSX/train_images/._57f5ad4b5b29.png
#   inflating: train_images/13063d1bc4ea.png
#   inflating: __MACOSX/train_images/._13063d1bc4ea.png
#   inflating: train_images/3325b1fe55d2.png
#   inflating: __MACOSX/train_images/._3325b1fe55d2.png
#   inflating: train_images/20c883d3bd38.png
#   inflating: __MACOSX/train_images/._20c883d3bd38.png
#   inflating: train_images/89b044cbaf85.png
#   inflating: __MACOSX/train_images/._89b044cbaf85.png
#   inflating: train_images/fe3b0e50be78.png
#   inflating: __MACOSX/train_images/._fe3b0e50be78.png
#   inflating: train_images/17eb5d4ad740.png
#   inflating: __MACOSX/train_images/._17eb5d4ad740.png
#   inflating: train_images/521d3e264d71.png
#   inflating: __MACOSX/train_images/._521d3e264d71.png
#   inflating: train_images/7270367410a1.png
#   inflating: __MACOSX/train_images/._7270367410a1.png
#   inflating: train_images/0d0b8fc9ab5c.png
#   inflating: __MACOSX/train_images/._0d0b8fc9ab5c.png
#   inflating: train_images/85cc6d636898.png
#   inflating: __MACOSX/train_images/._85cc6d636898.png
#   inflating: train_images/c613db1cab27.png
#   inflating: __MACOSX/train_images/._c613db1cab27.png
#   inflating: train_images/388f12e8df0b.png
#   inflating: __MACOSX/train_images/._388f12e8df0b.png
#   inflating: train_images/fb767cea406c.png
#   inflating: __MACOSX/train_images/._fb767cea406c.png
#   inflating: train_images/97a235367f9d.png
#   inflating: __MACOSX/train_images/._97a235367f9d.png
#   inflating: train_images/7102f29e052e.png
#   inflating: __MACOSX/train_images/._7102f29e052e.png
#   inflating: train_images/8dc22e65c06f.png
#   inflating: __MACOSX/train_images/._8dc22e65c06f.png
#   inflating: train_images/03b373718013.png
#   inflating: __MACOSX/train_images/._03b373718013.png
#   inflating: train_images/80ed04a84a16.png
#   inflating: __MACOSX/train_images/._80ed04a84a16.png
#   inflating: train_images/e12f9f19d1be.png
#   inflating: __MACOSX/train_images/._e12f9f19d1be.png
#   inflating: train_images/6fe4751a3b42.png
#   inflating: __MACOSX/train_images/._6fe4751a3b42.png
#   inflating: train_images/f1d719c97838.png
#   inflating: __MACOSX/train_images/._f1d719c97838.png
#   inflating: train_images/e4d3d437b0a8.png
#   inflating: __MACOSX/train_images/._e4d3d437b0a8.png
#   inflating: train_images/76e6a9238570.png
#   inflating: __MACOSX/train_images/._76e6a9238570.png
#   inflating: train_images/23fca0693e2a.png
#   inflating: __MACOSX/train_images/._23fca0693e2a.png
#   inflating: train_images/3f47f83217b5.png
#   inflating: __MACOSX/train_images/._3f47f83217b5.png
#   inflating: train_images/2f81ee5f2926.png
#   inflating: __MACOSX/train_images/._2f81ee5f2926.png
#   inflating: train_images/eabf421f94d0.png
#   inflating: __MACOSX/train_images/._eabf421f94d0.png
#   inflating: train_images/194814669fee.png
#   inflating: __MACOSX/train_images/._194814669fee.png
#   inflating: train_images/6af071b0ac6e.png
#   inflating: __MACOSX/train_images/._6af071b0ac6e.png
#   inflating: train_images/a8c54e2a4b79.png
#   inflating: __MACOSX/train_images/._a8c54e2a4b79.png
#   inflating: train_images/5ed6dc419e4d.png
#   inflating: __MACOSX/train_images/._5ed6dc419e4d.png
#   inflating: train_images/4c60f6fcea75.png
# ...
#   inflating: __MACOSX/train_images/._a12ca80bb8c7.png
#   inflating: train_images/c0202976c670.png
#   inflating: __MACOSX/train_images/._c0202976c670.png
#   inflating: train_images/26cd40b57ad1.png
#   inflating: __MACOSX/train_images/._26cd40b57ad1.png
#   inflating: train_images/b553e7909535.png
#   inflating: __MACOSX/train_images/._b553e7909535.png
#   inflating: train_images/d66ccb75ada1.png
#   inflating: __MACOSX/train_images/._d66ccb75ada1.png
#   inflating: train_images/bda7ff3b1562.png
#   inflating: __MACOSX/train_images/._bda7ff3b1562.png
#   inflating: train_images/0cecc2864b7f.png
#   inflating: __MACOSX/train_images/._0cecc2864b7f.png
#   inflating: train_images/cb39761f0712.png
#   inflating: __MACOSX/train_images/._cb39761f0712.png
#   inflating: train_images/9ac2e3e9fca5.png
#   inflating: __MACOSX/train_images/._9ac2e3e9fca5.png
#   inflating: train_images/318eb706a134.png
#   inflating: __MACOSX/train_images/._318eb706a134.png
#   inflating: train_images/aa6242f9e08c.png
#   inflating: __MACOSX/train_images/._aa6242f9e08c.png
#   inflating: train_images/d868acdccb5b.png
#   inflating: __MACOSX/train_images/._d868acdccb5b.png
#   inflating: train_images/196e6a186452.png
#   inflating: __MACOSX/train_images/._196e6a186452.png
#   inflating: train_images/e85d410d6836.png
#   inflating: __MACOSX/train_images/._e85d410d6836.png
#   inflating: train_images/ed2ef440d22c.png
#   inflating: __MACOSX/train_images/._ed2ef440d22c.png
#   inflating: train_images/a4d4b69f7404.png
#   inflating: __MACOSX/train_images/._a4d4b69f7404.png
#   inflating: train_images/750e0168399d.png
#   inflating: __MACOSX/train_images/._750e0168399d.png
#   inflating: train_images/2a3a1ed1c285.png
#   inflating: __MACOSX/train_images/._2a3a1ed1c285.png
#   inflating: train_images/57f933d3d7c7.png
#   inflating: __MACOSX/train_images/._57f933d3d7c7.png
#   inflating: train_images/2fe06bedb2c4.png
#   inflating: __MACOSX/train_images/._2fe06bedb2c4.png
#   inflating: train_images/180afe1d5ef7.png
#   inflating: __MACOSX/train_images/._180afe1d5ef7.png
#   inflating: train_images/84b79243e430.png
#   inflating: __MACOSX/train_images/._84b79243e430.png
#   inflating: train_images/8bf05909e1e1.png
#   inflating: __MACOSX/train_images/._8bf05909e1e1.png
#   inflating: train_images/33b91def2035.png
#   inflating: __MACOSX/train_images/._33b91def2035.png
#   inflating: train_images/032d7b0b4bf6.png
#   inflating: __MACOSX/train_images/._032d7b0b4bf6.png
#   inflating: train_images/5e505e25cd3e.png
#   inflating: __MACOSX/train_images/._5e505e25cd3e.png
#   inflating: train_images/7a9f45fdf29b.png
#   inflating: __MACOSX/train_images/._7a9f45fdf29b.png
#   inflating: train_images/9eaac43744f5.png
#   inflating: __MACOSX/train_images/._9eaac43744f5.png
#   inflating: train_images/e246cd89e1cc.png
#   inflating: __MACOSX/train_images/._e246cd89e1cc.png
#   inflating: train_images/da1fb35f5df9.png
#   inflating: __MACOSX/train_images/._da1fb35f5df9.png
#   inflating: train_images/369229040a34.png
#   inflating: __MACOSX/train_images/._369229040a34.png
#   inflating: train_images/aba3063c5413.png
#   inflating: __MACOSX/train_images/._aba3063c5413.png
#   inflating: train_images/6c30dd481717.png
#   inflating: __MACOSX/train_images/._6c30dd481717.png
#   inflating: train_images/a2b995b81692.png
#   inflating: __MACOSX/train_images/._a2b995b81692.png
#   inflating: train_images/9f1b14dfa14c.png
#   inflating: __MACOSX/train_images/._9f1b14dfa14c.png
#   inflating: train_images/51da6aebba8f.png
#   inflating: __MACOSX/train_images/._51da6aebba8f.png
#   inflating: train_images/099021fac3c9.png
#   inflating: __MACOSX/train_images/._099021fac3c9.png
#   inflating: train_images/f48241b0c995.png
#   inflating: __MACOSX/train_images/._f48241b0c995.png
#   inflating: train_images/8906c9ed54a2.png
#   inflating: __MACOSX/train_images/._8906c9ed54a2.png
#   inflating: train_images/f092febbf5c0.png
#   inflating: __MACOSX/train_images/._f092febbf5c0.png
#   inflating: train_images/0d744aed4d64.png
#   inflating: __MACOSX/train_images/._0d744aed4d64.png
#   inflating: train_images/e03a74e7d74f.png
#   inflating: __MACOSX/train_images/._e03a74e7d74f.png
#   inflating: train_images/8aa3c4681542.png
#   inflating: __MACOSX/train_images/._8aa3c4681542.png
#   inflating: train_images/6fb656d506b2.png
#   inflating: __MACOSX/train_images/._6fb656d506b2.png
#   inflating: train_images/bb2f89488ecd.png
#   inflating: __MACOSX/train_images/._bb2f89488ecd.png
#   inflating: train_images/da8900ac7f29.png
#   inflating: __MACOSX/train_images/._da8900ac7f29.png
#   inflating: train_images/fb88d23fc5fe.png
#   inflating: __MACOSX/train_images/._fb88d23fc5fe.png
#   inflating: train_images/6c6505a0c637.png
#   inflating: __MACOSX/train_images/._6c6505a0c637.png
#   inflating: train_images/8241e43408a8.png
#   inflating: __MACOSX/train_images/._8241e43408a8.png
#   inflating: train_images/35ac70c0d08f.png
#   inflating: __MACOSX/train_images/._35ac70c0d08f.png
#   inflating: train_images/d2d523e9f669.png
#   inflating: __MACOSX/train_images/._d2d523e9f669.png
#   inflating: train_images/4c78d9d18da9.png
#   inflating: __MACOSX/train_images/._4c78d9d18da9.png
#   inflating: train_images/eebd1e195952.png
#   inflating: __MACOSX/train_images/._eebd1e195952.png
#   inflating: train_images/012a242ac6ff.png
#   inflating: __MACOSX/train_images/._012a242ac6ff.png
#   inflating: train_images/22a6da005395.png
#   inflating: __MACOSX/train_images/._22a6da005395.png
#   inflating: train_images/7d37a2939f12.png
#   inflating: __MACOSX/train_images/._7d37a2939f12.png
#   inflating: train_images/e33766353db2.png
#   inflating: __MACOSX/train_images/._e33766353db2.png
#   inflating: train_images/25002fe43f92.png
#   inflating: __MACOSX/train_images/._25002fe43f92.png
#   inflating: train_images/08c60c647673.png
#   inflating: __MACOSX/train_images/._08c60c647673.png
#   inflating: train_images/1002b5151b8e.png
#   inflating: __MACOSX/train_images/._1002b5151b8e.png
#   inflating: train_images/606daaf0bfc7.png
#   inflating: __MACOSX/train_images/._606daaf0bfc7.png
#   inflating: train_images/2665f72e2dd3.png
#   inflating: __MACOSX/train_images/._2665f72e2dd3.png
#   inflating: train_images/3ca12e02dd4e.png
#   inflating: __MACOSX/train_images/._3ca12e02dd4e.png
#   inflating: train_images/873dcc0b468f.png
#   inflating: __MACOSX/train_images/._873dcc0b468f.png
#   inflating: train_images/c64c0966b4cf.png
#   inflating: __MACOSX/train_images/._c64c0966b4cf.png
#   inflating: train_images/901a3552fe26.png
#   inflating: __MACOSX/train_images/._901a3552fe26.png
#   inflating: train_images/51cd8d2057fa.png
#   inflating: __MACOSX/train_images/._51cd8d2057fa.png
#   inflating: train_images/d95959798b57.png
#   inflating: __MACOSX/train_images/._d95959798b57.png
#   inflating: train_images/f1a761c68559.png
#   inflating: __MACOSX/train_images/._f1a761c68559.png
#   inflating: train_images/adb56cecafaf.png
#   inflating: __MACOSX/train_images/._adb56cecafaf.png
#   inflating: train_images/07596907347b.png
#   inflating: __MACOSX/train_images/._07596907347b.png
#   inflating: train_images/1df0a4c23c95.png
#   inflating: __MACOSX/train_images/._1df0a4c23c95.png
#   inflating: train_images/44a4d04162cc.png
#   inflating: __MACOSX/train_images/._44a4d04162cc.png
#   inflating: train_images/e4210e7fe587.png
#   inflating: __MACOSX/train_images/._e4210e7fe587.png
#   inflating: train_images/5327f88a1919.png
#   inflating: __MACOSX/train_images/._5327f88a1919.png
#   inflating: train_images/005b95c28852.png
#   inflating: __MACOSX/train_images/._005b95c28852.png
#   inflating: train_images/810ed108f5b7.png
#   inflating: __MACOSX/train_images/._810ed108f5b7.png
#   inflating: train_images/f2d2a0c92034.png
#   inflating: __MACOSX/train_images/._f2d2a0c92034.png
#   inflating: train_images/475300735b7f.png
#   inflating: __MACOSX/train_images/._475300735b7f.png
#   inflating: train_images/de778495a1cd.png
#   inflating: __MACOSX/train_images/._de778495a1cd.png
#   inflating: train_images/639915f58a2f.png
#   inflating: __MACOSX/train_images/._639915f58a2f.png
#   inflating: train_images/a45c30da0c72.png
#   inflating: __MACOSX/train_images/._a45c30da0c72.png
#   inflating: train_images/de50dfa745f8.png
#   inflating: __MACOSX/train_images/._de50dfa745f8.png
#   inflating: train_images/ef8c39eb9157.png
#   inflating: __MACOSX/train_images/._ef8c39eb9157.png
#   inflating: train_images/24f271c87e73.png
#   inflating: __MACOSX/train_images/._24f271c87e73.png
#   inflating: train_images/9ed6c2b25767.png
#   inflating: __MACOSX/train_images/._9ed6c2b25767.png
#   inflating: train_images/e4c799738a19.png
#   inflating: __MACOSX/train_images/._e4c799738a19.png
#   inflating: train_images/7ad0c4975890.png
#   inflating: __MACOSX/train_images/._7ad0c4975890.png
#   inflating: train_images/ccea49708830.png
#   inflating: __MACOSX/train_images/._ccea49708830.png
#   inflating: train_images/ee74c3b177e0.png
#   inflating: __MACOSX/train_images/._ee74c3b177e0.png
#   inflating: train_images/578109578b46.png
#   inflating: __MACOSX/train_images/._578109578b46.png
#   inflating: train_images/65e120143825.png
#   inflating: __MACOSX/train_images/._65e120143825.png
#   inflating: train_images/e66ad813a508.png
#   inflating: __MACOSX/train_images/._e66ad813a508.png
#   inflating: train_images/a8652b2de23f.png
#   inflating: __MACOSX/train_images/._a8652b2de23f.png
#   inflating: train_images/3de8ad4151e1.png
#   inflating: __MACOSX/train_images/._3de8ad4151e1.png
#   inflating: train_images/d1b279cc02ae.png
#   inflating: __MACOSX/train_images/._d1b279cc02ae.png
#   inflating: train_images/d2fb715b0c41.png
#   inflating: __MACOSX/train_images/._d2fb715b0c41.png
#   inflating: train_images/b3a994760537.png
#   inflating: __MACOSX/train_images/._b3a994760537.png
#   inflating: train_images/27933cdbe0cc.png
#   inflating: __MACOSX/train_images/._27933cdbe0cc.png
#   inflating: train_images/937bc1b924b1.png
#   inflating: __MACOSX/train_images/._937bc1b924b1.png
#   inflating: train_images/4145dcb25053.png
#   inflating: __MACOSX/train_images/._4145dcb25053.png
#   inflating: train_images/a4d41c495666.png
#   inflating: __MACOSX/train_images/._a4d41c495666.png
#   inflating: train_images/1f31701dd61b.png
#   inflating: __MACOSX/train_images/._1f31701dd61b.png
#   inflating: train_images/a76b69e443ce.png
#   inflating: __MACOSX/train_images/._a76b69e443ce.png
#   inflating: train_images/876deb29f000.png
#   inflating: __MACOSX/train_images/._876deb29f000.png
#   inflating: train_images/27fca9f12b3c.png
#   inflating: __MACOSX/train_images/._27fca9f12b3c.png
#   inflating: train_images/b0b3b16fc305.png
#   inflating: __MACOSX/train_images/._b0b3b16fc305.png
#   inflating: train_images/5d024177e214.png
#   inflating: __MACOSX/train_images/._5d024177e214.png
#   inflating: train_images/f3a268d2726d.png
#   inflating: __MACOSX/train_images/._f3a268d2726d.png
#   inflating: train_images/58eb3809f456.png
#   inflating: __MACOSX/train_images/._58eb3809f456.png
#   inflating: train_images/541db13517e2.png
#   inflating: __MACOSX/train_images/._541db13517e2.png
#   inflating: train_images/87d46b1cc4e9.png
#   inflating: __MACOSX/train_images/._87d46b1cc4e9.png
#   inflating: train_images/bb5083fae98f.png
#   inflating: __MACOSX/train_images/._bb5083fae98f.png
#   inflating: train_images/4dbce359d0e1.png
#   inflating: __MACOSX/train_images/._4dbce359d0e1.png
#   inflating: train_images/c7d0deb71576.png
#   inflating: __MACOSX/train_images/._c7d0deb71576.png
#   inflating: train_images/73881f55a3ec.png
#   inflating: __MACOSX/train_images/._73881f55a3ec.png
#   inflating: train_images/45369821d6a3.png
#   inflating: __MACOSX/train_images/._45369821d6a3.png
#   inflating: train_images/218c822a3dd9.png
#   inflating: __MACOSX/train_images/._218c822a3dd9.png
#   inflating: train_images/f35d80bb1a22.png
#   inflating: __MACOSX/train_images/._f35d80bb1a22.png
#   inflating: train_images/cae51154e1ce.png
#   inflating: __MACOSX/train_images/._cae51154e1ce.png
#   inflating: train_images/c0968d41eb93.png
#   inflating: __MACOSX/train_images/._c0968d41eb93.png
#   inflating: train_images/aafb0c944f14.png
#   inflating: __MACOSX/train_images/._aafb0c944f14.png
#   inflating: train_images/94111ed3d276.png
#   inflating: __MACOSX/train_images/._94111ed3d276.png
#   inflating: train_images/9f5a8665cf2e.png
#   inflating: __MACOSX/train_images/._9f5a8665cf2e.png
#   inflating: train_images/26453eb7e989.png
#   inflating: __MACOSX/train_images/._26453eb7e989.png
#   inflating: train_images/555d0bef3c5b.png
#   inflating: __MACOSX/train_images/._555d0bef3c5b.png
#   inflating: train_images/a8aed92940fb.png
#   inflating: __MACOSX/train_images/._a8aed92940fb.png
#   inflating: train_images/2a7373eeb352.png
#   inflating: __MACOSX/train_images/._2a7373eeb352.png
#   inflating: train_images/3a4cfea0a766.png
#   inflating: __MACOSX/train_images/._3a4cfea0a766.png
#   inflating: train_images/4ccee4db09b6.png
#   inflating: __MACOSX/train_images/._4ccee4db09b6.png
#   inflating: train_images/51e656e5a541.png
#   inflating: __MACOSX/train_images/._51e656e5a541.png
#   inflating: train_images/81b0a2651c45.png
#   inflating: __MACOSX/train_images/._81b0a2651c45.png
#   inflating: train_images/4cae247d9909.png
#   inflating: __MACOSX/train_images/._4cae247d9909.png
#   inflating: train_images/b89938407ee6.png
#   inflating: __MACOSX/train_images/._b89938407ee6.png
#   inflating: train_images/b842b43cb7fb.png
#   inflating: __MACOSX/train_images/._b842b43cb7fb.png
#   inflating: train_images/8a01daa423f7.png
#   inflating: __MACOSX/train_images/._8a01daa423f7.png
#   inflating: train_images/81371b0c01ad.png
#   inflating: __MACOSX/train_images/._81371b0c01ad.png
#   inflating: train_images/48c72dec46e5.png
#   inflating: __MACOSX/train_images/._48c72dec46e5.png
#   inflating: train_images/cd48cfab4e44.png
#   inflating: __MACOSX/train_images/._cd48cfab4e44.png
#   inflating: train_images/e3cd96cb094c.png
#   inflating: __MACOSX/train_images/._e3cd96cb094c.png
#   inflating: train_images/f762c272c522.png
#   inflating: __MACOSX/train_images/._f762c272c522.png
#   inflating: train_images/913b1890ed1e.png
#   inflating: __MACOSX/train_images/._913b1890ed1e.png
#   inflating: train_images/6089fa333013.png
#   inflating: __MACOSX/train_images/._6089fa333013.png
#   inflating: train_images/5cc6dea19614.png
#   inflating: __MACOSX/train_images/._5cc6dea19614.png
#   inflating: train_images/349f3c0ac83e.png
#   inflating: __MACOSX/train_images/._349f3c0ac83e.png
#   inflating: train_images/6fe67fd7f5d1.png
#   inflating: __MACOSX/train_images/._6fe67fd7f5d1.png
#   inflating: train_images/164cd5a3a6cd.png
#   inflating: __MACOSX/train_images/._164cd5a3a6cd.png
#   inflating: train_images/6b30767595d8.png
#   inflating: __MACOSX/train_images/._6b30767595d8.png
#   inflating: train_images/2b4c7b5f1f1e.png
#   inflating: __MACOSX/train_images/._2b4c7b5f1f1e.png
#   inflating: train_images/ab78a66dee6a.png
#   inflating: __MACOSX/train_images/._ab78a66dee6a.png
#   inflating: train_images/c9d42d7534e0.png
#   inflating: __MACOSX/train_images/._c9d42d7534e0.png
#   inflating: train_images/79ade634c633.png
#   inflating: __MACOSX/train_images/._79ade634c633.png
#   inflating: train_images/0eff8eacb2f7.png
#   inflating: __MACOSX/train_images/._0eff8eacb2f7.png
#   inflating: train_images/2241b7e90782.png
#   inflating: __MACOSX/train_images/._2241b7e90782.png
#   inflating: train_images/58529a8638d0.png
#   inflating: __MACOSX/train_images/._58529a8638d0.png
#   inflating: train_images/172df1330a60.png
#   inflating: __MACOSX/train_images/._172df1330a60.png
#   inflating: train_images/7a77c3eb468c.png
#   inflating: __MACOSX/train_images/._7a77c3eb468c.png
#   inflating: train_images/4e82c3c8d31f.png
#   inflating: __MACOSX/train_images/._4e82c3c8d31f.png
#   inflating: train.csv
#   inflating: __MACOSX/._train.csv

# %%
dataset_path = "."
train_images = dataset_path + "/train_images"
train_csv = dataset_path + "/train.csv"

print("Train images:", train_images)
print("Train CSV:", train_csv)
# Out:
# Train images: ./train_images
# Train CSV: ./train.csv

# %% [markdown]
# Perform Imports and Set device to GPU

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import pandas as pd
import os
from PIL import Image
from torchvision import models, transforms
from sklearn.model_selection import StratifiedShuffleSplit, StratifiedKFold
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import cohen_kappa_score
from tqdm import tqdm
from sklearn.utils.class_weight import compute_class_weight
from torch.cuda.amp import autocast, GradScaler

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

torch.backends.cudnn.benchmark = True  # optimize conv kernels for speed
# Out:
# Using device: cuda

# %% [markdown]
# Dataset and Model Definitions

# %%
class RetinopathyDataset(Dataset):
    def __init__(self, csv_file, img_dir, transform=None):
        self.df = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_name = row["id_code"] + ".png"  # APTOS image format
        img_path = os.path.join(self.img_dir, img_name)

        img = Image.open(img_path).convert("RGB")

        if self.transform:
            img = self.transform(img)

        label = int(row["diagnosis"])
        return img, label

# %%
# Change this to another model

def get_inception_v3_model(num_classes):
    model = models.inception_v3(weights=None, aux_logits=True)  # skip download
    model.load_state_dict(torch.load("/content/inception_v3_base.pth"))
    model.fc = nn.Linear(2048, num_classes)
    model.AuxLogits.fc = nn.Linear(768, num_classes)
    return model.to(device)

# %%
class OrdinalInceptionV3(nn.Module):
    def __init__(self):
        super().__init__()
        base = models.inception_v3(weights="IMAGENET1K_V1", aux_logits=True)

        # Make backbone return 2048 features, NOT logits
        base.aux_logits = False
        base.fc = nn.Identity()

        self.backbone = base
        self.ordinal_layer = nn.Linear(2048, 4)

    def forward(self, x):
        # ALWAYS gives shape (B, 2048)
        feats = self.backbone(x)
        logits = self.ordinal_layer(feats)
        return logits

# %%
def ordinal_encode(labels, num_classes=5):
    """
    labels: (B,) tensor of 0..4
    returns (B, 4) ordinal labels
    """
    batch_size = labels.size(0)
    thresholds = torch.arange(num_classes-1).to(labels.device)
    return (labels.unsqueeze(1) > thresholds).float()

def ordinal_decode(logits):
    probs = torch.sigmoid(logits)
    return torch.sum(probs > 0.5, dim=1)

# %%
from sklearn.metrics import cohen_kappa_score

def train_one_fold_ordinal(model, train_loader, val_loader, fold, epochs=3, lr=1e-4):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler()

    criterion = nn.BCEWithLogitsLoss()

    best_qwk = -1
    best_state = None

    for epoch in range(epochs):
        model.train()
        total_loss = 0.0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            # convert numeric label → 4-dim ordinal label
            ord_labels = ordinal_encode(labels)

            optimizer.zero_grad()

            # ----- AMP forward -----
            with autocast():
                logits = model(images)
                loss = criterion(logits, ord_labels)

            # ----- AMP backward -----
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()

        # ----- Validation -----
        model.eval()
        val_preds = []
        val_true = []

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)

                logits = model(images)
                pred_classes = ordinal_decode(logits)

                val_preds.extend(pred_classes.cpu().numpy())
                val_true.extend(labels.cpu().numpy())

        qwk = cohen_kappa_score(val_true, val_preds, weights='quadratic')
        print(f"Fold {fold+1} Epoch {epoch+1}: Loss={total_loss/len(train_loader):.4f} | QWK={qwk:.4f}")

        if qwk > best_qwk:
            best_qwk = qwk
            best_state = model.state_dict()

    torch.save(best_state, f"best_modelfold{fold+1}.pt")
    return best_qwk

# %% [markdown]
# Helper Functions

# %%
def qwk_score(y_true, y_pred):
    return cohen_kappa_score(y_true, y_pred, weights="quadratic")

def get_loaders(fold):
    train_dataset = RetinopathyDataset(f"fold_{fold + 1}_train.csv", train_images, train_transform)
    val_dataset   = RetinopathyDataset(f"fold_{fold + 1}_val.csv",   train_images, val_transform)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)

    return train_loader, val_loader

# %% [markdown]
# Training Function

# %%
#change this according to the model

def train_one_fold_i(model, train_loader, val_loader, fold, epochs=3, lr=1e-4):
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scaler = GradScaler()   # AMP scaler

    # Compute class weights for this fold
    all_labels = np.array([y for _, y in train_loader.dataset])
    classes = np.arange(5)
    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=all_labels
    )
    class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights)

    best_qwk = -1
    best_state = None

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            # ---- AMP forward pass ----
            with autocast():
                outputs = model(images)
                loss = criterion(outputs.logits, labels)

            # ---- AMP backward pass ----
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()

        # Validation (no AMP needed)
        model.eval()
        val_preds = []
        val_true = []
        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                out = model(images)
                preds = torch.argmax(out, dim=1)
                val_preds.extend(preds.cpu().numpy())
                val_true.extend(labels.cpu().numpy())

        qwk = cohen_kappa_score(val_true, val_preds, weights='quadratic')
        print(f"Fold {fold + 1} Epoch {epoch+1}: Loss={total_loss/len(train_loader):.4f} | QWK={qwk:.4f}")

        if qwk > best_qwk:
            best_qwk = qwk
            best_state = model.state_dict()

    torch.save(best_state, f"best_model_fold_{fold + 1}.pt")
    return best_qwk

# %%
# Transforms for Resnet50 (change the resize for the model, everything keep the same?)
##change for inception
train_transform = transforms.Compose([
    transforms.Resize((299,299)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(0.2,0.2,0.2,0.05),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((299,299)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485,0.456,0.406], std=[0.229,0.224,0.225])
])

test_transform = val_transform

# %%
full_df = pd.read_csv(train_csv)

# First 80/20 stratified split
splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

for train_idx, test_idx in splitter.split(full_df, full_df["diagnosis"]):
    train_df = full_df.iloc[train_idx].reset_index(drop=True)
    test_df    = full_df.iloc[test_idx].reset_index(drop=True)

train_df.to_csv("train_split.csv", index=False)
test_df.to_csv("test_split.csv", index=False)

print(len(train_df), len(test_df))
# Out:
# 2929 733

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for fold, (tr_idx, val_idx) in enumerate(skf.split(train_df, train_df["diagnosis"])):
    fold_train_df = train_df.iloc[tr_idx].reset_index(drop=True)
    fold_val_df   = train_df.iloc[val_idx].reset_index(drop=True)

    fold_train_df.to_csv(f"fold_{fold + 1}_train.csv", index=False)
    fold_val_df.to_csv(f"fold_{fold + 1}_val.csv", index=False)

    print(f"Fold {fold + 1}: train={len(fold_train_df)}, val={len(fold_val_df)}")
# Out:
# Fold 1: train=2343, val=586
# Fold 2: train=2343, val=586
# Fold 3: train=2343, val=586
# Fold 4: train=2343, val=586
# Fold 5: train=2344, val=585

# %%
##oridnal thing
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_scores = []

# Save base model once (optional)
base_model = models.inception_v3(weights="IMAGENET1K_V1", aux_logits = True)
torch.save(base_model.state_dict(), "/content/inception_v3.pth")

for fold, (train_idx, val_idx) in enumerate(skf.split(train_df, train_df["diagnosis"])):
    print(f"\n======== Fold {fold + 1} ========")

    #Loaders for this fold
    train_loader, val_loader = get_loaders(fold)

    # ---- Use the new ordinal ResNet50 ----
    model = OrdinalInceptionV3().to(device)

   # ---- Train this fold using ordinal loss ----
    score = train_one_fold_ordinal(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        fold=fold,
        lr=1e-4,
        epochs=3                  # or however many you want
    )

    fold_scores.append(score)

print("QWK per fold:", fold_scores)
print("Average QWK:", np.mean(fold_scores))
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 199MB/s]
# ======== Fold 1 ========
# /tmp/ipython-input-2441271976.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 1 Epoch 1: Loss=0.2935 | QWK=0.8678
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 1 Epoch 2: Loss=0.1766 | QWK=0.8779
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 1 Epoch 3: Loss=0.1374 | QWK=0.8773
#
# ======== Fold 2 ========
# /tmp/ipython-input-2441271976.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 2 Epoch 1: Loss=0.2958 | QWK=0.8639
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 2 Epoch 2: Loss=0.1662 | QWK=0.9082
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 2 Epoch 3: Loss=0.1570 | QWK=0.8952
#
# ======== Fold 3 ========
# /tmp/ipython-input-2441271976.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 3 Epoch 1: Loss=0.3032 | QWK=0.8745
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 3 Epoch 2: Loss=0.1699 | QWK=0.8934
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 3 Epoch 3: Loss=0.1392 | QWK=0.8785
#
# ======== Fold 4 ========
# /tmp/ipython-input-2441271976.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 4 Epoch 1: Loss=0.2947 | QWK=0.8888
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 4 Epoch 2: Loss=0.1642 | QWK=0.8933
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 4 Epoch 3: Loss=0.1446 | QWK=0.8934
#
# ======== Fold 5 ========
# /tmp/ipython-input-2441271976.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 5 Epoch 1: Loss=0.2997 | QWK=0.8474
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 5 Epoch 2: Loss=0.1723 | QWK=0.8875
# /tmp/ipython-input-2441271976.py:26: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Fold 5 Epoch 3: Loss=0.1509 | QWK=0.8845
# QWK per fold: [np.float64(0.8778998577263757), np.float64(0.9082051758743799), np.float64(0.8933957982468315), np.float64(0.8934178608874616), np.float64(0.8874876360039565)]
# Average QWK: 0.8920812657478011

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_scores = []

base_model = models.inception_v3(weights="IMAGENET1K_V1", aux_logits = True)
torch.save(base_model.state_dict(), "/content/inception_v3_base.pth")


for fold, (train_idx, val_idx) in enumerate(skf.split(train_df, train_df["diagnosis"])):
    print(f"\n======== Fold {fold + 1} ========")
    train_loader, val_loader = get_loaders(fold)

    # Model
    model = get_inception_v3_model(num_classes=5)

    score = train_one_fold_i(model, train_loader, val_loader, fold, lr=1e-2)
    fold_scores.append(score)

print("QWK per fold:", fold_scores)
print("Average QWK:", np.mean(fold_scores))
# Out:
# ======== Fold 1 ========
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3782922829.py in <cell line: 0>()
#      11
#      12     # Model
# ---> 13     model = get_inception_v3_model(num_classes=5)
#      14
#      15     score = train_one_fold_i(model, train_loader, val_loader, fold, lr=1e-2)
#
# /tmp/ipython-input-2991037168.py in get_inception_v3_model(num_classes)
#       2
#       3 def get_inception_v3_model(num_classes):
# ----> 4     model = models.inception_v3(weights=None, aux_logits=True)  # skip download
#       5     model.load_state_dict(torch.load("/content/inception_v3_base.pth"))
#       6     model.fc = nn.Linear(2048, num_classes)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py in wrapper(*args, **kwargs)
#     140             kwargs.update(keyword_only_kwargs)
#     141
# --> 142         return fn(*args, **kwargs)
#     143
#     144     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py in inner_wrapper(*args, **kwargs)
#     226                 kwargs[weights_param] = default_weights_arg
#     227
# --> 228             return builder(*args, **kwargs)
#     229
#     230         return inner_wrapper
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py in inception_v3(weights, progress, **kwargs)
#     468         _ovewrite_named_param(kwargs, "num_classes", len(weights.meta["categories"]))
#     469
# --> 470     model = Inception3(**kwargs)
#     471
#     472     if weights is not None:
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py in __init__(self, num_classes, aux_logits, transform_input, inception_blocks, init_weights, dropout)
#      77         self.AuxLogits: Optional[nn.Module] = None
#      78         if aux_logits:
# ---> 79             self.AuxLogits = inception_aux(768, num_classes)
#      80         self.Mixed_7a = inception_d(768)
#      81         self.Mixed_7b = inception_e(1280)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py in __init__(self, in_channels, num_classes, conv_block)
#     372         if conv_block is None:
#     373             conv_block = BasicConv2d
# --> 374         self.conv0 = conv_block(in_channels, 128, kernel_size=1)
#     375         self.conv1 = conv_block(128, 768, kernel_size=5)
#     376         self.conv1.stddev = 0.01  # type: ignore[assignment]
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py in __init__(self, in_channels, out_channels, **kwargs)
#     399     def __init__(self, in_channels: int, out_channels: int, **kwargs: Any) -> None:
#     400         super().__init__()
# --> 401         self.conv = nn.Conv2d(in_channels, out_channels, bias=False, **kwargs)
#     402         self.bn = nn.BatchNorm2d(out_channels, eps=0.001)
#     403
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     513         padding_ = padding if isinstance(padding, str) else _pair(padding)
#     514         dilation_ = _pair(dilation)
# --> 515         super().__init__(
#     516             in_channels,
#     517             out_channels,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode, device, dtype)
#     175             self.register_parameter("bias", None)
#     176
# --> 177         self.reset_parameters()
#     178
#     179     def reset_parameters(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in reset_parameters(self)
#     181         # uniform(-1/sqrt(k), 1/sqrt(k)), where k = weight.size(1) * prod(*kernel_size)
#     182         # For more details see: https://github.com/pytorch/pytorch/issues/15314#issuecomment-477448573
# --> 183         init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#     184         if self.bias is not None:
#     185             fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/init.py in kaiming_uniform_(tensor, a, mode, nonlinearity, generator)
#     571     bound = math.sqrt(3.0) * std  # Calculate uniform bounds from standard deviation
#     572     with torch.no_grad():
# --> 573         return tensor.uniform_(-bound, bound, generator=generator)
#     574
#     575
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
test_dataset = RetinopathyDataset("test_split.csv", train_images, test_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)

num_folds = 5
all_fold_preds = []
all_true = []
def ordinal_decode(logits):
    """Convert 4 ordinal logits → single class prediction."""
    probs = torch.sigmoid(logits)          # shape (B,4)
    passed = (probs > 0.5).sum(dim=1)      # count thresholds satisfied
    return passed                          # 0–4

for fold in range(num_folds):
    print(f"Testing fold {fold + 1}")

    # Load ordinal model
    model = OrdinalInceptionV3().to(device)
    model.load_state_dict(torch.load(f"best_modelfold{fold + 1}.pt"))
    model.eval()

    fold_preds = []

    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            logits = model(images)                # shape (B,4)
            preds = ordinal_decode(logits)        # shape (B,)
            fold_preds.append(preds.cpu())
            if fold == 0:
                 all_true.append(labels)

    fold_preds = torch.cat(fold_preds, dim=0)     # shape (N,)
    all_fold_preds.append(fold_preds)

#---- Ordinal Ensemble: majority vote across folds ----
stacked = torch.stack(all_fold_preds)             # shape (5, N)
ensemble_preds, _  = torch.mode(stacked, dim=0)    # majority vote

#final_preds is a vector of length N with values 0–4
final_preds = ensemble_preds
y_true = torch.cat(all_true, dim = 0)

cm = confusion_matrix(y_true, final_preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Testing fold 1
# Testing fold 2
# Testing fold 3
# Testing fold 4
# Testing fold 5

# %%
test_dataset = RetinopathyDataset("test_split.csv", train_images, test_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)

num_folds = 5
all_fold_preds = []
all_true = []
for fold in range(num_folds):
    print(f"Testing fold {fold + 1}")
    model = get_inception_v3_model(num_classes=5)
    model.load_state_dict(torch.load(f"best_model_fold_{fold + 1}.pt"))
    model.eval()

    fold_preds = []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            probs = F.softmax(outputs, dim=1)
            fold_preds.append(probs.cpu())

            if fold == 0:
                 all_true.append(labels)


    fold_preds = torch.cat(fold_preds, dim=0)
    all_fold_preds.append(fold_preds)

# Ensemble by averaging
stacked_preds = torch.stack(all_fold_preds)
ensemble_preds = stacked_preds.mean(dim=0)
final_preds = torch.argmax(ensemble_preds, dim=1)
# Out:
# Testing fold 1
# /usr/local/lib/python3.12/dist-packages/torchvision/models/inception.py:43: FutureWarning: The default weight initialization of inception_v3 will be changed in future releases of torchvision. If you wish to keep the old behavior (which leads to long initialization times due to scipy/scipy#11299), please set init_weights=True.
#   warnings.warn(
# Testing fold 2
# Testing fold 3
# Testing fold 4
# Testing fold 5

# %%
# Accuracy
true_labels = torch.tensor(test_df["diagnosis"].values)
accuracy = (final_preds == true_labels).sum().item() / len(true_labels)
print(f"Test set accuracy: {accuracy:.4f}")

#QWK
y_true = true_labels.numpy() if torch.is_tensor(true_labels) else true_labels
y_pred = final_preds.numpy() if torch.is_tensor(final_preds) else final_preds

qwk = cohen_kappa_score(y_true, y_pred, weights='quadratic')
print(f"Test set QWK: {qwk:.4f}")

# Distribution plot
plt.figure(figsize=(8,5))
plt.hist(final_preds.numpy(), bins=np.arange(6)-0.5, edgecolor='black')
plt.xticks(range(5))
plt.xlabel("Predicted Class")
plt.ylabel("Number of Samples")
plt.title("Distribution of Predicted Classes on Test Set")
plt.show()
# Out:
# Test set accuracy: 0.8104
# Test set QWK: 0.8669

# %% [markdown]
# #Other attempts while working on the model (You can stop running cells here):

# %%
class SimpleDRCNN(nn.Module):
    def __init__(self, num_classes=5):
        super().__init__()

        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

        self.pool = nn.MaxPool2d(2, 2)
        self.dropout = nn.Dropout(0.3)

        # 128x128 → 64x64 → 32x32 → 16x16
        self.fc1 = nn.Linear(128 * 16 * 16, 256)
        self.fc2 = nn.Linear(256, num_classes)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x))) # 64x64
        x = self.pool(F.relu(self.conv2(x))) # 32x32
        x = self.pool(F.relu(self.conv3(x))) # 16x16

        x = torch.flatten(x, 1)
        x = self.dropout(x)

        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def train_one_fold(model, train_loader, val_loader, fold, epochs=3, patience=3, criterion = None):

    best_qwk = -np.inf
    wait = 0

    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for imgs, labels in tqdm(train_loader, desc=f"Fold {fold + 1} Epoch {epoch+1}"):
            imgs = imgs.cuda(); labels = labels.cuda()

            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # ===== Validation & QWK =====
        model.eval()
        val_labels = []
        val_preds = []

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs = imgs.cuda(); labels = labels.cuda()

                outputs = model(imgs)
                _, preds = torch.max(outputs, 1)

                val_labels.extend(labels.cpu().numpy())
                val_preds.extend(preds.cpu().numpy())

        qwk = qwk_score(val_labels, val_preds)
        print(f"Fold {fold + 1} Epoch {epoch+1}: QWK = {qwk:.4f}")

        # ===== Early Stopping =====
        if qwk > best_qwk:
            best_qwk = qwk
            wait = 0
            torch.save(model.state_dict(), f"best_model_fold_{fold + 1}.pt")
            print("  -> Saved new best model")
        else:
            wait += 1
            if wait >= patience:
                print("  -> Early stopping triggered!")
                break

    return best_qwk

# %%
# train_transform = transforms.Compose([
#     transforms.Resize((128, 128)),
#     transforms.RandomHorizontalFlip(),
#     transforms.RandomRotation(10),
#     transforms.ToTensor(),
# ])

# val_transform = transforms.Compose([
#     transforms.Resize((128, 128)),
#     transforms.ToTensor(),
# ])

# test_transform = transforms.Compose([
#     transforms.Resize((128, 128)),
#     transforms.ToTensor(),
# ])

# %%
# compute class weights
class_counts = train_df["diagnosis"].value_counts().sort_index().values
class_weights = 1.0 / class_counts
class_weights = class_weights / class_weights.sum()

class_weights = torch.tensor(class_weights, dtype=torch.float32).cuda()
criterion = nn.CrossEntropyLoss(weight=class_weights)

fold_scores = []
num_classes = 5

for fold, (train_idx, val_idx) in enumerate(skf.split(train_df, train_df["diagnosis"])):
    print(f"\n======== Fold {fold + 1} ========")
    train_loader, val_loader = get_loaders(fold)
    # Compute class weights for THIS fold only
    fold_train_df = train_df.iloc[train_idx].reset_index(drop=True)
    y = fold_train_df["diagnosis"].values
    classes = np.arange(num_classes)
    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=y
    )
    class_weights = torch.tensor(class_weights, dtype=torch.float32).cuda()
    print(f"Class weights for fold {fold + 1}: {class_weights.cpu().numpy()}")
    # Create weighted loss function
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    # Initialize model
    model = SimpleDRCNN(num_classes=num_classes).cuda()

    # Train one fold
    score = train_one_fold(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,      # <-- pass weighted loss
        fold=fold
    )

    fold_scores.append(score)

print("\nQWK per fold:", fold_scores)
print("Average QWK:", np.mean(fold_scores))
# Out:
# ======== Fold 1 ========
# Class weights for fold 1: [0.40571427 1.9772152  0.73333335 3.809756   2.479365  ]
# Fold 1 Epoch 1: 100%|██████████| 74/74 [05:17<00:00,  4.28s/it]
# Fold 1 Epoch 1: QWK = 0.4041
#   -> Saved new best model
# Fold 1 Epoch 2: 100%|██████████| 74/74 [05:08<00:00,  4.16s/it]
# Fold 1 Epoch 2: QWK = 0.4087
#   -> Saved new best model
# Fold 1 Epoch 3: 100%|██████████| 74/74 [05:13<00:00,  4.23s/it]
# Fold 1 Epoch 3: QWK = 0.4372
#   -> Saved new best model
#
# ======== Fold 2 ========
# Class weights for fold 2: [0.40571427 1.9772152  0.73333335 3.809756   2.479365  ]
# Fold 2 Epoch 1: 100%|██████████| 74/74 [05:12<00:00,  4.23s/it]
# Fold 2 Epoch 1: QWK = 0.4823
#   -> Saved new best model
# Fold 2 Epoch 2: 100%|██████████| 74/74 [05:12<00:00,  4.22s/it]
# Fold 2 Epoch 2: QWK = 0.3766
# Fold 2 Epoch 3: 100%|██████████| 74/74 [05:21<00:00,  4.34s/it]
# Fold 2 Epoch 3: QWK = 0.3710
#
# ======== Fold 3 ========
# Class weights for fold 3: [0.40571427 1.9855932  0.73333335 3.7790322  2.479365  ]
# Fold 3 Epoch 1: 100%|██████████| 74/74 [05:21<00:00,  4.35s/it]
# Fold 3 Epoch 1: QWK = 0.4237
#   -> Saved new best model
# Fold 3 Epoch 2: 100%|██████████| 74/74 [05:18<00:00,  4.30s/it]
# Fold 3 Epoch 2: QWK = 0.4227
# Fold 3 Epoch 3: 100%|██████████| 74/74 [05:16<00:00,  4.28s/it]
# Fold 3 Epoch 3: QWK = 0.5177
#   -> Saved new best model
#
# ======== Fold 4 ========
# Class weights for fold 4: [0.40571427 1.9772152  0.7321875  3.809756   2.4925532 ]
# Fold 4 Epoch 1: 100%|██████████| 74/74 [05:19<00:00,  4.32s/it]
# Fold 4 Epoch 1: QWK = 0.3994
#   -> Saved new best model
# Fold 4 Epoch 2: 100%|██████████| 74/74 [05:18<00:00,  4.31s/it]
# Fold 4 Epoch 2: QWK = 0.4197
#   -> Saved new best model
# Fold 4 Epoch 3: 100%|██████████| 74/74 [05:13<00:00,  4.23s/it]
# Fold 4 Epoch 3: QWK = 0.5408
#   -> Saved new best model
#
# ======== Fold 5 ========
# Class weights for fold 5: [0.40553632 1.978059   0.73364633 3.811382   2.4804232 ]
# Fold 5 Epoch 1: 100%|██████████| 74/74 [05:27<00:00,  4.43s/it]
# Fold 5 Epoch 1: QWK = 0.3796
#   -> Saved new best model
# Fold 5 Epoch 2: 100%|██████████| 74/74 [05:18<00:00,  4.31s/it]
# Fold 5 Epoch 2: QWK = 0.4543
#   -> Saved new best model
# Fold 5 Epoch 3: 100%|██████████| 74/74 [05:19<00:00,  4.31s/it]
# Fold 5 Epoch 3: QWK = 0.4763
#   -> Saved new best model
#
# QWK per fold: [np.float64(0.43716105352924584), np.float64(0.4823406239264507), np.float64(0.5176886121430371), np.float64(0.5407959554856808), np.float64(0.4763381910898591)]
# Average QWK: 0.4908648872348548

# %%
test_dataset = RetinopathyDataset("test_split.csv", train_images, test_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)

num_folds = 5
num_classes = 5

all_fold_preds = []

for fold in range(num_folds):
    print(f"\n===== Processing fold {fold + 1} =====")
    # Load the trained model for this fold
    model = SimpleDRCNN(num_classes=num_classes).to(device)
    model.load_state_dict(torch.load(f"best_model_fold_{fold + 1}.pt"))
    model.eval()

    fold_preds = []
    with torch.no_grad():
        for batch_idx, (images, _) in enumerate(test_loader):
            images = images.to(device)
            outputs = model(images)
            probs = F.softmax(outputs, dim=1)  # convert logits to probabilities
            fold_preds.append(probs.cpu())

            if (batch_idx + 1) % 10 == 0 or (batch_idx + 1) == len(test_loader):
                print(f"Fold {fold + 1} - processed batch {batch_idx + 1}/{len(test_loader)}")

    fold_preds = torch.cat(fold_preds, dim=0)  # shape: [num_samples, num_classes]
    all_fold_preds.append(fold_preds)

# Stack predictions: shape [num_folds, num_samples, num_classes]
stacked_preds = torch.stack(all_fold_preds)

# Average over the folds
ensemble_preds = stacked_preds.mean(dim=0)  # shape: [num_samples, num_classes]

# Final predicted class
final_preds = torch.argmax(ensemble_preds, dim=1)
# Out:
# ===== Processing fold 1 =====
# Fold 1 - processed batch 10/23
# Fold 1 - processed batch 20/23
# Fold 1 - processed batch 23/23
#
# ===== Processing fold 2 =====
# Fold 2 - processed batch 10/23
# Fold 2 - processed batch 20/23
# Fold 2 - processed batch 23/23
#
# ===== Processing fold 3 =====
# Fold 3 - processed batch 10/23
# Fold 3 - processed batch 20/23
# Fold 3 - processed batch 23/23
#
# ===== Processing fold 4 =====
# Fold 4 - processed batch 10/23
# Fold 4 - processed batch 20/23
# Fold 4 - processed batch 23/23
#
# ===== Processing fold 5 =====
# Fold 5 - processed batch 10/23
# Fold 5 - processed batch 20/23
# Fold 5 - processed batch 23/23

# %%
true_labels = torch.tensor(test_df["diagnosis"].values)
accuracy = (final_preds == true_labels).sum().item() / len(true_labels)
print(f"Test set accuracy: {accuracy:.4f}")

# ===== Compute QWK =====
qwk = cohen_kappa_score(true_labels.numpy(), final_preds.numpy(), weights="quadratic")
print(f"Test Set QWK: {qwk:.4f}")

# final_preds is a torch tensor, convert to numpy
preds_np = final_preds.numpy()

plt.figure(figsize=(8,5))
plt.hist(preds_np, bins=np.arange(num_classes+1)-0.5, edgecolor='black')
plt.xticks(range(num_classes))  # one tick per class
plt.xlabel("Predicted Class")
plt.ylabel("Number of Samples")
plt.title("Distribution of Predicted Classes on Test Set")
plt.show()
# Out:
# Test set accuracy: 0.6548
# Test Set QWK: 0.4429

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_true = test_df["diagnosis"].values
y_pred = final_preds.numpy()

print(classification_report(y_true, y_pred, digits=4))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d'); plt.xlabel("pred"); plt.ylabel("true"); plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8899    0.8283    0.8580       361
#            1     0.3271    0.4730    0.3867        74
#            2     0.6404    0.6500    0.6452       200
#            3     0.2683    0.2821    0.2750        39
#            4     0.1087    0.0847    0.0952        59
#
#     accuracy                         0.6548       733
#    macro avg     0.4469    0.4636    0.4520       733
# weighted avg     0.6690    0.6548    0.6599       733

# %%
# EPOCHS = 3
# num_folds = 5

# fold_results = {}

# for fold in range(num_folds):
#     print(f"\n===== Fold {fold + 1} / {num_folds} =====")

#     train_loader, val_loader = get_loaders(fold)

#     model = SimpleDRCNN().to(device)
#     criterion = nn.CrossEntropyLoss()
#     optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
#     best_val_acc = 0.0

#     for epoch in range(EPOCHS):
#         model.train()
#         total_loss = 0

#         for batch_idx, (images, labels) in enumerate(train_loader):
#             images = images.to(device)
#             labels = labels.to(device)

#             optimizer.zero_grad()
#             outputs = model(images)
#             loss = criterion(outputs, labels)
#             loss.backward()
#             optimizer.step()

#             total_loss += loss.item()

#         avg_loss = total_loss / len(train_loader)

#         # Validation
#         model.eval()
#         correct = 0
#         total = 0
#         with torch.no_grad():
#             for imgs, labels in val_loader:
#                 imgs = imgs.to(device)
#                 labels = labels.to(device)
#                 out = model(imgs)
#                 _, preds = torch.max(out, 1)
#                 correct += (preds == labels).sum().item()
#                 total += labels.size(0)

#         val_acc = correct / total
#         if val_acc > best_val_acc:
#           best_val_acc = val_acc
#           torch.save(model.state_dict(), f"fold_{fold}_best.pth")
#         print(f"Epoch {epoch+1}/{EPOCHS} | Avg Loss: {avg_loss:.4f} | Val Acc: {val_acc:.4f}")

#     # Save fold accuracy
#     fold_results[fold] = val_acc
# Out:
# Using device: cuda
#
# ===== Fold 1 / 5 =====
# Epoch 1/3 | Avg Loss: 1.1890 | Val Acc: 0.6724
# Epoch 2/3 | Avg Loss: 0.8916 | Val Acc: 0.6945
# Epoch 3/3 | Avg Loss: 0.8378 | Val Acc: 0.6792
#
# ===== Fold 2 / 5 =====
# Epoch 1/3 | Avg Loss: 1.1768 | Val Acc: 0.6587
# Epoch 2/3 | Avg Loss: 0.9075 | Val Acc: 0.6775
# Epoch 3/3 | Avg Loss: 0.8370 | Val Acc: 0.6894
#
# ===== Fold 3 / 5 =====
# Epoch 1/3 | Avg Loss: 1.1946 | Val Acc: 0.6792
# Epoch 2/3 | Avg Loss: 0.8900 | Val Acc: 0.7031
# Epoch 3/3 | Avg Loss: 0.8460 | Val Acc: 0.6928
#
# ===== Fold 4 / 5 =====
# Epoch 1/3 | Avg Loss: 1.1863 | Val Acc: 0.6741
# Epoch 2/3 | Avg Loss: 0.8812 | Val Acc: 0.6962
# Epoch 3/3 | Avg Loss: 0.8346 | Val Acc: 0.6758
#
# ===== Fold 5 / 5 =====
# Epoch 1/3 | Avg Loss: 1.2115 | Val Acc: 0.6769
# Epoch 2/3 | Avg Loss: 0.9243 | Val Acc: 0.6940
# Epoch 3/3 | Avg Loss: 0.8501 | Val Acc: 0.6906

# %%
# test_dataset = RetinopathyDataset("test_split.csv", train_images, test_transform)
# test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# num_folds = 5
# num_classes = 5

# all_fold_preds = []

# for fold in range(num_folds):
#     # Load the trained model for this fold
#     model = SimpleDRCNN(num_classes=num_classes).to(device)
#     model.load_state_dict(torch.load(f"fold_{fold}_best.pth"))
#     model.eval()

#     fold_preds = []
#     with torch.no_grad():
#         for images, _ in test_loader:  # labels are ignored here
#             images = images.to(device)
#             outputs = model(images)
#             probs = F.softmax(outputs, dim=1)  # convert logits to probabilities
#             fold_preds.append(probs.cpu())

#     fold_preds = torch.cat(fold_preds, dim=0)  # shape: [num_samples, num_classes]
#     all_fold_preds.append(fold_preds)

# # Stack predictions: shape [num_folds, num_samples, num_classes]
# stacked_preds = torch.stack(all_fold_preds)

# # Average over the folds
# ensemble_preds = stacked_preds.mean(dim=0)  # shape: [num_samples, num_classes]

# # Final predicted class
# final_preds = torch.argmax(ensemble_preds, dim=1)

# %%
# true_labels = torch.tensor(test_df["diagnosis"].values)
# accuracy = (final_preds == true_labels).sum().item() / len(true_labels)
# print(f"Test set accuracy: {accuracy:.4f}")

# # final_preds is a torch tensor, convert to numpy
# preds_np = final_preds.numpy()

# plt.figure(figsize=(8,5))
# plt.hist(preds_np, bins=np.arange(num_classes+1)-0.5, edgecolor='black')
# plt.xticks(range(num_classes))  # one tick per class
# plt.xlabel("Predicted Class")
# plt.ylabel("Number of Samples")
# plt.title("Distribution of Predicted Classes on Test Set")
# plt.show()
# Out:
# Test set accuracy: 0.6835

# %%
# class TestDataset(Dataset):
#     def __init__(self, img_dir, transform=None):
#         self.img_dir = img_dir
#         self.transform = transform
#         self.filenames = sorted(os.listdir(img_dir))

#     def __len__(self):
#         return len(self.filenames)

#     def __getitem__(self, idx):
#         fname = self.filenames[idx]
#         path = os.path.join(self.img_dir, fname)

#         img = Image.open(path).convert("RGB")
#         if self.transform:
#             img = self.transform(img)

#         return img, fname

# %%
# test_images = dataset_path + "/test_images"

# test_dataset = APTosTestDataset(test_images, transform=test_transform)
# test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# %%
# device = torch.device("cuda")
# model = SimpleDRCNN().to(device)

# model.load_state_dict(torch.load("/content/drive/MyDrive/aptos_model.pth"))
# model.eval()

# print("Model loaded and ready!")
# Out:
# Model loaded and ready!

# %%
# model.eval()
# results = []

# with torch.no_grad():
#     for imgs, fnames in test_loader:
#         imgs = imgs.to(device)
#         outputs = model(imgs)

#         preds = outputs.argmax(dim=1).cpu().tolist()

#         for fname, pred in zip(fnames, preds):
#             results.append((fname, pred))

# df = pd.DataFrame(results, columns=["id_code", "diagnosis"])
# df.to_csv("/content/drive/MyDrive/aptos_predictions.csv", index=False)

# print("Saved predictions to aptos_predictions.csv!")
# Out:
# Saved predictions to aptos_predictions.csv!

# %%
# from pydrive2.auth import GoogleAuth, ServiceAccountCredentials
# from pydrive2.drive import GoogleDrive

# gauth = GoogleAuth()

# # Prevent PyDrive2 from trying to read client_secrets.json
# gauth.settings = {
#     'client_config_backend': 'service',
#     'service_config': {
#         'client_json_file_path': 'acquired-talent-479707-u9-7a6249ae19df.json'  # your file
#     }
# }

# gauth.credentials = ServiceAccountCredentials.from_json_keyfile_name(
#     'acquired-talent-479707-u9-7a6249ae19df.json',
#     scopes=['https://www.googleapis.com/auth/drive']
# )

# gauth.Authorize()

# drive = GoogleDrive(gauth)
# print("Service account authenticated.")
# Out:
# Service account authenticated.

# %%
# folder_id = "1HN1QyKm6RVPwEMVfwFO-pNDbrlpp3WNf"

# # List files
# file_list = drive.ListFile({'q': f"'{folder_id}' in parents"}).GetList()

# for f in file_list:
#     print(f['title'], f['id'])
# Out:
# train_images 1iRGGeaZs7Cl6c4x9rMPL1CKuDyja19_t
# test_images 1XO9QC-0YHH16cc25j_QO3A1KhKq-mAhV
# train.csv 1UT6Tky1MQcvvHQ7mS3ctJQ-l1aG_wV6Y
# test.csv 1E2ulvO1HPkR9NCM1UGxewr1JuLkZNCo1
# sample_submission.csv 1IVABRmibzIu-2uivjTmeK5_B4uP3p5HH

# %%
# # Download dataset
# def download_folder_recursively(folder_id, dest_path):
#     os.makedirs(dest_path, exist_ok=True)

#     file_list = drive.ListFile({'q': f"'{folder_id}' in parents"}).GetList()

#     for f in file_list:
#         fname = f['title']
#         fid = f['id']

#         if f['mimeType'] == 'application/vnd.google-apps.folder':
#             print(f"[Folder] {fname}")
#             download_folder_recursively(fid, os.path.join(dest_path, fname))
#         else:
#             print(f"[File] {fname}")
#             out_path = os.path.join(dest_path, fname)
#             f.GetContentFile(out_path)

# # Download your whole dataset folder:
# download_folder_recursively(
#     "1HN1QyKm6RVPwEMVfwFO-pNDbrlpp3WNf",
#     "aptos_dataset"
# )
# Out:
# [Folder] train_images
# [File] ff52392372d3.png
# [File] ffa47f6a7bf4.png
# [File] ff8a0b45c789.png
# [File] ff4cd992667b.png
# [File] ffcf7b45f213.png
# [File] ff59d44a70a7.png
# [File] ffec9a18a3ce.png
# [File] ff631653374e.png
# [File] ffc04fed30e6.png
# [File] ff77e8e5b5f3.png
# [File] ffd97f8cd5aa.png
# [File] fe0fc67c7980.png
# [File] fe674c2f73f5.png
# [File] fe0e2dee1834.png
# [File] fefded6bf135.png
# [File] fdbc252813b1.png
# [File] fd62bd0db4f1.png
# [File] fe06dad6851c.png
# [File] fda39982a810.png
# [File] fdc685055659.png
# [File] ff1e940105f9.png
# [File] ff0740cb484a.png
# [File] fecf4c5ae84b.png
# [File] ff03f74667df.png
# [File] fd87b6b2e664.png
# [File] ff4832d55461.png
# [File] fea14b3d44b0.png
# [File] fe37f4492920.png
# [File] fe3b0e50be78.png
# [File] ff4955e76894.png
# [File] fe3f62695b2d.png
# [File] fe2df69676cf.png
# [File] ff344e5c9341.png
# [File] febfb20dc311.png
# [File] fdd534271f3d.png
# [File] fdd18ccbbdc5.png
# [File] fed5bb685832.png
# [File] fce73678f650.png
# [File] fcc32dffd24d.png
# [File] fc782722a50c.png
# [File] fb88783de055.png
# [File] fd079d2e93a2.png
# [File] fbfa925506f6.png
# [File] fd48cf452e9d.png
# [File] fbcbc81cf9be.png
# [File] fb767cea406c.png
# [File] fc1b1841eadf.png
# [File] fca1a8738b8a.png
# [File] fca931da5c5e.png
# [File] fb88d23fc5fe.png
# [File] fcc55ae641ae.png
# [File] fc4d69128e7c.png
# [File] fc898dfeb24f.png
# [File] fce93caa4758.png
# [File] fb6b8200b7f8.png
# [File] fbdc796290d4.png
# [File] fc603cbedb41.png
# [File] fcc6aa6755e6.png
# [File] fc4c2d35c6f8.png
# [File] fc8fce67fbf8.png
# [File] fd4c946c52bf.png
# [File] fd0a70082e7c.png
# [File] fba493e17448.png
# [File] fa7fa797c650.png
# [File] fa748b57262b.png
# [File] fa9bece586fc.png
# [File] fa9f1bc03f21.png
# [File] fb696a8e055a.png
# [File] fb1b8771c70a.png
# [File] fac399455195.png
# [File] fb61230b99dd.png
# [File] fa3e544a7401.png
# [File] fa6f3d8bb1d5.png
# [File] fa573163dd8b.png
# [File] fa59221cf464.png
# [File] f9e1c439d4c8.png
# [File] f9ecf1795804.png
# [File] f9e779a13204.png
# [File] f9d8ff3e6592.png
# [File] fa0c87bd75ce.png
# [File] f9aa35187bf3.png
# [File] f952ad2e4356.png
# [File] f994a3b07935.png
# [File] f9d52509c571.png
# [File] f999c6921e6d.png
# [File] f9156aeffc5e.png
# [File] f91cfa82b9d4.png
# [File] f90f8931a9bc.png
# [File] f901d460517c.png
# [File] f920ccd926db.png
# [File] f85fd4fac887.png
# [File] f850cb51fdba.png
# [File] f8d62557ad0c.png
# [File] f8fc411092c7.png
# [File] f85c78201a50.png
# [File] f8f5942b690e.png
# [File] f8cf7ed8ef00.png
# [File] f86d1c404acb.png
# [File] f7fec8935126.png
# [File] f80118bbda18.png
# [File] f8372e80f731.png
# [File] f7edc074f06b.png
# [File] f819c65b803c.png
# [File] f6f433f3306f.png
# [File] f7735b6d47f7.png
# [File] f72ef9ceeaa8.png
# [File] f71bea807c96.png
# [File] f6f7dba7104d.png
# [File] f72adcac5638.png
# [File] f71333204618.png
# [File] f7116e7b2f4e.png
# [File] f7e9fa75c7c1.png
# [File] f7defe70afc3.png
# [File] f7508f14dd7b.png
# [File] f762c272c522.png
# [File] f71aca5a7dc3.png
# [File] f6f3ea0d2693.png
# [File] f69835dc7c50.png
# [File] f69400b316a7.png
# [File] f6d760566a51.png
# [File] f64b6e85f1c9.png
# [File] f68690db78d3.png
# [File] f66c4ee86629.png
# [File] f64214bed40e.png
# [File] f62b8a076833.png
# [File] f61bf44c677c.png
# [File] f5e9a307288c.png
# [File] f5e6226bd2e0.png
# [File] f633c474e8b8.png
# [File] f58cdfa968be.png
# [File] f583a722434c.png
# [File] f5a8c6426a71.png
# [File] f55e1d2a19e4.png
# [File] f4df3d86688d.png
# [File] f58f0b2fd718.png
# [File] f5c953bee7cd.png
# [File] f58d37d48e42.png
# [File] f531232ecb55.png
# [File] f57cf3b6f48e.png
# [File] f5650eb52640.png
# [File] f549294e12e1.png
# [File] f56ff0440ed1.png
# [File] f4ea2a2cfbb9.png
# [File] f4de9620e3f2.png
# [File] f5733f77273d.png
# [File] f4e68b61f480.png
# [File] f576e45d1da2.png
# [File] f580566e27f5.png
# [File] f36cb007a1ef.png
# [File] f45f1485c940.png
# [File] f4874247ede6.png
# [File] f3b6b7ca1eb1.png
# [File] f431f2e119d7.png
# [File] f451eee2b66b.png
# [File] f4d3169b468a.png
# [File] f42b693a9414.png
# [File] f48241b0c995.png
# [File] f3cd489acbee.png
# [File] f4d3777f2710.png
# [File] f4c7ae514c54.png
# [File] f460608cf4cc.png
# [File] f3a4751af42e.png
# [File] f3b27ac2d371.png
# [File] f47a2a4a0411.png
# [File] f3a268d2726d.png
# [File] f3bb996b45ce.png
# [File] f3a88d3026dc.png
# [File] f481f76a6b75.png
# [File] f18abfa690ab.png
# [File] f2094a20b275.png
# [File] f35d80bb1a22.png
# [File] f2c0b41acd05.png
# [File] f2d2a0c92034.png
# [File] f2f569a64949.png
# [File] f366fb1cc475.png
# [File] f2ee81781411.png
# [File] f0e1201b5c1f.png
# [File] f26b02ead915.png
# [File] f0f89314e860.png
# [File] f0c0f7b5e820.png
# [File] f1979147aad4.png
# [File] f1dc26c4bfa3.png
# [File] f0a2dc580009.png
# [File] f23902998c21.png
# [File] f361060eda3e.png
# [File] f0c13be90519.png
# [File] f252046c0fe6.png
# [File] f1a761c68559.png
# [File] f09fd9433dff.png
# [File] f298b7d05958.png
# [File] f30f203ef51e.png
# [File] f1d719c97838.png
# [File] f233638e0e90.png
# [File] f09cfc6a4dbd.png
# [File] f080a22008be.png
# [File] f0546a45ef10.png
# [File] f0267c42907c.png
# [File] f03d3c4ce7fb.png
# [File] f092febbf5c0.png
# [File] ef7a4ed8d5d1.png
# [File] f00ce9b9d6f4.png
# [File] f02956bd7c50.png
# [File] f025f33b2c9b.png
# [File] f0860c21533b.png
# [File] f06e7a9df795.png
# [File] efff2f1a35f5.png
# [File] f066db7a2efe.png
# [File] ef7eb85b75fc.png
# [File] f0800723bc63.png
# [File] ef81cd8854cb.png
# [File] f002ce614c59.png
# [File] f02057c41256.png
# [File] f02babb3a023.png
# [File] f0098e9d4aee.png
# [File] ef8109305128.png
# [File] ef99c499d665.png
# [File] ef8c39eb9157.png
# [File] eeaea2c5ff34.png
# [File] ef247f28004f.png
# [File] ef4121e9bb67.png
# [File] ef26625121b3.png
# [File] ee77763a6afb.png
# [File] eeb231c3ef1f.png
# [File] eed4afc8ec83.png
# [File] ef5155990874.png
# [File] ee74c3b177e0.png
# [File] ef476be214d4.png
# [File] eedae6b28f96.png
# [File] ee78ce914066.png
# [File] ef48780f5d5f.png
# [File] eebd1e195952.png
# [File] ee6e39319b39.png
# [File] ed6704e3b72e.png
# [File] ecad6845f630.png
# [File] edceb0657d77.png
# [File] ed6bd9293a89.png
# [File] eda1d75cbcf0.png
# [File] ee36ca728641.png
# [File] ee059945b08a.png
# [File] ed246ae1ed08.png
# [File] ed3a0fc5b546.png
# [File] ee3fe7809e6a.png
# [File] ed2c06fcc573.png
# [File] ed2c52c14493.png
# [File] ec6f1797a25a.png
# [File] ee02294cc3d9.png
# [File] eda29a9d78f3.png
# [File] ed3ce1674761.png
# [File] ee1ec90b980f.png
# [File] ed2ef440d22c.png
# [File] ed88faaa325a.png
# [File] ee2c2a5f7d0e.png
# [File] ed648b9bcd95.png
# [File] ecb4500285ed.png
# [File] ee3f5cf52188.png
# [File] eadc57064154.png
# [File] ec363f48867b.png
# [File] eba3acc42197.png
# [File] eb32a815f78c.png
# [File] ec6659926105.png
# [File] eae70f527755.png
# [File] eabf421f94d0.png
# [File] ebf4b22240f4.png
# [File] eae901557a84.png
# [File] ea9e0fb6fb0b.png
# [File] ebe0175e530c.png
# [File] ec01f0862669.png
# [File] eb1d37b71fd1.png
# [File] eb050765b323.png
# [File] eabc7c716255.png
# [File] eadfc8809ec8.png
# [File] eaa0dfbd5024.png
# [File] ead23cc922ed.png
# [File] eb6b1f1c09db.png
# [File] eb175669d789.png
# [File] ebd96d853918.png
# [File] ec4649213ccf.png
# [File] ec0c9f817b03.png
# [File] ec57cc20d776.png
# [File] eb1ad14dd281.png
# [File] ea6a53e54d0f.png
# [File] ea68b58a6e8f.png
# [File] e9faf0296643.png
# [File] ea5c42a78979.png
# [File] ea4dcb055139.png
# [File] ea7e21bab610.png
# [File] ea1d045f9fea.png
# [File] e9f82b5bbaf4.png
# [File] ea588d1e5d96.png
# [File] e9ff9352ccb3.png
# [File] ea05c22d92e9.png
# [File] ea9c41e1ced0.png
# [File] ea4ce9516144.png
# [File] ea15a290eb96.png
# [File] e96099b961b4.png
# [File] e907d23cce3d.png
# [File] e85d410d6836.png
# [File] e9286ddf6ffe.png
# [File] e81f4a2fbbdc.png
# [File] e933923aab15.png
# [File] e868c3da340b.png
# [File] e9ab8413e771.png
# [File] e93394175a19.png
# [File] e96bd80a8a53.png
# [File] e8ddfc9709ce.png
# [File] e9f3c85a2a02.png
# [File] e9129ce55fd7.png
# [File] e9ce5bf645ab.png
# [File] e893e86dde94.png
# [File] e8d1c6c07cf2.png
# [File] e9678824215d.png
# [File] e8e44b3160e3.png
# [File] e82232a3c28b.png
# [File] e83d315d8f98.png
# [File] e97ecf4355cb.png
# [File] e821c1b6417a.png
# [File] e966850247f4.png
# [File] e7a372a1c3a4.png
# [File] e7fc93ac5b6d.png
# [File] e811f39a1243.png
# [File] e6f0ce5bf282.png
# [File] e7a7187066ad.png
# [File] e740af6ac6ea.png
# [File] e6a58edc5b42.png
# [File] e69b48516577.png
# [File] e7defafeb957.png
# [File] e724866f5084.png
# [File] e7291472109b.png
# [File] e76a9cbb2a8c.png
# [File] e756495c11cb.png
# [File] e6a5e4718873.png
# [File] e6a6acf7fca1.png
# [File] e79e10907295.png
# [File] e7d2c2c3b30f.png
# [File] e7b5dd5bab1f.png
# [File] e7578d8dba72.png
# [File] e77a93c3d9a9.png
# [File] e59c5f345bb0.png
# [File] e5d56f4f359b.png
# [File] e599151ca14b.png
# [File] e65f94ad9be3.png
# [File] e68bdd36e589.png
# [File] e632e38fd2d4.png
# [File] e5f332efcbc7.png
# [File] e66855a5c583.png
# [File] e5de79795c1d.png
# [File] e6552b7432b3.png
# [File] e5f73f2855c0.png
# [File] e62490b7d0e9.png
# [File] e65a2ff90494.png
# [File] e66ad813a508.png
# [File] e663c6627a95.png
# [File] e60e4edb3ca9.png
# [File] e68746d426b2.png
# [File] e4c799738a19.png
# [File] e4d3d437b0a8.png
# [File] e529c5757d64.png
# [File] e4730ddde408.png
# [File] e580676516b0.png
# [File] e4dcca36ceb4.png
# [File] e540d2e35d15.png
# [File] e582e56e7942.png
# [File] e55188915f9d.png
# [File] e4a44f9158dc.png
# [File] e4e343eaae2a.png
# [File] e47770a2e5d1.png
# [File] e4f12411fd85.png
# [File] e499434242cc.png
# [File] e594c19e2e1d.png
# [File] e5197d77ec68.png
# [File] e4ae1ee6aada.png
# [File] e52ed5c29c5e.png
# [File] e47452069ea1.png
# [File] e4b0df29b96f.png
# [File] e42d9a94a66d.png
# [File] e50b0174690d.png
# [File] e3ab63dc9a60.png
# [File] e4151feb8443.png
# [File] e4210e7fe587.png
# [File] e3cd96cb094c.png
# [File] e38f3a65b02b.png
# [File] e3e490babc0c.png
# [File] e39b627cf648.png
# [File] e3b47ed5b511.png
# [File] e3a7671f787b.png
# [File] e3ec668f6fad.png
# [File] e31c42a8652b.png
# [File] e2c3b037413b.png
# [File] e33766353db2.png
# [File] e2a47a74e6e1.png
# [File] e30a890600e1.png
# [File] e2c39ed0c941.png
# [File] e34fa07bd64d.png
# [File] e2a233493b90.png
# [File] e322acd46152.png
# [File] e26bcae6c67b.png
# [File] e29e54ff921e.png
# [File] e32a359be36d.png
# [File] e387311a840e.png
# [File] e2ec22b3d07e.png
# [File] e25ccfe38e44.png
# [File] e251bdf05b85.png
# [File] e26d8718ca58.png
# [File] e265c870f9b3.png
# [File] e2856afe62c5.png
# [File] e32dc722eca5.png
# [File] e1dc02a3dc2a.png
# [File] e2265c383348.png
# [File] e23add229074.png
# [File] e2161692a0b4.png
# [File] e1e490773462.png
# [File] e1ab92228e60.png
# [File] e1c02f6c3362.png
# [File] e1b8acb1cea1.png
# [File] e19936582c61.png
# [File] e1fb532f55df.png
# [File] e229aca862c7.png
# [File] e246cd89e1cc.png
# [File] e07045d7c5f7.png
# [File] e12f9f19d1be.png
# [File] e087bd4b88f2.png
# [File] e12b67835e03.png
# [File] e06d3d4733f0.png
# [File] e04f3c6619a3.png
# [File] e0d229db881a.png
# [File] e135d7ba9a0e.png
# [File] e03e70bc8bba.png
# [File] e13412678eff.png
# [File] e0863b353093.png
# [File] e12df54e0d1e.png
# [File] e160a3b19911.png
# [File] e1900014dabf.png
# [File] e1418d28d668.png
# [File] e12d41e7b221.png
# [File] e0b5a982a018.png
# [File] e16fc934069f.png
# [File] e16af45285e5.png
# [File] e17507a4a1f5.png
# [File] e06cccc08c59.png
# [File] e10190a9d52f.png
# [File] e067b06fd655.png
# [File] e150935f66a6.png
# [File] df0886f1e76b.png
# [File] e01b7bac822b.png
# [File] dfc7ec7db0e0.png
# [File] dfea19863428.png
# [File] e0313be77035.png
# [File] e03a74e7d74f.png
# [File] df8365d6ac33.png
# [File] e037643244b7.png
# [File] df841a0440d8.png
# [File] dee687c6e88a.png
# [File] e019b3e0f33d.png
# [File] df4913ca3712.png
# [File] df4aec4a0eaf.png
# [File] df6d13d04da1.png
# [File] df5ce3ea7820.png
# [File] df9cb3729eb1.png
# [File] df84e7113003.png
# [File] df3adfd6ba36.png
# [File] de2eb5c8aa83.png
# [File] de55ed25e0e8.png
# [File] de6210f88536.png
# [File] de778495a1cd.png
# [File] de38adaae009.png
# [File] dec5595e6154.png
# [File] de16416220de.png
# [File] dee31065f8fe.png
# [File] dea7538bb91a.png
# [File] de18071c36e6.png
# [File] de730033c683.png
# [File] dee1031a76ae.png
# [File] de57c9e9fa93.png
# [File] de50dfa745f8.png
# [File] de4cdabbce6d.png
# [File] dc0eea0b68a7.png
# [File] dd02d60bef14.png
# [File] dcf109df1a2b.png
# [File] dd285d9e97fe.png
# [File] dce73d90c00c.png
# [File] dd19428c3d29.png
# [File] dccdf750c962.png
# [File] dd110d2b8c21.png
# [File] dbee04ae6426.png
# [File] dde43aa22ae6.png
# [File] dcc6c0ad5cad.png
# [File] dbfd238b3468.png
# [File] dc0f6e5b489b.png
# [File] dd3dad6ca78f.png
# [File] dd3176bacfe2.png
# [File] dd90c321d7bc.png
# [File] ddb222ff7c1d.png
# [File] dc3c0d8ee20b.png
# [File] dc6fa1b38b83.png
# [File] d9e58e4d8689.png
# [File] da0a1043abf7.png
# [File] da6389d129aa.png
# [File] da8900ac7f29.png
# [File] da6bbb76d562.png
# [File] da9fe02dead3.png
# [File] da44f80b422b.png
# [File] da949aa67a4f.png
# [File] db690e2d02f8.png
# [File] dbb2c63f6f08.png
# [File] db3cd58aa315.png
# [File] da3a2275c850.png
# [File] daad7b617f21.png
# [File] da2bdf4236ac.png
# [File] da0a83f074f3.png
# [File] da1fb35f5df9.png
# [File] daeaa5d8cf70.png
# [File] da9262d9f5d9.png
# [File] db52626d450c.png
# [File] dbd062558b81.png
# [File] daff5427c9b2.png
# [File] dad71ba27a9b.png
# [File] db49cdf1ea64.png
# [File] db4ed1e07aa3.png
# [File] db6207e62c7b.png
# [File] da9574d35b82.png
# [File] d990a3f0cbdb.png
# [File] d8da9de62743.png
# [File] d9ad2a0ec026.png
# [File] d99dd99be001.png
# [File] d8cdb7d7283a.png
# [File] d9bbdc33db83.png
# [File] d881c04f01fe.png
# [File] d911dd40c63b.png
# [File] d88806d9ece9.png
# [File] d94e10f42861.png
# [File] d91635f380b4.png
# [File] d97911a32918.png
# [File] d968a983d4d2.png
# [File] d9ba044671e1.png
# [File] d9c9b9786da3.png
# [File] d99b0f7dd9b9.png
# [File] d952dbfb0fe4.png
# [File] d9a475dfe59a.png
# [File] d91273efb92a.png
# [File] d9311f7497cb.png
# [File] d9d2631f043c.png
# [File] d994203deb64.png
# [File] d95959798b57.png
# [File] d93b61dc8f64.png
# [File] d88c4843aec3.png
# [File] d801c0a66738.png
# [File] d871895742b1.png
# [File] d844a7252f4e.png
# [File] d78b7401096f.png
# [File] d83d0695e215.png
# [File] d866c26d76f0.png
# [File] d803598dabda.png
# [File] d83c3efade75.png
# [File] d7bc62d60e8c.png
# [File] d7ac4a0c9760.png
# [File] d85a842d20bd.png
# [File] d838d5b9f571.png
# [File] d85ea1220a03.png
# [File] d81338217fc5.png
# [File] d7a01fca9838.png
# [File] d81b6ed83bc2.png
# [File] d85d052900b4.png
# [File] d8404680bba6.png
# [File] d807c53c1399.png
# [File] d7e5fe5245e0.png
# [File] d868acdccb5b.png
# [File] d865997a6280.png
# [File] d85588ff2ebd.png
# [File] d7ab5c040294.png
# [File] d7bc00091cfc.png
# [File] d74ccc796517.png
# [File] d774692d9919.png
# [File] d7078e8b0349.png
# [File] d6f36ec5564a.png
# [File] d6f6bdfd8011.png
# [File] d6e26fe51dce.png
# [File] d6b109c82067.png
# [File] d6df4fe492ec.png
# [File] d6dbb0820ea5.png
# [File] d66ccb75ada1.png
# [File] d67374d3fa2a.png
# [File] d6803e467592.png
# [File] d69698f838db.png
# [File] d66b6f333dc7.png
# [File] d667af5742f6.png
# [File] d659d7fd5ccf.png
# [File] d5ad3362424c.png
# [File] d5c63a8d9e94.png
# [File] d56d32a1d62d.png
# [File] d5b4705ac2ee.png
# [File] d6130f2ec903.png
# [File] d567a1a22d33.png
# [File] d57d1be1bbd1.png
# [File] d6228d951958.png
# [File] d51e5d7484ea.png
# [File] d6283ded6aea.png
# [File] d5a39339ff3d.png
# [File] d2c5fb82fe5f.png
# [File] d2ffe9287dc7.png
# [File] d2afca74cbc3.png
# [File] d2901144070c.png
# [File] d2dc86021c67.png
# [File] d3e884109b45.png
# [File] d38cf0f4a9af.png
# [File] d29b37d110f3.png
# [File] d516f77d4516.png
# [File] d2c6b99ef62c.png
# [File] d3e56584a481.png
# [File] d473f6fafba0.png
# [File] d29096bd94aa.png
# [File] d3be5346684b.png
# [File] d2fb715b0c41.png
# [File] d4583e9525dc.png
# [File] d4bc001f7224.png
# [File] d2d523e9f669.png
# [File] d48178e4a49b.png
# [File] d3de0d313d61.png
# [File] d2cd47ed2c1d.png
# [File] d436c06f0490.png
# [File] d364423ec6f9.png
# [File] d332d7b8a26e.png
# [File] d39752cb6e57.png
# [File] d3dfd0a2dee6.png
# [File] d4f32b9c07df.png
# [File] d3d578fe433f.png
# [File] d28bd830c171.png
# [File] d51c2153d151.png
# [File] d41b33fcb94f.png
# [File] d51b3fe0fa1b.png
# [File] d2c2f02bb313.png
# [File] d30d079e6f9a.png
# [File] d4be0403e6ab.png
# [File] d1a60c3b9fe5.png
# [File] d271d3a2b552.png
# [File] d16e59a2b33a.png
# [File] d1ca85af57c9.png
# [File] d16e39b9d6f0.png
# [File] d18b1d8ac4de.png
# [File] d1cf31577a59.png
# [File] d1cad012a254.png
# [File] d18f6431ebce.png
# [File] d1fa0f744620.png
# [File] d1a24527a15d.png
# [File] d1f1ea894da1.png
# [File] d264396d8d1a.png
# [File] d1f7ea924a01.png
# [File] d27ac9e54901.png
# [File] d26bc6e1230d.png
# [File] d16398c971e9.png
# [File] d18e5b68f6d2.png
# [File] d1afdb8cf70d.png
# [File] d18aea8238a0.png
# [File] d25b8a8ad3c4.png
# [File] d26bb2ed6e71.png
# [File] d1b279cc02ae.png
# [File] d160ebef4117.png
# [File] d15ca3469b87.png
# [File] d1fb4efb117c.png
# [File] cff262ed8f4c.png
# [File] cfb17a7cc8d4.png
# [File] d10ef306996b.png
# [File] d0ffa0425ef1.png
# [File] cffc50047828.png
# [File] d0926ed2c8e5.png
# [File] cfd1bd0fcbb4.png
# [File] d02b79fc3200.png
# [File] d0d59ed675b5.png
# [File] d06ccd0cf4b8.png
# [File] cf6551521a35.png
# [File] cfdbaef73a8b.png
# [File] d035c2bd9104.png
# [File] cfed7c1172ec.png
# [File] cf8f1bc7a215.png
# [File] d141728fa392.png
# [File] cf8ae5501bd6.png
# [File] d10d315f123f.png
# [File] d144144a2f3f.png
# [File] d0b132d2c7ec.png
# [File] d0079cc188e9.png
# [File] cd941e5bc659.png
# [File] ce207b69ff37.png
# [File] cd563556cb57.png
# [File] ceaa5803d780.png
# [File] cd972e5639e0.png
# [File] ce754234d760.png
# [File] cf1b9d26d38d.png
# [File] cf0824f53dd9.png
# [File] ce8d2efd9d4f.png
# [File] cf0575534cec.png
# [File] cd93a472e5cd.png
# [File] cd9e2190c73f.png
# [File] ceb32a193eff.png
# [File] cec299c2a2d5.png
# [File] cd8da43e3069.png
# [File] cd54d022e37d.png
# [File] ce887b196c23.png
# [File] cf603a9ef2d5.png
# [File] cd5714db652d.png
# [File] ce6f33a81ad5.png
# [File] ceb601fe8dba.png
# [File] cd66754e1b3b.png
# [File] cca626a0e19a.png
# [File] cc9270f06b65.png
# [File] cd01f4f83336.png
# [File] cd3fd04d72f5.png
# [File] ccd34029493d.png
# [File] cc839823755b.png
# [File] cd1c98ec48b1.png
# [File] ccea49708830.png
# [File] cd45bfa07d41.png
# [File] ccd6dcb2f568.png
# [File] cc964bf04dbc.png
# [File] cd01672507c9.png
# [File] cd314653a4d8.png
# [File] cc671a73e1cb.png
# [File] cd48cfab4e44.png
# [File] cd29c88c9e36.png
# [File] cd4e7f9fa1a9.png
# [File] cb0cc98d7e35.png
# [File] cbc23af521f3.png
# [File] cad5b1a82e60.png
# [File] cac40227d3b2.png
# [File] cb02bb47fdc5.png
# [File] cc1eebed9276.png
# [File] cb39761f0712.png
# [File] cbc2e57447c2.png
# [File] ca9c912ebad7.png
# [File] cb2201c226d6.png
# [File] cac80797770f.png
# [File] cb68fce07789.png
# [File] cb75210abebe.png
# [File] cab3dfa7962d.png
# [File] cb28adab4e8a.png
# [File] cae51154e1ce.png
# [File] cbf0394039f8.png
# [File] cb2f3c5d71a7.png
# [File] cc3d2e961768.png
# [File] cbd0870aa933.png
# [File] cb602182cde3.png
# [File] cadde4030858.png
# [File] cbe633765ea7.png
# [File] cae33655ca00.png
# [File] cc12453ea915.png
# [File] caec68f11c86.png
# [File] cb547e723a16.png
# [File] c947bb6cf9f6.png
# [File] ca7570c5925c.png
# [File] ca7f5caddf96.png
# [File] ca30a97e9d13.png
# [File] ca0f1a17c8e5.png
# [File] c9f0dc2c8b43.png
# [File] c98f623d08d1.png
# [File] c97472ef2c66.png
# [File] ca360bec5851.png
# [File] c9485c38fdd5.png
# [File] ca63fe4f4b52.png
# [File] c94f37085d0f.png
# [File] c9ea9d5eab65.png
# [File] ca891d37a43c.png
# [File] c8fc0df22999.png
# [File] c90c6b94cf40.png
# [File] ca05f7e7801b.png
# [File] ca1036496659.png
# [File] ca6842bfcbc9.png
# [File] c96f743915b5.png
# [File] c9e697117f3f.png
# [File] c9d42d7534e0.png
# [File] ca25745942b0.png
# [File] ca7140ecf389.png
# [File] c8d2d32f7f29.png
# [File] c9c563864ab1.png
# [File] ca2b54b95ade.png
# [File] c739ff9580d3.png
# [File] c81c6911f5e0.png
# [File] c80f79579fed.png
# [File] c8a3eb9a5b52.png
# [File] c8905b8d5cf1.png
# [File] c7b622ec8104.png
# [File] c755a0c4edcc.png
# [File] c7d0deb71576.png
# [File] c85b79d70079.png
# [File] c87493ed320c.png
# [File] c7c0470bcf87.png
# [File] c7e827fc7f41.png
# [File] c8823cdaf7fa.png
# [File] c80b0f27541a.png
# [File] c73c5f6ef664.png
# [File] c76664770c07.png
# [File] c7c3d363bc86.png
# [File] c6916bc42016.png
# [File] c6f5b5b5be41.png
# [File] c6229222bf22.png
# [File] c6d4e4a3bd4c.png
# [File] c6a145742708.png
# [File] c6e1e9fbf39b.png
# [File] c64c0966b4cf.png
# [File] c6a2975228af.png
# [File] c639d837f5e4.png
# [File] c67117c6ab3b.png
# [File] c70d09370109.png
# [File] c62cef02efa2.png
# [File] c62585bd68fb.png
# [File] c704bd669f36.png
# [File] c6c2bad91f23.png
# [File] c613db1cab27.png
# [File] c68dfa021d62.png
# [File] c6a8f8f998a2.png
# [File] c5ad60521f8c.png
# [File] c546670d9684.png
# [File] c5a9ebef1517.png
# [File] c5e238aa18be.png
# [File] c568e5245ea5.png
# [File] c58971bcebb2.png
# [File] c5a6f432a1ec.png
# [File] c5a0e84e955d.png
# [File] c5431b81cbc9.png
# [File] c561bcd519e9.png
# [File] c597ef460944.png
# [File] c56e65f74187.png
# [File] c58e5c0c5b33.png
# [File] c56293f53191.png
# [File] c57c164bca05.png
# [File] c5bec7f1e5f3.png
# [File] c5ba9e455d5e.png
# [File] c5b58cc992af.png
# [File] c52bb7343387.png
# [File] c48ae5da188e.png
# [File] c3789c1dab96.png
# [File] c373b73a80c8.png
# [File] c406325360b1.png
# [File] c3e02d4a1798.png
# [File] c4a8f2fcf6e8.png
# [File] c3acf47700ea.png
# [File] c3c8fdda50c0.png
# [File] c3d12a23f451.png
# [File] c3b15bf9b4bc.png
# [File] c3cd0200df79.png
# [File] c3aa424eff9a.png
# [File] c38dec54a9f7.png
# [File] c4aef0d88d1b.png
# [File] c446985355f1.png
# [File] c4e8b1ec8893.png
# [File] c40976189f22.png
# [File] c3a82acb7d7a.png
# [File] c280730cc211.png
# [File] c12e9ca420a5.png
# [File] c2d2b4f536da.png
# [File] c1e6fa1ad314.png
# [File] c2a58b2cfd0b.png
# [File] c1ebe785503a.png
# [File] c31651ea04c6.png
# [File] c21eb81de9fc.png
# [File] c24bcf7a1bc4.png
# [File] c261b1aaa828.png
# [File] c26f98f58350.png
# [File] c1437a7a52c9.png
# [File] c1c8550508e0.png
# [File] c102db7634d8.png
# [File] c1896142a20a.png
# [File] c334f8688b77.png
# [File] c18a006f7f1d.png
# [File] c2f3281cf528.png
# [File] c252da9b41d8.png
# [File] c365c598ad4e.png
# [File] c25e02b39c01.png
# [File] c1799a6f5c65.png
# [File] c1819db0aece.png
# [File] c23ff6dcf15e.png
# [File] c013e869acce.png
# [File] c027e5482e8c.png
# [File] c0e509786f7f.png
# [File] c0968d41eb93.png
# [File] c06024f05a16.png
# [File] bff51afc76d4.png
# [File] c0202976c670.png
# [File] c0e15e8e2b46.png
# [File] c01eae4b4939.png
# [File] c0f15fe3b4b7.png
# [File] c0a117de7d0a.png
# [File] bffca6eeb2bf.png
# [File] c096131ad065.png
# [File] c0a0828e01b4.png
# [File] c05b7b4c22fe.png
# [File] bfdee9be1f1d.png
# [File] bebfbd907cac.png
# [File] bf1b7e21e774.png
# [File] bed8296c8dfe.png
# [File] beb00fa6e7c9.png
# [File] bfa30ebf63a8.png
# [File] bec0acd539b2.png
# [File] bf8092e4001d.png
# [File] bfd5c0e55420.png
# [File] be8697eb2078.png
# [File] beeca5f14618.png
# [File] beb2ad14fd2d.png
# [File] bfaa0080ab61.png
# [File] bf18ff30a8f6.png
# [File] bf7b4eae7ad0.png
# [File] be7f791a7877.png
# [File] bf6cbccacf39.png
# [File] bf9cba745efc.png
# [File] bfb578c0e8d8.png
# [File] bf87aedf2489.png
# [File] bfefa7344e7d.png
# [File] bf811911acf9.png
# [File] bf7221a016b5.png
# [File] bfda2fd0533a.png
# [File] bf7047dc683c.png
# [File] bebb3f167654.png
# [File] bfe467b7e997.png
# [File] bdc6c60e9133.png
# [File] bdb98063fe84.png
# [File] be161517d3ac.png
# [File] be521870a0ea.png
# [File] be7bc89f5fec.png
# [File] bde1063a5dd7.png
# [File] bdff5d8bddf8.png
# [File] bd500a73beae.png
# [File] bda91b76095b.png
# [File] bd34a0639575.png
# [File] be6cbf6e5b10.png
# [File] bd269a1f0e4d.png
# [File] be21d8b60e2a.png
# [File] bda8c973b09d.png
# [File] bda7ff3b1562.png
# [File] be197b663520.png
# [File] be68322c7223.png
# [File] bd9904495ccd.png
# [File] bdf47b9f10c4.png
# [File] bd375ba756b1.png
# [File] bd5013540a13.png
# [File] be3a7d9e981e.png
# [File] bba38f2294a3.png
# [File] bac1744955c2.png
# [File] bc34f52c37c7.png
# [File] bb08949dd70a.png
# [File] bcd503c726ba.png
# [File] bca2bdc15fc5.png
# [File] bb9a3d835a94.png
# [File] bcb0498ed2c1.png
# [File] bc73ce76ec43.png
# [File] bc34ed91c9bc.png
# [File] bc23f74e14dd.png
# [File] bb7e0a2544cd.png
# [File] bb11db08584a.png
# [File] bc7bf19b84e3.png
# [File] bb2f89488ecd.png
# [File] bc92a61a1f9c.png
# [File] bcc762618e7d.png
# [File] bacfa2b8e706.png
# [File] bacfb1029f6b.png
# [File] bb45257258cc.png
# [File] bd06028eb7dd.png
# [File] bb85097857fa.png
# [File] bb733062f494.png
# [File] badb5ff8d3c7.png
# [File] bc8c6a778cde.png
# [File] bb783d8e496f.png
# [File] bcdc8db5423b.png
# [File] bb5083fae98f.png
# [File] bb752b179751.png
# [File] b9b6ee2b9453.png
# [File] ba25f947f4ec.png
# [File] baaca2f7e1f0.png
# [File] b98f77098b9d.png
# [File] b9fe7da14a32.png
# [File] ba735b286d62.png
# [File] ba4d2c4b3039.png
# [File] ba4e62c11cc0.png
# [File] ba2624883599.png
# [File] b9b99dad668d.png
# [File] ba2ea9182090.png
# [File] b9bc81fcb075.png
# [File] b99c825b93c5.png
# [File] bab776139279.png
# [File] b99afe7137fb.png
# [File] b99794a0beed.png
# [File] ba0107fb1bfd.png
# [File] b9d0b83d70c3.png
# [File] b9c7c5182075.png
# [File] ba08cee68c71.png
# [File] b90bc89ce8d8.png
# [File] b96b518596b3.png
# [File] b94c58d063bf.png
# [File] b927a9238434.png
# [File] b9519abce0c1.png
# [File] b8fb9f55cd6d.png
# [File] b95d4dd8e5e2.png
# [File] b8e20c076b03.png
# [File] b87f9c59748b.png
# [File] b8f1b30877db.png
# [File] b963a11638f2.png
# [File] b8dab47a260e.png
# [File] b8ebedd382de.png
# [File] b8ac328009e0.png
# [File] b91ef82e723a.png
# [File] b9127e38d9b9.png
# [File] b89938407ee6.png
# [File] b960142a8de7.png
# [File] b8e9a8f4617d.png
# [File] b92eacd1392a.png
# [File] b86fb2d5be1a.png
# [File] b83a6eca125f.png
# [File] b82dfa63a75f.png
# [File] b835b6e31a59.png
# [File] b842b43cb7fb.png
# [File] b82d5f1f1145.png
# [File] b8297a2291f5.png
# [File] b7f0bc7d399e.png
# [File] b72f59b85f7c.png
# [File] b6a0e348a01e.png
# [File] b7a1bb106051.png
# [File] b7aca95b97b9.png
# [File] b6bf847fbcb2.png
# [File] b72a86d61959.png
# [File] b6bfe9db60e5.png
# [File] b70cb31b9abb.png
# [File] b759cbef90c5.png
# [File] b77b8a1f09f1.png
# [File] b7bd4a6627b6.png
# [File] b74de20d73de.png
# [File] b70e7c26f51e.png
# [File] b746a6681ba9.png
# [File] b7ce561a7328.png
# [File] b77b88926843.png
# [File] b71428739d4e.png
# [File] b6d9974443ce.png
# [File] b7983cb3f270.png
# [File] b73d0bcd3d33.png
# [File] b762c29cf2f3.png
# [File] b7278b4f2448.png
# [File] b6fd109b1bc9.png
# [File] b7e0f95353f2.png
# [File] b640e3bdff75.png
# [File] b665041e1633.png
# [File] b69c224edd6e.png
# [File] b65ff67743b2.png
# [File] b6304c545f95.png
# [File] b66f23ffa730.png
# [File] b60dbf9f0744.png
# [File] b67ae80f7eba.png
# [File] b64e1eef3d63.png
# [File] b5834ee64541.png
# [File] b43440c6ebe4.png
# [File] b468ebf5cb11.png
# [File] b576c5269ad1.png
# [File] b5bf7b84fc66.png
# [File] b50b30aa6e6c.png
# [File] b56340f472d2.png
# [File] b5204c0decc7.png
# [File] b4f41b5bf0ef.png
# [File] b4b04d81acbb.png
# [File] b574d229ec4c.png
# [File] b5b913358b32.png
# [File] b402daa0864c.png
# [File] b49b2fac2514.png
# [File] b498b84d383f.png
# [File] b553e7909535.png
# [File] b4e15102cd7a.png
# [File] b5a3ca5c0a80.png
# [File] b5c80d0ed0ff.png
# [File] b532dedd928c.png
# [File] b402b18d99a5.png
# [File] b3f31c371e59.png
# [File] b55d2ddb3e75.png
# [File] b3d135bd3bb5.png
# [File] b5e6ae31493c.png
# [File] b46b09a45f39.png
# [File] b598bc9753c2.png
# [File] b460ca9fa26f.png
# [File] b549af91bd30.png
# [File] b3c0c3330278.png
# [File] b3a994760537.png
# [File] b3819a805dca.png
# [File] b3d12069e1c5.png
# [File] b2b79b37d314.png
# [File] b37aae3c8fe1.png
# [File] b310bd564329.png
# [File] b2748ac28fc1.png
# [File] b35cad8fe2d7.png
# [File] b2aaa81cc8f0.png
# [File] b22cc1bf0b8a.png
# [File] b351ae99413a.png
# [File] b2b7ccd34cbd.png
# [File] b294927b14b0.png
# [File] b1f4122fd36a.png
# [File] b200c23b299b.png
# [File] b376def52ccc.png
# [File] b22354b5f94b.png
# [File] b2ffa3e18559.png
# [File] b21abe5d9722.png
# [File] b1b3e7d0a5f3.png
# [File] b191ba0a2b12.png
# [File] b1c6f0997e27.png
# [File] b085caa513a8.png
# [File] b033ab4fb723.png
# [File] b019a49787c1.png
# [File] b187b3c93afb.png
# [File] b0acd3593310.png
# [File] b11dcdcbc8c8.png
# [File] af8aa32beee4.png
# [File] b06dabab4f09.png
# [File] b0f8613305a3.png
# [File] b17f0b81dab3.png
# [File] b0eeae01b8ab.png
# [File] b0b3b16fc305.png
# [File] b13d72ceea26.png
# [File] b0619ca93a5f.png
# [File] b09101adb478.png
# [File] afc744fad65e.png
# [File] afc345cc9145.png
# [File] b0d6417bad3e.png
# [File] b0d35981708b.png
# [File] b1197f2cc9b3.png
# [File] b07bc463b718.png
# [File] b10fca20c885.png
# [File] b05922e7abd3.png
# [File] b086c7cd3868.png
# [File] b0cc9f8d06e4.png
# [File] b16dd4483ca5.png
# [File] b0f0fa677d5f.png
# [File] af87d48ffe01.png
# [File] b0c9a492e068.png
# [File] aeccef0bdc26.png
# [File] ae94ce412de9.png
# [File] aea59ebec445.png
# [File] aef9016557ca.png
# [File] ae20112e7a1e.png
# [File] af7a36454670.png
# [File] ae8424cdb029.png
# [File] af3b0115aad1.png
# [File] af831c158744.png
# [File] ae57c8630249.png
# [File] ae61e19fb766.png
# [File] aed4e743c230.png
# [File] addf66a50f42.png
# [File] aeb6f4fd2eed.png
# [File] af133a85ea0c.png
# [File] aec51513cf45.png
# [File] af6166d57f13.png
# [File] ae2e888905ba.png
# [File] ae1344610ebe.png
# [File] ae8472f8d310.png
# [File] aeed1f251ceb.png
# [File] ae2c3f6312ef.png
# [File] af6a1508cd95.png
# [File] ae49cc60f251.png
# [File] af5a0bc4e1fa.png
# [File] ae5d31979f19.png
# [File] ae58ccb5905e.png
# [File] af828dab3ffc.png
# [File] aebe87a423c8.png
# [File] af345c68e836.png
# [File] aeab0a63bcaf.png
# [File] ae975c43bd8b.png
# [File] ad93d88c87ea.png
# [File] ad944bd56bb6.png
# [File] ad570b850a4f.png
# [File] adb56cecafaf.png
# [File] add1d681d712.png
# [File] ad6b07d5c338.png
# [File] ad2f0b9d059c.png
# [File] ad312ca98202.png
# [File] ad20080452de.png
# [File] ad3fc5076852.png
# [File] ad1f7445b1a8.png
# [File] ad029ba7fa8b.png
# [File] acc9f29538c4.png
# [File] aca88f566228.png
# [File] ace2281f00c4.png
# [File] ad1aa75d5630.png
# [File] ace287a5c991.png
# [File] acf976efd7ce.png
# [File] ad12cde115ab.png
# [File] ac720570dd0f.png
# [File] ac81fc200162.png
# [File] abf0f56c6f12.png
# [File] ac5b5dddf91b.png
# [File] ac17cc18a994.png
# [File] ac1667fac512.png
# [File] ac2c814949f9.png
# [File] ac0a48ccbf70.png
# [File] ababe19ed448.png
# [File] abf09c44d5f4.png
# [File] abbb8791785e.png
# [File] abe940882578.png
# [File] abdb365cacbc.png
# [File] aba3063c5413.png
# [File] ab686895533e.png
# [File] ab653b8554c0.png
# [File] ab88081e5654.png
# [File] ab32db41c409.png
# [File] ab7991df166b.png
# [File] ab1c20a94f3f.png
# [File] ab78a66dee6a.png
# [File] ab3c505b624f.png
# [File] ab50123abadb.png
# [File] ab03d50bba2f.png
# [File] ab724603ee93.png
# [File] aafb0c944f14.png
# [File] aafe980edd0c.png
# [File] aa841de1ee82.png
# [File] aaaadb174012.png
# [File] aa9cfe639ef1.png
# [File] aabd867043cf.png
# [File] aa9b8f05f4bf.png
# [File] aa94cc4bfd84.png
# [File] aad0c0ee9268.png
# [File] aae8f9f3ef8c.png
# [File] aa8a1e814811.png
# [File] aa6673241154.png
# [File] aa5ce75edcf5.png
# [File] aa6242f9e08c.png
# [File] aa60813e1a8d.png
# [File] aa4407aab872.png
# [File] a9dc80cba9a4.png
# [File] a9c7b83caf81.png
# [File] a9e984b57556.png
# [File] aa10a4b2e709.png
# [File] aa0afc41ed19.png
# [File] aa31bc6b8f4d.png
# [File] a9e3d186cd1b.png
# [File] a9d0c900b6a9.png
# [File] a9a28c37c8c4.png
# [File] a9b3177f01c0.png
# [File] a9bc2f892cb3.png
# [File] a987aa7aac37.png
# [File] a9a3225cf4b5.png
# [File] a96ff96bbae5.png
# [File] a8eb35b3bcd2.png
# [File] a95858e052d6.png
# [File] a93f1ea3ff4a.png
# [File] a95d9d61ddd4.png
# [File] a963ac561580.png
# [File] a94da3d3b5c0.png
# [File] a8c9fcdbc0be.png
# [File] a8c950a99107.png
# [File] a8dea22ef903.png
# [File] a8e88d4891c4.png
# [File] a8e08e7fe016.png
# [File] a8c54e2a4b79.png
# [File] a8b3c0961d42.png
# [File] a8b637abd96b.png
# [File] a88f68b0b114.png
# [File] a8a6588c8eb7.png
# [File] a8aed92940fb.png
# [File] a879c3569552.png
# [File] a86c6283fd78.png
# [File] a88365134c3c.png
# [File] a87f53bc984a.png
# [File] a8854768549f.png
# [File] a8263d248523.png
# [File] a86128b601a7.png
# [File] a82a12ad3fb1.png
# [File] a8582e346df0.png
# [File] a8652b2de23f.png
# [File] a85cda5f725d.png
# [File] a821b6ecef33.png
# [File] a80dab8eddf4.png
# [File] a81b06f50612.png
# [File] a804cef3e51f.png
# [File] a7ec056502e7.png
# [File] a7b7dc8788b9.png
# [File] a7c10ca6c117.png
# [File] a7b0d0c51731.png
# [File] a77eb914b383.png
# [File] a77dbec966d4.png
# [File] a7b03e58a6e1.png
# [File] a790a3b36390.png
# [File] a6c9e96a10d7.png
# [File] a7673ac44509.png
# [File] a76132e79688.png
# [File] a75bab2463d4.png
# [File] a763661f98a5.png
# [File] a721efb1e049.png
# [File] a6d45de20e4d.png
# [File] a66c3165876f.png
# [File] a664d2055886.png
# [File] a73c3d516c59.png
# [File] a73d012c4c38.png
# [File] a6731dd737af.png
# [File] a673193cd5a9.png
# [File] a688f20f8895.png
# [File] a70d0f12a641.png
# [File] a6b6d27c1b32.png
# [File] a76b69e443ce.png
# [File] a505981d1cab.png
# [File] a53d6d2472a6.png
# [File] a49b0b4484ea.png
# [File] a56230242a95.png
# [File] a4b8de38eac1.png
# [File] a5bb85afc6e8.png
# [File] a4ee03ecff60.png
# [File] a484bdf85b4c.png
# [File] a62ea0043aa7.png
# [File] a5c9a8c726b2.png
# [File] a62e995f167c.png
# [File] a47432cd41e7.png
# [File] a6356a3c5d11.png
# [File] a5a2a7003d60.png
# [File] a64273801bde.png
# [File] a654b25124c3.png
# [File] a4d4b69f7404.png
# [File] a476fd984005.png
# [File] a627eb8c08c5.png
# [File] a4d41c495666.png
# [File] a61723fc38c2.png
# [File] a45d77edf8d9.png
# [File] a528be013a04.png
# [File] a47878630dc2.png
# [File] a56729de89e9.png
# [File] a646c084928c.png
# [File] a3475dc3ac80.png
# [File] a386ec9aabde.png
# [File] a28bfb772f50.png
# [File] a3bd2e034614.png
# [File] a2d349f567a6.png
# [File] a2811f512c1c.png
# [File] a32b5ce3d48a.png
# [File] a3fcf42ff56d.png
# [File] a44345b27804.png
# [File] a34fc5376669.png
# [File] a3ad6c2db6f1.png
# [File] a3957df90a78.png
# [File] a45c30da0c72.png
# [File] a2dff8dbc9f8.png
# [File] a2b97d98f130.png
# [File] a3706ce27869.png
# [File] a32886cb31ab.png
# [File] a4359815f152.png
# [File] a4012932e18d.png
# [File] a443c4fd489c.png
# [File] a30a143a53a3.png
# [File] a3802934bad7.png
# [File] a384e688e228.png
# [File] a2b995b81692.png
# [File] a3d2a0c4cd17.png
# [File] a3132c8828e4.png
# [File] a2ddabee14e9.png
# [File] a419fcb2dfb5.png
# [File] a2ad3da4c7d6.png
# [File] a3b2e93d058b.png
# [File] a2696f444ecb.png
# [File] a1eb88562239.png
# [File] a15590a7d774.png
# [File] a1822dd8d05d.png
# [File] a1edf0e66592.png
# [File] a1b12fdce6c3.png
# [File] a15652b22ab8.png
# [File] a19507501b40.png
# [File] a14fcf84bfe1.png
# [File] a188c60b93fb.png
# [File] a1b28bcbce00.png
# [File] a15470303941.png
# [File] a21b37719f9b.png
# [File] a182b5b191de.png
# [File] a247961a5cd9.png
# [File] a19ecd0a706e.png
# [File] a1faeb4d5f10.png
# [File] a2163f0c2af5.png
# [File] a26f50218b84.png
# [File] a1e236fbc863.png
# [File] a1872f9c0cba.png
# [File] a150ff5dfe07.png
# [File] a02dfd67a925.png
# [File] a0adbe677508.png
# [File] a0d04a19cf40.png
# [File] a11bf2edd470.png
# [File] a0cd7bffdaa0.png
# [File] a06a63d866b2.png
# [File] a14bbd9a583e.png
# [File] a11c62cb3f86.png
# [File] a07efb1ecfc0.png
# [File] a06b353e7bed.png
# [File] a0e635689259.png
# [File] a0a0cd8af5a6.png
# [File] a0fd94e2ad76.png
# [File] a0445785e2f7.png
# [File] a07d9a5045cb.png
# [File] a07d571bf7ba.png
# [File] a125377fb985.png
# [File] a04fb36db784.png
# [File] a06e5ac695ce.png
# [File] a0267206d51e.png
# [File] a12ca80bb8c7.png
# [File] a0b7ad98df57.png
# [File] a08a0133754a.png
# [File] a06e41bd2634.png
# [File] 9f8112c710be.png
# [File] 9e99ae6ee7af.png
# [File] a015ce4f51ad.png
# [File] 9f5a8665cf2e.png
# [File] a01024054596.png
# [File] 9e7a63b2fc6a.png
# [File] 9ed6c2b25767.png
# [File] 9f1efb799b7b.png
# [File] 9faad91b6578.png
# [File] 9e3510963315.png
# [File] 9f285b3e57ed.png
# [File] a00b4cb250a7.png
# [File] 9e2a8135f471.png
# [File] 9f37c98b8187.png
# [File] 9f436886e056.png
# [File] 9eaac43744f5.png
# [File] 9df31421cdd2.png
# [File] 9fa02dfb5553.png
# [File] 9f1b14dfa14c.png
# [File] 9e2058917304.png
# [File] 9f4132bd6ed6.png
# [File] a01c590c444f.png
# [File] 9fefe2b44795.png
# [File] 9f935fb38440.png
# [File] 9ed666e982cd.png
# [File] 9fab29e69a6b.png
# [File] 9e5737f771c3.png
# [File] 9e2ba2b979f1.png
# [File] 9eaf735cf01f.png
# [File] 9e5ec293267c.png
# [File] 9d75de31f1b8.png
# [File] 9d74428188bb.png
# [File] 9d98a0b585f2.png
# [File] 9de9421f17e3.png
# [File] 9da74370835a.png
# [File] 9d9bfefa809c.png
# [File] 9dab2e6ba44b.png
# [File] 9be0683649ff.png
# [File] 9b95d6203406.png
# [File] 9bf060db8376.png
# [File] 9cf7c1349673.png
# [File] 9c72ed6befa0.png
# [File] 9be71d6d7e59.png
# [File] 9b418ce42c13.png
# [File] 9c514d2d5b3f.png
# [File] 9c088d2d1559.png
# [File] 9c14ce27cbfc.png
# [File] 9c5dd3612f0c.png
# [File] 9cedf5c7016b.png
# [File] 9b70f84400af.png
# [File] 9c52b87d01f1.png
# [File] 9cc6b1f9bcbd.png
# [File] 9ba469af2980.png
# [File] 9d1feed37610.png
# [File] 9ce46d400cd6.png
# [File] 9c893e16c055.png
# [File] 9bbb6c455913.png
# [File] 9b4fc15df3c8.png
# [File] 9d62478042b6.png
# [File] 9b32e8ef0ca0.png
# [File] 9bafbbd152d2.png
# [File] 9b57e43b44e7.png
# [File] 9c6512166557.png
# [File] 9b7b6e4db1d5.png
# [File] 9bd008aab548.png
# [File] 9a9b21215c55.png
# [File] 9a496b1e20f9.png
# [File] 9a28d4e8aef0.png
# [File] 9ae54843c69a.png
# [File] 9ac2e3e9fca5.png
# [File] 9a1029536d78.png
# [File] 9a3c03a5ad0f.png
# [File] 9ac41b9a809e.png
# [File] 9a7bd084395e.png
# [File] 9a159d4674cd.png
# [File] 9ad92f1c1542.png
# [File] 9a3109657ac1.png
# [File] 9a78c6a7b1c2.png
# [File] 99ecdb41d5e7.png
# [File] 9ab18a4a957f.png
# [File] 9a326446c431.png
# [File] 9a4f370d341b.png
# [File] 9b093fe95d6b.png
# [File] 9a94e0316ee3.png
# [File] 9a56cfb980ec.png
# [File] 9b0eb9f41da4.png
# [File] 9904939ab83d.png
# [File] 992b9a07b25f.png
# [File] 98f7136d2e7a.png
# [File] 996f57c86ba5.png
# [File] 9910c827e2fe.png
# [File] 99132193eaa0.png
# [File] 99c626e58464.png
# [File] 991a0b7a8c87.png
# [File] 99240ee00485.png
# [File] 98fbe56dcc2c.png
# [File] 996f9bba4ef0.png
# [File] 98e44127872f.png
# [File] 999115d9386b.png
# [File] 99e8bf998285.png
# [File] 992599744a23.png
# [File] 9878db94d9f3.png
# [File] 99c6a123ed6a.png
# [File] 9985375d709f.png
# [File] 999ad827ed35.png
# [File] 98d41bce73a8.png
# [File] 98f48850ebce.png
# [File] 98e8adcf085c.png
# [File] 98441214557f.png
# [File] 9870ce41cac4.png
# [File] 98104c8c67eb.png
# [File] 97fdee242fea.png
# [File] 9859e2a6cc24.png
# [File] 97f290d31813.png
# [File] 9858cc2ae073.png
# [File] 983c98354e9c.png
# [File] 97da093947e8.png
# [File] 98277aeb96a7.png
# [File] 9837048b85dc.png
# [File] 97a5ad7548b7.png
# [File] 977e1ca77653.png
# [File] 971bb98ab935.png
# [File] 96793edb1003.png
# [File] 962cf85e4f6d.png
# [File] 9785805af1b8.png
# [File] 974c7d7b9c64.png
# [File] 96ea316ed0ab.png
# [File] 975252e325e3.png
# [File] 9782c0489eca.png
# [File] 96ce10a1dbd7.png
# [File] 973b0facfa9b.png
# [File] 962c0fc85e13.png
# [File] 96d48b073f18.png
# [File] 97c6cb55866d.png
# [File] 96c699221180.png
# [File] 96a9706b8534.png
# [File] 97bf61736b86.png
# [File] 976082127e2a.png
# [File] 95e732e043a1.png
# [File] 97d02a9b94f7.png
# [File] 966c07831334.png
# [File] 96b5474ae604.png
# [File] 97a235367f9d.png
# [File] 95a4cc805c7b.png
# [File] 969f92a390db.png
# [File] 9688c6ef5dc5.png
# [File] 96c3e3db68bc.png
# [File] 94076a9fb9b5.png
# [File] 94372043d55b.png
# [File] 92d9e9f08709.png
# [File] 94ef1d14597f.png
# [File] 92e3d608fd3c.png
# [File] 958c1fa044ba.png
# [File] 94b1d8ad35ec.png
# [File] 949710bead24.png
# [File] 959bb2d01091.png
# [File] 946545473380.png
# [File] 956765d5f46d.png
# [File] 959dc602febc.png
# [File] 93d6d20a5ee3.png
# [File] 937bc1b924b1.png
# [File] 941d874c8afb.png
# [File] 94dcb491143f.png
# [File] 92fcf50b3562.png
# [File] 94145d1f42cf.png
# [File] 944a233fbf8e.png
# [File] 9568eb7e9c08.png
# [File] 94a67ec0714f.png
# [File] 932181b93b2f.png
# [File] 936299166bea.png
# [File] 94b9ccc73bb9.png
# [File] 934104859e68.png
# [File] 93be637084a2.png
# [File] 93421787f520.png
# [File] 92f313287a29.png
# [File] 9519a590985d.png
# [File] 94f9ecf4b8d2.png
# [File] 93802d1e3c41.png
# [File] 93a1b984de84.png
# [File] 94111ed3d276.png
# [File] 930fee99213a.png
# [File] 942f544c4e15.png
# [File] 9274e75dc4d5.png
# [File] 91b6ebaa3678.png
# [File] 921433215353.png
# [File] 922586d86cd8.png
# [File] 9287e57326d0.png
# [File] 92889b863ae6.png
# [File] 9232dc06cfdc.png
# [File] 917f76f360b6.png
# [File] 92587e494d51.png
# [File] 91e82fe4e434.png
# [File] 91f3c4c1e72b.png
# [File] 91b7a4179ecf.png
# [File] 91e8af9ceee9.png
# [File] 929cd3867815.png
# [File] 91cbe1c775ef.png
# [File] 91a88d3b0358.png
# [File] 91cf56d3d1af.png
# [File] 92d8a7c8e718.png
# [File] 91e2c2890c9f.png
# [File] 92b0d27fc0ec.png
# [File] 905cc86bf100.png
# [File] 904b03ad5594.png
# [File] 8ffa608170d3.png
# [File] 9039cbfcbb2f.png
# [File] 8ff863f8874f.png
# [File] 907aaff827e5.png
# [File] 901a3552fe26.png
# [File] 90a786abe58e.png
# [File] 8ff2733f6aef.png
# [File] 90a9a41eec6d.png
# [File] 913b1890ed1e.png
# [File] 9122b31414d3.png
# [File] 9033f1493da1.png
# [File] 916915f01e17.png
# [File] 9041eb43456e.png
# [File] 913490237ad4.png
# [File] 912fbe06407e.png
# [File] 910bfd38e2f5.png
# [File] 90960ddf4d14.png
# [File] 916ec976ff30.png
# [File] 9095d43fb132.png
# [File] 90bde2ff8953.png
# [File] 90b8bf342032.png
# [File] 902dc5a91a3f.png
# [File] 90c982cc2d96.png
# [File] 906d02fb822d.png
# [File] 8eb3337a54e9.png
# [File] 8f9819752ca0.png
# [File] 8e6df9eedcd8.png
# [File] 8f2996b8d855.png
# [File] 8f14bca04b47.png
# [File] 8eeac97f02f0.png
# [File] 8ed586c43023.png
# [File] 8e7981855125.png
# [File] 8fc09fecd22f.png
# [File] 8ee50c26fc13.png
# [File] 8f318a978844.png
# [File] 8f06ca4642bd.png
# [File] 8f1e7433a95d.png
# [File] 8ead17dfb6a6.png
# [File] 8fd7ad26e691.png
# [File] 8fbb2ca39911.png
# [File] 8ead8f37423c.png
# [File] 8f10e41a2f02.png
# [File] 8e76054f0831.png
# [File] 8ef2eb8c51c4.png
# [File] 8e63fc4ab532.png
# [File] 8d3d67661620.png
# [File] 8dc22e65c06f.png
# [File] 8d13c46e7d75.png
# [File] 8cb6b5b2f19c.png
# [File] 8e4a354e3da2.png
# [File] 8e67f2d7e0ee.png
# [File] 8e3b79e1f1f7.png
# [File] 8c84e96d9b01.png
# [File] 8e20b8fac7c3.png
# [File] 8d9516ea3587.png
# [File] 8e2a3978c244.png
# [File] 8db2ce991101.png
# [File] 8ceff4c4c860.png
# [File] 8dafa62f9322.png
# [File] 8d8aca52c07b.png
# [File] 8d7bb0649a02.png
# [File] 8c87bd748996.png
# [File] 8dba09a4e5ed.png
# [File] 8cb6b0efaaac.png
# [File] 8d4ff745a409.png
# [File] 8d4d14a4ab07.png
# [File] 8dfa629ca74e.png
# [File] 8dfff47b06b7.png
# [File] 8d62ba9cb22a.png
# [File] 8c0d05233238.png
# [File] 8c4ceddeb1c6.png
# [File] 8bf05909e1e1.png
# [File] 8be6629a6039.png
# [File] 8c2f0f04e1ed.png
# [File] 8bdb891661a8.png
# [File] 8c7c26c52a6c.png
# [File] 8bed09514c3b.png
# [File] 8bf2d925dc0c.png
# [File] 8bc6716c2238.png
# [File] 8c29a76fa08c.png
# [File] 8b568d47a1fd.png
# [File] 8bad12d70368.png
# [File] 8b8fe3fc8950.png
# [File] 8b76c3c5cb3e.png
# [File] 8b58f9a338e8.png
# [File] 8bbd7835e9aa.png
# [File] 8b26d3cd61e8.png
# [File] 8a67f1efa315.png
# [File] 8ae049175db6.png
# [File] 8a759f94613a.png
# [File] 8af6a4e5396f.png
# [File] 8ab8d9b3ce3f.png
# [File] 8aab201c0691.png
# [File] 8a9bef2fbd4e.png
# [File] 8af50c9d0a86.png
# [File] 8a81f62320d6.png
# [File] 8ac0c44bbf24.png
# [File] 8a87dd2a784e.png
# [File] 8aa3c4681542.png
# [File] 8acdf12f412a.png
# [File] 8acffaf1f4b9.png
# [File] 8a7765e785fb.png
# [File] 8b079e79035f.png
# [File] 8ab3faa3701f.png
# [File] 8a8a251770cd.png
# [File] 8a482c024fc2.png
# [File] 8a3eb86ae4bd.png
# [File] 8a25a080f28f.png
# [File] 8a234d68b27e.png
# [File] 89fc080f7e83.png
# [File] 8a01daa423f7.png
# [File] 89ee1fa16f90.png
# [File] 89d9c071a56f.png
# [File] 89ed6a0dd53f.png
# [File] 89d2a7403a06.png
# [File] 89b725411cee.png
# [File] 898f0bc8acfa.png
# [File] 89b044cbaf85.png
# [File] 887c26fc0e1f.png
# [File] 8958a4d17b7e.png
# [File] 88e4399d207c.png
# [File] 894a37fc3738.png
# [File] 891392c9683c.png
# [File] 88e5051f65bd.png
# [File] 895fe2bfc5b6.png
# [File] 891329021e12.png
# [File] 8906c9ed54a2.png
# [File] 896ad584a841.png
# [File] 883c6a184f16.png
# [File] 87b1938994b5.png
# [File] 8860c7b11530.png
# [File] 87b671c6d4c5.png
# [File] 8846b09384a4.png
# [File] 880edb2cdb69.png
# [File] 882a71de424e.png
# [File] 8871e6a26596.png
# [File] 87d46b1cc4e9.png
# [File] 881ec6186e68.png
# [File] 885fa5fc5da8.png
# [File] 883ddb650967.png
# [File] 878e356c8fc9.png
# [File] 879744b9dc65.png
# [File] 87a9f4d20f07.png
# [File] 8785b71238d8.png
# [File] 878a3a097436.png
# [File] 87774aafe068.png
# [File] 876e1dd12d38.png
# [File] 875a2fc5fe23.png
# [File] 875d2ffcbf47.png
# [File] 876deb29f000.png
# [File] 874f8c1929f6.png
# [File] 873fe0404d6e.png
# [File] 873dcc0b468f.png
# [File] 86fbac86ed3e.png
# [File] 870f433e8f37.png
# [File] 86d6808f0609.png
# [File] 8714d17bb6da.png
# [File] 87295c5fa1cc.png
# [File] 870fbe6eaa68.png
# [File] 86e7f98f73f1.png
# [File] 869bbd3170cc.png
# [File] 86d58f850a0c.png
# [File] 86baef833ae0.png
# [File] 86b3a7929bec.png
# [File] 8688f3d0fcaf.png
# [File] 8650d32f4a9e.png
# [File] 85fce24084da.png
# [File] 86722fcd802c.png
# [File] 8693ab1fd2be.png
# [File] 85f99e7e4052.png
# [File] 86410aa13b3e.png
# [File] 8660e1864665.png
# [File] 8676427e4625.png
# [File] 857002ed4e49.png
# [File] 85cbb84ac8e0.png
# [File] 851e40a21f81.png
# [File] 85cc6d636898.png
# [File] 8596a24a14bd.png
# [File] 8564b7aa3c1a.png
# [File] 855f0a5442b6.png
# [File] 84c663f39632.png
# [File] 84e8c62165b5.png
# [File] 8543a801dce0.png
# [File] 857230f64a2e.png
# [File] 84b472c49cfa.png
# [File] 84a72e15b23c.png
# [File] 8446826853d0.png
# [File] 8448af27ba07.png
# [File] 84b88e8d3bca.png
# [File] 84b4da14bc23.png
# [File] 84b79243e430.png
# [File] 849a91e9ab28.png
# [File] 848e66b9e199.png
# [File] 847b04287c9c.png
# [File] 8433a032b96c.png
# [File] 842d697884f6.png
# [File] 8421107255ae.png
# [File] 83df53d58f28.png
# [File] 83e529e95b0e.png
# [File] 840a06a9c690.png
# [File] 840527bc6628.png
# [File] 83d81ba5959c.png
# [File] 83fda7c0500b.png
# [File] 837acf120946.png
# [File] 83a63c4a3e4a.png
# [File] 83b61051737f.png
# [File] 838c87c63422.png
# [File] 835b9f6e12ba.png
# [File] 83517eaeccb9.png
# [File] 8329e80c10ac.png
# [File] 83d6e40c869f.png
# [File] 830e297965a1.png
# [File] 8344c783da65.png
# [File] 838b3e4d0bb4.png
# [File] 82d364726a58.png
# [File] 82f2784ead76.png
# [File] 82e5bc01f8a4.png
# [File] 82deb07a6618.png
# [File] 83038ca49b6d.png
# [File] 821789e9053f.png
# [File] 82ac8463fadd.png
# [File] 81bc03e2ff2b.png
# [File] 82bb8a01935f.png
# [File] 8273fdb4405e.png
# [File] 8201cab8322d.png
# [File] 82088c6734e6.png
# [File] 82910bba4753.png
# [File] 81d79d53ed7b.png
# [File] 8241e43408a8.png
# [File] 81b0a2651c45.png
# [File] 8185ce1cdcef.png
# [File] 8191ae701985.png
# [File] 81914ceb4e74.png
# [File] 8114d6a160df.png
# [File] 81704925f759.png
# [File] 81371b0c01ad.png
# [File] 812d5adafaf2.png
# [File] 810d3779abd9.png
# [File] 810ed108f5b7.png
# [File] 80feb1f7ca5e.png
# [File] 80f6b30ece8c.png
# [File] 80ed04a84a16.png
# [File] 80e7cc0a0649.png
# [File] 80e6e425f966.png
# [File] 80dbeb0fdc75.png
# [File] 80d24897669f.png
# [File] 80a02014b418.png
# [File] 80964d8e0863.png
# [File] 7fe7309d0b4f.png
# [File] 80ca40196225.png
# [File] 80c67efc8101.png
# [File] 803120c5d287.png
# [File] 7f84284598f5.png
# [File] 80b5a9519aec.png
# [File] 80b5697f2a5e.png
# [File] 8010c931321f.png
# [File] 8000a6b97a84.png
# [File] 7fdb177b8f7d.png
# [File] 7f6ce40f306b.png
# [File] 807135cbc438.png
# [File] 7fc3a8bb40de.png
# [File] 7e980424868e.png
# [File] 7ea756985353.png
# [File] 7ef5ff774a48.png
# [File] 7e4019ac7f5a.png
# [File] 7e9458de5707.png
# [File] 7e160c8b611e.png
# [File] 7f39c36469b5.png
# [File] 7e0598cc88a0.png
# [File] 7ec1ffe8220b.png
# [File] 7d94a000c2d0.png
# [File] 7ee6de71c140.png
# [File] 7f2cce721e19.png
# [File] 7ec0e61a7e29.png
# [File] 7f6690fa390a.png
# [File] 7f1f3269f546.png
# [File] 7f43becd3e83.png
# [File] 7ddcfcea7369.png
# [File] 7dee6bf8b9c1.png
# [File] 7da558d92100.png
# [File] 7ed4128b2a4e.png
# [File] 7e6e90a93aa5.png
# [File] 7f60f2a083d3.png
# [File] 7e77b61e1639.png
# [File] 7e9081e95bf6.png
# [File] 7eeb191ad06b.png
# [File] 7f2123bc89a3.png
# [File] 7efc91af4ae6.png
# [File] 7eee3d1f1268.png
# [File] 7e5a76c4e103.png
# [File] 7f0ffeb0a333.png
# [File] 7e70344b0c25.png
# [File] 7ccf9d25dc48.png
# [File] 7d1da90d3ca9.png
# [File] 7ccb267fd394.png
# [File] 7d0a871c45db.png
# [File] 7d48f8cdfb69.png
# [File] 7d8f67cadc29.png
# [File] 7d261f986bef.png
# [File] 7d626a7ffe76.png
# [File] 7ce671f952be.png
# [File] 7d1b40fdbd86.png
# [File] 7d3835e4e63a.png
# [File] 7d37a2939f12.png
# [File] 7d11dbc1e738.png
# [File] 7c6594b50690.png
# [File] 7c2e852171c0.png
# [File] 7bc4dd99eee5.png
# [File] 7c52fe73e748.png
# [File] 7c629b491d1a.png
# [File] 7bc00e58d419.png
# [File] 7be1b9aa78aa.png
# [File] 7bc2e0fa3f72.png
# [File] 7ba6b23c4b46.png
# [File] 7c90ab025331.png
# [File] 7bf981d9c7fe.png
# [File] 7c3747c0b2c3.png
# [File] 7cc4b7aabe04.png
# [File] 7bda86d95c5b.png
# [File] 7c2f820a6425.png
# [File] 7a238a1d3cf3.png
# [File] 7b9d519cbd66.png
# [File] 7b211d8bd249.png
# [File] 7a6495a39d87.png
# [File] 7a3ea1779b13.png
# [File] 7a46cfa69bae.png
# [File] 7a42443ed106.png
# [File] 7b20210d9120.png
# [File] 7b8c78b41c0d.png
# [File] 7a77c3eb468c.png
# [File] 7ad0c4975890.png
# [File] 7ae69d22075a.png
# [File] 7a6e384a0846.png
# [File] 7a9f45fdf29b.png
# [File] 7b49041cbf17.png
# [File] 7b29e3783919.png
# [File] 7af4d8704032.png
# [File] 7b87b0015282.png
# [File] 7adfb8fc0621.png
# [File] 7a39c91416e2.png
# [File] 7b691d9ced34.png
# [File] 7aabd768abff.png
# [File] 789f0ec1eab8.png
# [File] 79059d0592c4.png
# [File] 7877be80901c.png
# [File] 799214e8b07c.png
# [File] 7a12f49e29df.png
# [File] 78d53c82a23e.png
# [File] 79540be95177.png
# [File] 789c60cba801.png
# [File] 79ade634c633.png
# [File] 78a577c3e0bf.png
# [File] 7a06ea127e02.png
# [File] 788ddb0b70b7.png
# [File] 79cbae28d8b2.png
# [File] 79be2ff796bf.png
# [File] 78937523f7a8.png
# [File] 799cb4c816ae.png
# [File] 7a0cff4c24b2.png
# [File] 78b3f819dcc5.png
# [File] 78bcdffb8785.png
# [File] 79d44db3da2d.png
# [File] 789434d095d1.png
# [File] 79ce83c07588.png
# [File] 780f9c237c56.png
# [File] 772af553b8b7.png
# [File] 77acc2cafee1.png
# [File] 77baa08a1345.png
# [File] 785777558f05.png
# [File] 7831ce1d895e.png
# [File] 77b7b71ebcc3.png
# [File] 7743f4e04a6d.png
# [File] 77a1f1398fdb.png
# [File] 7828dd083cdc.png
# [File] 780be525036d.png
# [File] 77e15f213b04.png
# [File] 77e7c7a160c8.png
# [File] 77543f66a84a.png
# [File] 780f9daaa24b.png
# [File] 77ab222bf85c.png
# [File] 77a9538b8362.png
# [File] 784d6d302f98.png
# [File] 77f69c7ff324.png
# [File] 75a4343b12f9.png
# [File] 757572337fd0.png
# [File] 757e39293591.png
# [File] 75c180e04f65.png
# [File] 7569ac24762e.png
# [File] 76cab26493f1.png
# [File] 7635921c5efb.png
# [File] 75a7bc945b7d.png
# [File] 763ad1236efe.png
# [File] 76c0c7e1b6cb.png
# [File] 76e589911303.png
# [File] 7550966ef777.png
# [File] 76095c338728.png
# [File] 7663aba8d762.png
# [File] 76516f828d88.png
# [File] 760b6f4c6d82.png
# [File] 76fe19ff64fb.png
# [File] 75a071608ea6.png
# [File] 76be29bb30b2.png
# [File] 756b0d6488bb.png
# [File] 76e6a9238570.png
# [File] 76f3473df8a6.png
# [File] 76b950c6ed5e.png
# [File] 762d6e5d5068.png
# ...
# [File] 650104ede84c.png
# [File] 655cafb4c932.png
# [File] 6504b703c429.png
# [File] 65cf00be6fb4.png
# [File] 650fbed3fdca.png
# [File] 657859f893d9.png
# [File] 658ad9f09f5d.png
# [File] 6531070bf03c.png
# [File] 65a7fe9482fe.png
# [File] 653534ded339.png
# [File] 65a3b13ad9a0.png
# [File] 64eb5a79dfdd.png
# [File] 64fedbf97473.png
# [File] 63c3c571b8ee.png
# [File] 64b9206afb3f.png
# [File] 63e041a757eb.png
# [File] 64ac539f58cb.png
# [File] 64bad93fde3f.png
# [File] 64c6c6ee0d98.png
# [File] 63b71347e95d.png
# [File] 63b4d030b016.png
# [File] 64678182d8a8.png
# [File] 64a13949e879.png
# [File] 63c0eafd6aa9.png
# [File] 63c7b0265775.png
# [File] 63d217b059b6.png
# [File] 62ecdc90dd42.png
# [File] 6377e23928f6.png
# [File] 62e6f814c8f5.png
# [File] 63a03880939c.png
# [File] 6324d77cf926.png
# [File] 62b826899151.png
# [File] 633fe9dbaf39.png
# [File] 62b4be2799ca.png
# [File] 62cc7ddb53b6.png
# [File] 6363b360aefb.png
# [File] 639915f58a2f.png
# [File] 63363410389a.png
# [File] 628b581aa905.png
# [File] 6253f23229b1.png
# [File] 61f403fdb434.png
# [File] 6294b378d09f.png
# [File] 624fb7317106.png
# [File] 62318d514160.png
# [File] 6298468d7d75.png
# [File] 62ab144d5cee.png
# [File] 61e301bd3c25.png
# [File] 61c2fbd16e38.png
# [File] 61da799bf0aa.png
# [File] 61c667663f2f.png
# [File] 61d9c88a3a4b.png
# [File] 61bbe8db6f3a.png
# [File] 61bbc11fe503.png
# [File] 61ac9b0dc6b9.png
# [File] 61a62b1dcc36.png
# [File] 6194e0fff071.png
# [File] 6181aa9f75f4.png
# [File] 6180920bc224.png
# [File] 6165081b9021.png
# [File] 6107a2e9f60e.png
# [File] 60eeae3ba23d.png
# [File] 612f2df37a1d.png
# [File] 613bacb35c05.png
# [File] 6110ecb3bb1c.png
# [File] 6155cf375354.png
# [File] 60e269e3e188.png
# [File] 613028ede6a0.png
# [File] 60f15dd68d30.png
# [File] 60edda7b4871.png
# [File] 60aa4e649abf.png
# [File] 6089fa333013.png
# [File] 609be3ca5ddf.png
# [File] 5fcff7280019.png
# [File] 606daaf0bfc7.png
# [File] 6028a575dc27.png
# [File] 5f70ad48a525.png
# [File] 6061f5b7378d.png
# [File] 5f51192841f7.png
# [File] 5f6db235c04d.png
# [File] 5f13e8a07344.png
# [File] 5f4a8c074bd5.png
# [File] 5ed6dc419e4d.png
# [File] 5efa24b03d5e.png
# [File] 5e7cc6ab4ac4.png
# [File] 5eb311bcb5f9.png
# [File] 5e7630f8438e.png
# [File] 5dd2e26fc244.png
# [File] 5e7db41b3bee.png
# [File] 5e97cb2b0888.png
# [File] 5e5275ddee29.png
# [File] 5e52c9fe676f.png
# [File] 5e505e25cd3e.png
# [File] 5eb8fb1aad41.png
# [File] 5ea9e447bb62.png
# [File] 5ead17e894ae.png
# [File] 5de4615a5161.png
# [File] 5e18af29d812.png
# [File] 5d5b5da5f939.png
# [File] 5db895d3f1fc.png
# [File] 5db2e3a4594a.png
# [File] 5dc23e440de3.png
# [File] 5d74f98d62be.png
# [File] 5d6239c0fd39.png
# [File] 5d9c841eb245.png
# [File] 5cf9127f251a.png
# [File] 5ca73d28f17f.png
# [File] 5cab3ef4b31c.png
# [File] 5c85d22bd0de.png
# [File] 5c8482926a08.png
# [File] 5d3c8c1f57da.png
# [File] 5ce5eeaf757a.png
# [File] 5cbe88914a72.png
# [File] 5d024177e214.png
# [File] 5ca779ace6e7.png
# [File] 5cc6dea19614.png
# [File] 5d4e5fd34d91.png
# [File] 5cde55f745af.png
# [File] 5c7ab966a3ee.png
# [File] 5c817060c0ed.png
# [File] 5c6194562ed2.png
# [File] 5bf3357a2823.png
# [File] 5b804948e35f.png
# [File] 5b76117c4bcb.png
# [File] 5bf6f2958e53.png
# [File] 5bda2ed09e62.png
# [File] 5ba156a35ff2.png
# [File] 5bea250d8bf5.png
# [File] 5b994ff78547.png
# [File] 5baed382f062.png
# [File] 5b5b80a3edee.png
# [File] 5b47043942f4.png
# [File] 5b72ff04333d.png
# [File] 5b3e7197ac1c.png
# [File] 5b644a403e1f.png
# [File] 5b3d41626ec5.png
# [File] 5b32ece9c627.png
# [File] 5b301a6d1ac7.png
# [File] 5b1c4cefeb24.png
# [File] 5b2648ad455e.png
# [File] 5b0e53f53ef3.png
# [File] 5b068765e846.png
# [File] 5a091e8cd95c.png
# [File] 5a5d3798c357.png
# [File] 5a93c0f783c4.png
# [File] 5a179c123fd8.png
# [File] 5ac7a414560e.png
# [File] 5a36cea278ae.png
# [File] 5a27b9b2a9c1.png
# [File] 5a11d21c2828.png
# [File] 5a2c27b95c7c.png
# [File] 5ad3dabeb2cd.png
# [File] 5a0fe0ee4301.png
# [File] 5a444c32cd9a.png
# [File] 5a03fe3ed15c.png
# [File] 59f3f70abddd.png
# [File] 59fee5bc3479.png
# [File] 59ee65760535.png
# [File] 5995321563b7.png
# [File] 599b89048034.png
# [File] 59bd19c1c5bb.png
# [File] 59e5212f7139.png
# [File] 595446774178.png
# [File] 596f4fdb0004.png
# [File] 59928f999ae7.png
# [File] 599498e9e4bc.png
# [File] 594f69b503ad.png
# [File] 598b8f5b3822.png
# [File] 58f07741ee3b.png
# [File] 58eb3809f456.png
# [File] 58ccba7eec9c.png
# [File] 58c12863f33d.png
# [File] 5905a9b06a73.png
# [File] 58b866484a05.png
# [File] 58af2c054ced.png
# [File] 5879285f9d8d.png
# [File] 5889a0c75cac.png
# [File] 58a9e0d7f7af.png
# [File] 587146a55885.png
# [File] 586f5c56081e.png
# [File] 58529a8638d0.png
# [File] 582115961a3d.png
# [File] 582f739b8f62.png
# [File] 58184d6fd087.png
# [File] 5814cbd2e9bf.png
# [File] 57f933d3d7c7.png
# [File] 58059e73d2d4.png
# [File] 57ce57a8cfb0.png
# [File] 57db4781e7ec.png
# [File] 57f5ad4b5b29.png
# [File] 57a5f1015504.png
# [File] 57a710de68a4.png
# [File] 57a5e4274275.png
# [File] 5777ef74c9ec.png
# [File] 578109578b46.png
# [File] 576e189d23d4.png
# [File] 57760be09c03.png
# [File] 555d0bef3c5b.png
# [File] 565f3404f9b2.png
# [File] 568455854a11.png
# [File] 5728b8aa98ef.png
# [File] 55eac26bd383.png
# [File] 55fd453001cc.png
# [File] 5548a7961a3e.png
# [File] 5511f114e7ee.png
# [File] 5723d0ec895e.png
# [File] 5633ced07d8e.png
# [File] 5712e2aa73a2.png
# [File] 55968f0e63c4.png
# [File] 57469423a012.png
# [File] 573ea80a53be.png
# [File] 5671eb95512b.png
# [File] 55eb405ec71e.png
# [File] 571bbdbf585e.png
# [File] 56e56aa08362.png
# [File] 55f7f018c61c.png
# [File] 549381330191.png
# [File] 54dc6e8107cd.png
# [File] 54f57cf26126.png
# [File] 53f6c1c65c04.png
# [File] 54bdcdecd8f3.png
# [File] 541db13517e2.png
# [File] 547b37da9223.png
# [File] 545df1bbcd61.png
# [File] 542964865b1e.png
# [File] 54334705a34d.png
# [File] 53ddae6a619e.png
# [File] 55092c0071eb.png
# [File] 537e50fdf22e.png
# [File] 5445255635f0.png
# [File] 54038e56131d.png
# [File] 53c874dbc594.png
# [File] 537e5c578f40.png
# [File] 55034b1dbff2.png
# [File] 54b322c66d01.png
# [File] 5486da4273d7.png
# [File] 540e4973829e.png
# [File] 54bbe3da103e.png
# [File] 54cab3596214.png
# [File] 527bea76116c.png
# [File] 53273d664cd8.png
# [File] 524f240e0c90.png
# [File] 535682537302.png
# [File] 5299a532f0e0.png
# [File] 531b39880c32.png
# [File] 5265dc9acdf8.png
# [File] 5293576816aa.png
# [File] 5257cb536da2.png
# [File] 5327f88a1919.png
# [File] 523d0c2cb4d6.png
# [File] 52ae917fcea4.png
# [File] 523b3f0fc646.png
# [File] 530d78467615.png
# [File] 52ddde91a349.png
# [File] 52886bed8a07.png
# [File] 53704c80f0d8.png
# [File] 5321ab64f9ea.png
# [File] 525acfea47e8.png
# [File] 5347b4c8e9b3.png
# [File] 53327edb9e4d.png
# [File] 525d0dd8dc45.png
# [File] 5264a54e1830.png
# [File] 52edbe29d655.png
# [File] 523ff163211b.png
# [File] 5288f7441f64.png
# [File] 52dbec057cc8.png
# [File] 529906ff9dfa.png
# [File] 51cfeccaf40d.png
# [File] 52230bbef30e.png
# [File] 519c6e8f78dc.png
# [File] 5188a8afa879.png
# [File] 511fd66b2df8.png
# [File] 51e656e5a541.png
# [File] 51da6aebba8f.png
# [File] 51405d042000.png
# [File] 51d574513bcb.png
# [File] 51af8c112682.png
# [File] 518e880613de.png
# [File] 51d780864365.png
# [File] 51cd8d2057fa.png
# [File] 51269b77d312.png
# [File] 51a078d6d43a.png
# [File] 51d0034d177d.png
# [File] 521d3e264d71.png
# [File] 51aa3361294c.png
# [File] 5152bf091152.png
# [File] 51af8a689511.png
# [File] 513b0a4651fa.png
# [File] 51a1d162e223.png
# [File] 521b5377a727.png
# [File] 5173d54fc214.png
# [File] 5077cdb88aed.png
# [File] 501c319f7a9f.png
# [File] 50915e2329a1.png
# [File] 50916d67bb51.png
# [File] 51131b48f9d4.png
# [File] 50ddd7d976df.png
# [File] 50a2aef380c8.png
# [File] 5056fa7d505f.png
# [File] 5069feccd866.png
# [File] 50d8249f7bc9.png
# [File] 50840c36f0b4.png
# [File] 5078caaf1f57.png
# [File] 50f5201fd18a.png
# [File] 5090917a2676.png
# [File] 51030843fde2.png
# [File] 504a69096fcb.png
# [File] 500aad15b7c8.png
# [File] 50d8a8fb7737.png
# [File] 510aa0a898fa.png
# [File] 4e0656629d02.png
# [File] 4fd5ec0dca09.png
# [File] 4ec7796df40e.png
# [File] 4df6a81b476e.png
# [File] 4e8585a96739.png
# [File] 4e1e252317b5.png
# [File] 4e82c3c8d31f.png
# [File] 4e43d05cc2ef.png
# [File] 4e7694eebb91.png
# [File] 4fa26d065ad3.png
# [File] 4fef9ed8a4c5.png
# [File] 4f46d7ee61ed.png
# [File] 4ffa38550c95.png
# [File] 4e6071b73120.png
# [File] 4e85aa647534.png
# [File] 4ee1ad981a6d.png
# [File] 4f60129e9a5b.png
# [File] 4ef7144e24ff.png
# [File] 4eaf2f81819d.png
# [File] 4e4a6224a04e.png
# [File] 4faf4063db8c.png
# [File] 4e231670b48c.png
# [File] 4fecf87184e6.png
# [File] 4e54ccfd49b2.png
# [File] 4ecd1fdd1435.png
# [File] 4ed31cc07366.png
# [File] 4f20f9a9a65b.png
# [File] 4f7755e74a9e.png
# [File] 4ef0b485a7da.png
# [File] 4ef16a53d899.png
# [File] 4f5dd7660b17.png
# [File] 4f0866b90c27.png
# [File] 4f6abc40c72d.png
# [File] 4eabad7948cf.png
# [File] 4dd71fc7f22b.png
# [File] 4dd9d29eae5d.png
# [File] 4d21ce39c905.png
# [File] 4dd4a4bf2421.png
# [File] 4d1e7def7624.png
# [File] 4cf4d528c08e.png
# [File] 4cfd22ae43d4.png
# [File] 4dc2211a1c31.png
# [File] 4d009cebabc9.png
# [File] 4ccfa0b4e96c.png
# [File] 4d167ca69ea8.png
# [File] 4d7d6928534a.png
# [File] 4ccee4db09b6.png
# [File] 4dbce359d0e1.png
# [File] 4da6e2089d57.png
# [File] 4dd5d5ccddcf.png
# [File] 4d17559ac1e2.png
# [File] 4d1cf360b2d7.png
# [File] 4d47300e3ddb.png
# [File] 4d9fc85a8259.png
# [File] 4da2961e62fe.png
# [File] 4cddfc22b0ad.png
# [File] 4dd14c380696.png
# [File] 4ce74e5eb51d.png
# [File] 4d3de40ced3a.png
# [File] 4cde86044ad1.png
# [File] 4dd7b322f342.png
# [File] 4c129470cec4.png
# [File] 4c5ab774a381.png
# [File] 4aa3d771c5e4.png
# [File] 4b1001050f1d.png
# [File] 4c570172778b.png
# [File] 4ab8c0cece7f.png
# [File] 4c53cc97ea13.png
# [File] 4c3c1ed09771.png
# [File] 4bd5d0b30198.png
# [File] 4c9f0fdaaef7.png
# [File] 4c78d9d18da9.png
# [File] 4c60f6fcea75.png
# [File] 4a96c28f3f07.png
# [File] 4c60b10a3a6a.png
# [File] 4abca30b676b.png
# [File] 4aa07d720638.png
# [File] 4c52922f3bfd.png
# [File] 4bcee3cbe232.png
# [File] 4b237b958555.png
# [File] 4ad8d3ec8789.png
# [File] 4b6cb0bcfd44.png
# [File] 4bd941611343.png
# [File] 4b5ffea77373.png
# [File] 4b6895d0cf8d.png
# [File] 4beeca5cc859.png
# [File] 4ad6109706e8.png
# [File] 4b422b48d0d4.png
# [File] 4a7dc013e802.png
# [File] 4c17e85686f0.png
# [File] 4b618537d52f.png
# [File] 4cae247d9909.png
# [File] 4c635a01593d.png
# [File] 4c6c5a1bf5ab.png
# [File] 4c389d033cb0.png
# [File] 49a4765f8822.png
# [File] 4a589edaea60.png
# [File] 4a693dd3921a.png
# [File] 4a213b405ee4.png
# [File] 49eb73968c44.png
# [File] 4a44cc840ebe.png
# [File] 496155f71d0a.png
# [File] 4958bfcc9f38.png
# [File] 4a3da369b227.png
# [File] 4a5a6efc0bef.png
# [File] 49c5e7f6b8d2.png
# [File] 4a558a1cd243.png
# [File] 4a1afe4044f4.png
# [File] 4a0bba3b7d83.png
# [File] 4a4cb731f91a.png
# [File] 4982378d72f9.png
# [File] 499c8df39222.png
# [File] 49e4b95ee2dc.png
# [File] 4a05f81b3aba.png
# [File] 498f143c0374.png
# [File] 495255c7492f.png
# [File] 49d69c4c6290.png
# [File] 4a0890b08532.png
# [File] 4927945ecfed.png
# [File] 49386d603494.png
# [File] 493d99f030e2.png
# [File] 494fc9c745a3.png
# [File] 495106ae3b68.png
# [File] 49419f8d5cb4.png
# [File] 4826d10030b3.png
# [File] 47b756014447.png
# [File] 48afe8c47454.png
# [File] 48543037d0b3.png
# [File] 478fc46eaa49.png
# [File] 47d1603a555b.png
# [File] 48c72dec46e5.png
# [File] 4926dea289f8.png
# [File] 482088e6be44.png
# [File] 484dbeb9bf2a.png
# [File] 46f56c38051f.png
# [File] 46d3316c4857.png
# [File] 475300735b7f.png
# [File] 4860f7813654.png
# [File] 4731e708ede3.png
# [File] 47e51065b819.png
# [File] 4818672273af.png
# [File] 486e852a3b4d.png
# [File] 48c49f662f7d.png
# [File] 4704dbb59536.png
# [File] 48fda42bd5d4.png
# [File] 475c7ded0f7a.png
# [File] 47536db39f00.png
# [File] 48a45619d1a3.png
# [File] 45ae04cfde5d.png
# [File] 45c39ab9e797.png
# [File] 44e951e45dca.png
# [File] 45e4b7eada54.png
# [File] 46923eea9a4e.png
# [File] 44e0d56e9d42.png
# [File] 462937ece243.png
# [File] 460893cd86e3.png
# [File] 453d553b0a94.png
# [File] 465c618f7b23.png
# [File] 4554062fa836.png
# [File] 46acc506fa61.png
# [File] 467b7d9d811c.png
# [File] 4689b739d240.png
# [File] 454792eb6e05.png
# [File] 46cdc8b685bd.png
# [File] 4661006f3ba6.png
# [File] 45693d027798.png
# [File] 46c1548d730e.png
# [File] 457c7c927e27.png
# [File] 44f4ae58990e.png
# [File] 44ecf3f4efa5.png
# [File] 4528fbbd43a3.png
# [File] 453a1e2754b2.png
# [File] 461fa5292fda.png
# [File] 44f7f3ef9d50.png
# [File] 45369821d6a3.png
# [File] 454a944eb557.png
# [File] 44271f3cb18f.png
# [File] 44a4d04162cc.png
# [File] 4464bb62bf20.png
# [File] 4409965eb2a4.png
# [File] 4393c5bc576a.png
# [File] 4462fba1d2a1.png
# [File] 4384fa687afa.png
# [File] 441848e0f308.png
# [File] 436e7a7af761.png
# [File] 44a86263117b.png
# [File] 4478b870e549.png
# [File] 4489d421e5aa.png
# [File] 437900a99871.png
# [File] 43bc7c066dfb.png
# [File] 43fb6eda9b97.png
# [File] 437cbec4a3f8.png
# [File] 44878f34e31f.png
# [File] 43ddd0ab0cc4.png
# [File] 43823561c3f0.png
# [File] 445a8a6da55c.png
# [File] 436fa3fd145a.png
# [File] 4403538fb50f.png
# [File] 44c869174e3a.png
# [File] 441117562359.png
# [File] 44976c3b11a6.png
# [File] 43e9c66eb0f3.png
# [File] 44855f666225.png
# [File] 43f22d1be8dd.png
# [File] 441affbe99aa.png
# [File] 42b93b574f23.png
# [File] 435d900fa7b2.png
# [File] 42b08dca9b2f.png
# [File] 42c65af5ab16.png
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pydrive2/auth.py in LoadServiceConfigSettings(self)
#     612             try:
# --> 613                 self.client_config[config] = self.settings["service_config"][
#     614                     config
#
# KeyError: 'client_user_email'
#
# During handling of the above exception, another exception occurred:
#
# InvalidConfigError                        Traceback (most recent call last)
# /tmp/ipython-input-224364988.py in <cell line: 0>()
#      18
#      19 # Download your whole dataset folder:
# ---> 20 download_folder_recursively(
#      21     "1HN1QyKm6RVPwEMVfwFO-pNDbrlpp3WNf",
#      22     "aptos_dataset"
#
# /tmp/ipython-input-224364988.py in download_folder_recursively(folder_id, dest_path)
#      11         if f['mimeType'] == 'application/vnd.google-apps.folder':
#      12             print(f"[Folder] {fname}")
# ---> 13             download_folder_recursively(fid, os.path.join(dest_path, fname))
#      14         else:
#      15             print(f"[File] {fname}")
#
# /tmp/ipython-input-224364988.py in download_folder_recursively(folder_id, dest_path)
#      15             print(f"[File] {fname}")
#      16             out_path = os.path.join(dest_path, fname)
# ---> 17             f.GetContentFile(out_path)
#      18
#      19 # Download your whole dataset folder:
#
# /usr/local/lib/python3.12/dist-packages/pydrive2/auth.py in _decorated(self, *args, **kwargs)
#      59                 self.auth.ServiceAuth()
#      60             else:
# ---> 61                 self.auth.LocalWebserverAuth()
#      62
#      63         # Initialise service if not built yet.
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_pydrive2.py in PatchedLocalWebServerAuth(self, *args, **kwargs)
#      61               self.credentials.refresh(httplib2.Http())
#      62               return
# ---> 63             return orig_local_webserver_auth(self, *args, **kwargs)
#      64
#      65           module.GoogleAuth.LocalWebserverAuth = PatchedLocalWebServerAuth
#
# /usr/local/lib/python3.12/dist-packages/pydrive2/auth.py in _decorated(self, *args, **kwargs)
#     123             self.LoadCredentials()
#     124         if self.flow is None:
# --> 125             self.GetFlow()
#     126         if self.credentials is None:
#     127             code = decoratee(self, *args, **kwargs)
#
# /usr/local/lib/python3.12/dist-packages/pydrive2/auth.py in GetFlow(self)
#     642             config in self.client_config for config in self.CLIENT_CONFIGS_LIST
#     643         ):
# --> 644             self.LoadClientConfig()
#     645         constructor_kwargs = {
#     646             "redirect_uri": self.client_config["redirect_uri"],
#
# /usr/local/lib/python3.12/dist-packages/pydrive2/auth.py in LoadClientConfig(self, backend)
#     530             self.LoadClientConfigSettings()
#     531         elif backend == "service":
# --> 532             self.LoadServiceConfigSettings()
#     533         else:
#     534             raise InvalidConfigError("Unknown client_config_backend")
#
# /usr/local/lib/python3.12/dist-packages/pydrive2/auth.py in LoadServiceConfigSettings(self)
#     617                 err = "Insufficient service config in settings"
#     618                 err += f"\n\nMissing: {config} key."
# --> 619                 raise InvalidConfigError(err)
#     620
#     621     def LoadClientConfigSettings(self):
#
# InvalidConfigError: Insufficient service config in settings
#
# Missing: client_user_email key.

# %%
# train_transform = transforms.Compose([
#     transforms.Resize((128, 128)),
#     transforms.RandomHorizontalFlip(p=0.5),
#     transforms.ToTensor(),
# ])

# test_transform = transforms.Compose([
#     transforms.Resize((128, 128)),
#     transforms.ToTensor(),
# ])

# %%
# class RetinopathyDataset(Dataset):
#     def __init__(self, df, img_dir, transform=None, has_labels=True):
#         self.df = df
#         self.img_dir = img_dir
#         self.transform = transform
#         self.has_labels = has_labels

#     def __len__(self):
#         return len(self.df)

#     def __getitem__(self, idx):
#         row = self.df.iloc[idx]
#         img_name = row["id_code"] + ".png"
#         img_path = os.path.join(self.img_dir, img_name)

#         img = Image.open(img_path).convert("RGB")

#         if self.transform:
#             img = self.transform(img)

#         if self.has_labels:
#             return img, int(row["diagnosis"])
#         return img

# %%
# class SimpleDRCNN(nn.Module):
#     def __init__(self, num_classes=5):
#         super(SimpleDRCNN, self).__init__()

#         self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
#         self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
#         self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)

#         self.pool = nn.MaxPool2d(2, 2)
#         self.dropout = nn.Dropout(0.3)

#         # 128 -> 64 -> 32 -> 16
#         self.fc1 = nn.Linear(128 * 16 * 16, 512)
#         self.fc2 = nn.Linear(512, num_classes)

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         x = self.pool(F.relu(self.conv3(x)))
#         x = self.dropout(x)
#         x = torch.flatten(x, 1)
#         x = F.relu(self.fc1(x))
#         x = self.dropout(x)
#         return self.fc2(x)

# %%
# DATA_DIR = "/content/aptos2019-blindness-detection"

# train_csv_path = os.path.join(DATA_DIR, "train.csv")
# test_csv_path = os.path.join(DATA_DIR, "test.csv")
# train_img_dir = os.path.join(DATA_DIR, "train_images")
# test_img_dir = os.path.join(DATA_DIR, "test_images")
# train_df = pd.read_csv(train_csv_path)
# test_df = pd.read_csv(test_csv_path)
# print(train_df.head())
# print(test_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3308167054.py in <cell line: 0>()
#       5 train_img_dir = os.path.join(DATA_DIR, "train_images")
#       6 test_img_dir = os.path.join(DATA_DIR, "test_images")
# ----> 7 train_df = pd.read_csv(train_csv_path)
#       8 test_df = pd.read_csv(test_csv_path)
#       9 print(train_df.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/aptos2019-blindness-detection/train.csv'

# %%
# train_csv = "/content/train.csv"
# train_img_dir = "/content/train_images"

# train_df = pd.read_csv(train_csv)

# train_dataset = RetinopathyDataset(train_df, train_img_dir, transform=train_transform)

# train_loader = DataLoader(
#     train_dataset,
#     batch_size=64,          # GPU-friendly
#     shuffle=True,
#     num_workers=2,          # Great for Colab
#     pin_memory=True
# )

# %%
# model = SimpleDRCNN().to(device)
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# scaler = torch.cuda.amp.GradScaler()

# epochs = 5

# for epoch in range(epochs):
#     model.train()
#     running_loss = 0.0

#     pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{epochs}")

#     for imgs, labels in pbar:
#         imgs = imgs.to(device, non_blocking=True)
#         labels = labels.to(device, non_blocking=True)

#         optimizer.zero_grad()

#         with torch.cuda.amp.autocast():
#             outputs = model(imgs)
#             loss = criterion(outputs, labels)

#         scaler.scale(loss).backward()
#         scaler.step(optimizer)
#         scaler.update()

#         running_loss += loss.item()
#         pbar.set_postfix(loss=running_loss / len(train_loader))

# print("Training finished!")
